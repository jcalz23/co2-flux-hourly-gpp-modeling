# %% [markdown]
# # Notesbook Setup

# %%
if 'google.colab' in str(get_ipython()):
  IN_COLLAB = True
else:
  IN_COLLAB = False

#TODO: CHANGE THIS BASED ON YOUR OWN LOCAL SETTINGS
MY_HOME_ABS_PATH = "/content/drive/MyDrive/W210/co2-flux-hourly-gpp-modeling"

if IN_COLLAB:
  from google.colab import drive
  drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %% [markdown]
# ## Import modules

# %%
# install required modules quietly
required_packages = ['geopandas', 'pyspark', 'azure-storage-blob']

for p in required_packages: 
  try:
      __import__(p)
  except ImportError:
      # %pip install {p} --quiet

# %%
# Import SparkSession
from pyspark.sql import SparkSession
# Create a Spark Session
spark = SparkSession.builder.master("local[*]").getOrCreate()
# Check Spark Session Information
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://60df871e0e07:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.3.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>pyspark-shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
import os
os.environ["PYARROW_IGNORE_TIMEZONE"] = "1"
import math
import json

import pyspark.pandas as pd
from calendar import monthrange
from datetime import datetime
from io import BytesIO

import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio

# Load locale custome modules
import sys
if IN_COLLAB:
  os.chdir(MY_HOME_ABS_PATH)
  sys.path.insert(0,os.path.abspath("./code/src/tools"))
else:
  sys.path.append(os.path.abspath("./code/src/tools"))

from CloudIO.AzStorageClient import AzStorageClient
from edahelpers import *

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %% [markdown]
# ## Define Constants

# %%
root_dir =  MY_HOME_ABS_PATH
tmp_dir =  root_dir + os.sep + '.tmp'
raw_data_dir = tmp_dir
data_dir = root_dir + os.sep + 'data'
cred_dir = root_dir + os.sep + '.cred'
az_cred_file = cred_dir + os.sep + 'azblobcred.json'

if IN_COLLAB:
  raw_data_dir = "/content/drive/MyDrive/CO2_flux_gpp_modeling/DS_capstone_23Spring_CO2/Data/half_hourly_data"

site_metadata_filename = data_dir + os.sep + 'site-metadata.csv'

# Output
tag = "1_raw"
container = "gold-samples-data"
blob_name = f"gold_samples_trim_v_{tag}.parquet" #Advisor suggested features only

# %%
# "Golden" Sites
tier1_sites = ["US-MMS", "US-Vcp", "FR-Pue", "CH-Lae", "US-Var", "US-Ne2", "ES-LJu", "US-Ton"]
tier2_sites = ["US-UMB", "US-Me2", "FI-Hyy", "US-NR1", "IT-Lav", "US-Wkg", "US-ARM", "US-SRM"]

target_sites = tier1_sites + tier2_sites

# %% [markdown]
# # Get Gold Sample Site Metadata

# %%
# Load site metadata
included_site_features = ['site_id', 'site_name', 'IGBP', 'lat', 'long', 'koppen_main_name', 'start_time','end_time', 'record_count', 'recorded_day_percentage']
train_site_metadata_df = pd.read_csv(site_metadata_filename, usecols = included_site_features)

# only focus on target sites
train_site_metadata_df= train_site_metadata_df.loc[train_site_metadata_df['site_id'].isin(target_sites)]
print(f"size:{train_site_metadata_df.shape}")
train_site_metadata_df.reset_index(inplace=True, drop=True)
train_site_metadata_df=train_site_metadata_df.dropna()
display(train_site_metadata_df)
# Out:
# size:(16, 10)
#    site_id IGBP      lat       long                               site_name  \
# 0   FR-Pue  EBF 43.74130    3.59570                               Puechabon
# 1   US-NR1  ENF 40.03290 -105.54640          Niwot Ridge Forest (LTER NWT1)
# 3   US-SRM  WSA 31.82140 -110.86610                     Santa Rita Mesquite
# 4   US-Ton  WSA 38.43160 -120.96598                             Tonzi Ranch
# 5   US-Var  GRA 38.41330 -120.95070                       Vaira Ranch- Ione
# 6   US-Wkg  GRA 31.73650 -109.94190         Walnut Gulch Kendall Grasslands
# 7   US-ARM  CRO 36.60580  -97.48880  ARM Southern Great Plains site- Lamont
# 9   US-Me2  ENF 44.45230 -121.55740          Metolius mature ponderosa pine
# 10  US-UMB  DBF 45.55980  -84.71380       Univ. of Mich. Biological Station
# 11  US-Vcp  ENF 35.86240 -106.59740           Valles Caldera Ponderosa Pine
# 12  CH-Lae   MF 47.47833    8.36439                                 Laegern
# 13  ES-LJu  OSH 36.92659   -2.75212                     Llano de los Juanes
# 14  FI-Hyy  ENF 61.84741   24.29477                                Hyytiala
# 15  IT-Lav  ENF 45.95620   11.28132                                Lavarone
#
#    koppen_main_name  record_count           start_time             end_time  \
# 0         Temperate  245760.00000  2000-07-26 00:00:00  2014-12-31 23:30:00
# 1              Cold  270768.00000  1999-05-02 00:00:00  2014-12-31 23:30:00
# 3              Arid  190752.00000  2004-01-01 00:00:00  2014-12-31 23:30:00
# 4         Temperate  230928.00000  2001-05-24 00:00:00  2014-12-31 23:30:00
# 5         Temperate  245712.00000  2000-11-01 00:00:00  2014-12-31 23:30:00
# 6              Arid  186768.00000  2004-05-07 00:00:00  2014-12-31 23:30:00
# 7         Temperate  259104.00000  2003-01-01 00:00:00  2018-12-31 23:30:00
# 9              Cold  230688.00000  2002-01-01 00:00:00  2017-12-31 23:30:00
# 10             Cold  191904.00000  2007-01-01 00:00:00  2017-12-31 23:30:00
# 11             Cold  174528.00000  2007-01-01 00:00:00  2017-12-31 23:30:00
# 12             Cold  288384.00000  2004-04-09 00:00:00  2020-12-17 23:30:00
# 13        Temperate  239616.00000  2004-05-26 00:00:00  2020-12-31 23:30:00
# 14             Cold  407472.00000  1996-06-18 00:00:00  2020-12-31 23:30:00
# 15             Cold  297840.00000  2003-01-01 00:00:00  2020-12-31 23:30:00
#
#     recorded_day_percentage
# 0                   0.97117
# 1                   0.98567
# 3                   0.98905
# 4                   0.96801
# 5                   0.98937
# 6                   1.00000
# 7                   0.92368
# 9                   0.82238
# 10                  0.99502
# 11                  0.90493
# 12                  0.98540
# 13                  0.82322
# 14                  0.94712
# 15                  0.94373

# %%
train_site_IGBP = list(train_site_metadata_df['IGBP'].unique())
print(train_site_IGBP)

train_site_koppen = train_site_metadata_df['koppen_main_name'].unique()
print(train_site_koppen)
# Out:
# ['EBF', 'ENF', 'WSA', 'GRA', 'CRO', 'DBF', 'MF', 'OSH']
# ['Temperate' 'Cold' 'Arid']

# %%
# Target test dataset record count:
print(f"Train dataset (untrimmed) size: {train_site_metadata_df['record_count'].sum()}")
print(f"Target test dataset (untrimmed) size: {train_site_metadata_df['record_count'].sum()*0.2}")
print(f"Target test dataset (untrimmed) size: {train_site_metadata_df['record_count'].sum()*0.1}")
# Out:
# Train dataset (untrimmed) size: 3460224.0
# Target test dataset (untrimmed) size: 692044.8
# Target test dataset (untrimmed) size: 346022.4

# %% [markdown]
# # Get Test Sites Candidates

# %%
# Load site metadata
included_site_features = ['site_id', 'site_name', 'IGBP', 'lat', 'long', 'koppen_main_name', 'start_time','end_time', 'record_count', 'recorded_day_percentage']
test_site_metadata_df = pd.read_csv(site_metadata_filename, usecols = included_site_features)

# Not the gold sample site, and same IGBP as gold sample sites
cond = ((~test_site_metadata_df['site_id'].isin(target_sites)) &\
        (test_site_metadata_df['IGBP'].isin(train_site_IGBP)) &\
        (test_site_metadata_df['koppen_main_name'].isin(train_site_koppen)))
test_site_metadata_df = test_site_metadata_df.loc[cond]
test_site_metadata_df.reset_index(inplace=True, drop=True)
test_site_metadata_df = test_site_metadata_df.dropna()
test_site_metadata_df.drop(test_site_metadata_df[test_site_metadata_df['recorded_day_percentage'] <= 0.8].index, inplace = True)
print(f"size:{test_site_metadata_df.shape}")
test_site_metadata_df.sort_values(['record_count','recorded_day_percentage'], ascending=[True, False])
# Out:
# size:(169, 10)
#     site_id IGBP       lat       long  \
# 171  DK-Gds  ENF  56.07370    9.33410
# 95   US-Wi7  OSH  46.64911  -91.06928
# 96   US-Wi8  DBF  46.72233  -91.25242
# 44   ES-Ln2  OSH  36.96950   -3.47582
# 88   US-Wi0  ENF  46.61878  -91.08144
# 93   US-Wi5  ENF  46.65308  -91.08581
# 41   DK-Fou  CRO  56.48420    9.58722
# 120  US-Bi2  CRO  38.10910 -121.53510
# 70   US-KS1  ENF  28.45830  -80.67090
# 33   CN-Du3  GRA  42.05510  116.28090
# 6    AU-Lox  DBF -34.47040  140.65510
# 73   US-Me1  ENF  44.57940 -121.50000
# 145  US-Wgr  CRO  45.11290 -122.65600
# 141  US-Tw2  CRO  38.10470 -121.64330
# 8    AU-Rob  EBF -17.11750  145.63010
# 135  US-Ro5  CRO  44.69100  -93.05760
# 136  US-Ro6  CRO  44.69460  -93.05780
# 72   US-Lin  CRO  36.35660 -119.84230
# 35   CN-Sw2  GRA  41.79020  111.89710
# 0    AR-SLu   MF -33.46480  -66.45980
# 84   US-Tw3  CRO  38.11590 -121.64670
# 119  US-Bi1  CRO  38.09920 -121.49930
# 54   IT-La2  ENF  45.95420   11.28530
# 59   JP-MBF  DBF  44.38690  142.31860
# 116  US-ARb  GRA  35.54970  -98.04020
# 117  US-ARc  GRA  35.54650  -98.04000
# 65   US-GBT  ENF  41.36579 -106.23970
# 53   IT-Isp  DBF  45.81264    8.63358
# 71   US-LWW  GRA  34.96040  -97.97890
# 148  BE-Lcr  DBF  51.11218    3.85043
# 30   CN-Dan  GRA  30.49780   91.06640
# 32   CN-Du2  GRA  42.04670  116.28360
# 1    AR-Vir  ENF -28.23950  -56.18860
# 206  FR-EM2  CRO  49.87211    3.02065
# 193  IT-BFt  DBF  45.19775   10.74197
# 3    AU-Cum  EBF -33.61518  150.72362
# 4    AU-Emr  GRA -23.85870  148.47460
# 180  FI-Qvd  CRO  60.29524   22.39161
# 10   AU-TTE  GRA -22.28700  133.64000
# 28   CN-Cha   MF  42.40250  128.09580
# 43   ES-LgS  OSH  37.09794   -2.96583
# 76   US-Me5  ENF  44.43719 -121.56676
# 55   IT-PT1  DBF  45.20087    9.06104
# 31   CN-Din  EBF  23.17330  112.53610
# 50   IT-CA3  DBF  42.38000   12.02220
# 178  FI-Ken  ENF  67.98721   24.24301
# 5    AU-Gin  WSA -31.37640  115.71380
# 12   AU-Wac  EBF -37.42590  145.18780
# 26   CA-TPD  DBF  42.63533  -80.55773
# 121  US-CRT  CRO  41.62850  -83.34710
# 34   CN-Qia  ENF  26.74140  115.05810
# 115  US-AR2  GRA  36.63580  -99.59750
# 190  FR-Tou  GRA  43.57286    1.37474
# 40   DK-Eng  GRA  55.69053   12.19175
# 13   AU-Whr  EBF -36.67320  145.02940
# 104  CA-NS1  ENF  55.87920  -98.48390
# 45   FI-Jok  CRO  60.89860   23.51345
# 137  US-Rws  OSH  43.16750 -116.71320
# 49   IT-CA2  CRO  42.37722   12.02604
# 18   CA-NS7  OSH  56.63583  -99.94833
# 48   IT-CA1  DBF  42.38041   12.02656
# 29   CN-Cng  GRA  44.59340  123.50920
# 105  CA-NS2  ENF  55.90580  -98.52470
# 39   DE-Seh  CRO  50.87062    6.44965
# 114  US-AR1  GRA  36.42670  -99.42000
# 134  US-Ro4  GRA  44.67810  -93.07230
# 7    AU-Rig  GRA -36.64990  145.57590
# 107  CA-NS5  ENF  55.86310  -98.48500
# 125  US-FR2  WSA  29.94950  -97.99620
# 77   US-Me6  ENF  44.32328 -121.60780
# 60   JP-SMF   MF  35.26170  137.07880
# 67   US-Goo  GRA  34.25470  -89.87350
# 108  CA-NS6  OSH  55.91670  -98.96440
# 106  CA-NS3  ENF  55.91170  -98.38220
# 42   ES-Amo  OSH  36.83361   -2.25232
# 208  SE-Lnn  CRO  58.34063   13.10177
# 112  CA-SJ2  ENF  53.94500 -104.64900
# 195  IT-Lsn  OSH  45.74048   12.75030
# 181  FI-Sii  GRA  61.83265   24.19285
# 14   AU-Wom  EBF -37.42220  144.09440
# 182  FI-Var  ENF  67.75490   29.61000
# 127  US-Fuf  ENF  35.08900 -111.76200
# 173  ES-Abr  WSA  38.70184   -6.78588
# 126  US-Fmf  ENF  35.14260 -111.72730
# 85   US-Twt  CRO  38.10872 -121.65310
# 81   US-SRC   MF  31.90830 -110.83950
# 74   US-Me3  ENF  44.31540 -121.60780
# 200  RU-Fy2  ENF  56.44760   32.90190
# 9    AU-Stp  GRA -17.15070  133.35020
# 36   CZ-BK2  GRA  49.49443   18.54285
# 132  US-Prr  ENF  65.12370 -147.48760
# 157  CZ-Lnz  DBF  48.68155   16.94633
# 202  SE-Htm  ENF  56.09763   13.41897
# 163  DE-HoH  DBF  52.08656   11.22235
# 204  SE-Ros  ENF  64.17250   19.73800
# 184  FR-Bil  ENF  44.49365   -0.95609
# 61   NL-Hor  GRA  52.24035    5.07130
# 27   CH-Oe1  GRA  47.28583    7.73194
# 122  US-Dk1  GRA  35.97120  -79.09340
# 177  ES-LM2  WSA  39.93459   -5.77588
# 176  ES-LM1  WSA  39.94269   -5.77868
# 203  SE-Nor  ENF  60.08650   17.47950
# 110  CA-Qfo  ENF  49.69250  -74.34210
# 124  US-Dk3  ENF  35.97820  -79.09420
# 188  FR-Hes  DBF  48.67410    7.06465
# 156  CZ-KrP  CRO  49.57326   15.07877
# 69   US-IB2  GRA  41.84062  -88.24103
# 123  US-Dk2  DBF  35.97360  -79.10040
# 87   US-Whs  OSH  31.74380 -110.05220
# 52   IT-Cpz  EBF  41.70525   12.37611
# 198  IT-SR2  ENF  43.73202   10.29091
# 56   IT-Ro1  DBF  42.40812   11.93001
# 168  DE-RuS  CRO  50.86591    6.44714
# 158  CZ-RAJ  ENF  49.44372   16.69651
# 144  US-Vcm  ENF  35.88840 -106.53210
# 66   US-GLE  ENF  41.36653 -106.23990
# 57   IT-Ro2  DBF  42.39026   11.92093
# 101  CA-Ca3  ENF  49.53460 -124.90040
# 129  US-KFS  GRA  39.05610  -95.19070
# 131  US-Oho  DBF  41.55450  -83.84380
# 130  US-Mpj  OSH  34.43840 -106.23770
# 167  DE-RuR  GRA  50.62191    6.30413
# 147  BE-Dor  GRA  50.31135    4.96859
# 138  US-SRG  GRA  31.78940 -110.82770
# 103  CA-Gro   MF  48.21670  -82.15560
# 142  US-UMd  DBF  45.56250  -84.69750
# 179  FI-Let  ENF  60.64183   23.95952
# 47   FR-LBr  ENF  44.71711   -0.76930
# 139  US-Seg  GRA  34.36230 -106.70190
# 159  CZ-Stn  DBF  49.03598   17.96990
# 2    AT-Neu  GRA  47.11667   11.31750
# 140  US-Ses  OSH  34.33490 -106.74420
# 20   CA-Obs  ENF  53.98717 -105.11779
# 118  US-Bar  DBF  44.06460  -71.28810
# 199  IT-Tor  GRA  45.84444    7.57806
# 99   CA-Ca1  ENF  49.86730 -125.33360
# 166  DE-Obe  ENF  50.78666   13.72129
# 58   IT-SRo  ENF  43.72786   10.28444
# 185  FR-FBn   MF  43.24079    5.67865
# 133  US-Ro1  CRO  44.71430  -93.08980
# 46   FI-Sod  ENF  67.36239   26.63859
# 102  CA-Cbo  DBF  44.31670  -79.93330
# 187  FR-Gri  CRO  48.84422    1.95191
# 153  CH-Fru  GRA  47.11583    8.53778
# 151  CH-Cha  GRA  47.21022    8.41044
# 113  CA-TP4  ENF  42.71020  -80.35740
# 19   CA-Oas  DBF  53.62889 -106.19779
# 192  IT-BCi  CRO  40.52375   14.95744
# 189  FR-Lam  CRO  43.49644    1.23788
# 186  FR-Fon  DBF  48.47636    2.78010
# 165  DE-Kli  CRO  50.89306   13.52238
# 155  CZ-BK1  ENF  49.50208   18.53688
# 183  FR-Aur  CRO  43.54965    1.10610
# 161  DE-Gri  GRA  50.95004   13.51259
# 149  BE-Lon  CRO  50.55162    4.74623
# 154  CH-Oe2  CRO  47.28642    7.73375
# 196  IT-MBo  GRA  46.01468   11.04583
# 191  IL-Yat  ENF  31.34504   35.05199
# 128  US-Ho1  ENF  45.20410  -68.74020
# 197  IT-Ren  ENF  46.58686   11.43369
# 146  BE-Bra   MF  51.30761    4.51984
# 160  DE-Geb  CRO  51.09973   10.91463
# 162  DE-Hai  DBF  51.07921   10.45217
# 207  NL-Loo  ENF  52.16658    5.74356
# 201  RU-Fyo  ENF  56.46153   32.92208
# 172  DK-Sor  DBF  55.48587   11.64464
# 150  BE-Vie   MF  50.30493    5.99812
# 152  CH-Dav  ENF  46.81533    9.85591
# 170  DE-Tha  ENF  50.96256   13.56515
#
#                                              site_name koppen_main_name  \
# 171                                  Gludsted Plantage             Cold
# 95                            Red pine clearcut (RPCC)             Cold
# 96                       Young hardwood clearcut (YHW)             Cold
# 44                            Lanjaron-Salvage logging             Cold
# 88                                Young red pine (YRP)             Cold
# 93                        Mixed young jack pine (MYJP)             Cold
# 41                                              Foulum             Cold
# 120                                Bouldin Island corn        Temperate
# 70                   Kennedy Space Center (slash pine)        Temperate
# 33                              Duolun Degraded Meadow             Cold
# 6                                               Loxton             Arid
# 73                              Metolius - Eyerly burn             Cold
# 145                                   Willamette Grass        Temperate
# 141                                     Twitchell Corn        Temperate
# 8                  Robson Creek, Queensland, Australia        Temperate
# 135                                Rosemount I18_South             Cold
# 136                                Rosemount I18_North             Cold
# 72                             Lindcove Orange Orchard             Arid
# 35                              Siziwang Grazed (SZWG)             Arid
# 0                                             San Luis             Arid
# 84                                   Twitchell Alfalfa        Temperate
# 119                             Bouldin Island Alfalfa        Temperate
# 54                                           Lavarone2             Cold
# 59                           Moshiri Birch Forest Site             Cold
# 116        ARM Southern Great Plains burn site- Lamont        Temperate
# 117     ARM Southern Great Plains control site- Lamont        Temperate
# 65                                GLEES Brooklyn Tower             Cold
# 53                                        Ispra ABC-IS        Temperate
# 71                            Little Washita Watershed        Temperate
# 148                                          Lochristi        Temperate
# 30                                           Dangxiong             Arid
# 32                              Duolun_grassland (D01)             Cold
# 1                                             Virasoro        Temperate
# 206                                   Estrees-Mons A28        Temperate
# 193                                      Bosco Fontana        Temperate
# 3                                     Cumberland Plain        Temperate
# 4                                              Emerald             Arid
# 180                                             Qvidja             Cold
# 10                                        Ti Tree East             Arid
# 28                                        Changbaishan             Cold
# 43                                         Laguna Seca             Cold
# 76                      Metolius-first young aged pine             Cold
# 55                                 Parco Ticino forest        Temperate
# 31                                          Dinghushan        Temperate
# 50                                      Castel d'Asso3        Temperate
# 178                                         Kenttarova             Cold
# 5                                               Gingin        Temperate
# 12                                       Wallaby Creek        Temperate
# 26             Ontario - Turkey Point Mature Deciduous             Cold
# 121                     Curtice Walter-Berger cropland             Cold
# 34                                         Qianyanzhou        Temperate
# 115            ARM USDA UNL OSU Woodward Switchgrass 2        Temperate
# 190                                           Toulouse        Temperate
# 40                                             Enghave             Cold
# 13                                               Whroo             Arid
# 104                                 UCI-1850 burn site             Cold
# 45                                           Jokioinen             Cold
# 137               Reynolds Creek Wyoming big sagebrush             Arid
# 49                                      Castel d'Asso2        Temperate
# 18                                  UCI-1998 burn site             Cold
# 48                                      Castel d'Asso1        Temperate
# 29                                           Changling             Cold
# 105                                 UCI-1930 burn site             Cold
# 39                                           Selhausen        Temperate
# 114            ARM USDA UNL OSU Woodward Switchgrass 1        Temperate
# 134                                  Rosemount Prairie             Cold
# 7                                          Riggs Creek        Temperate
# 107                                 UCI-1981 burn site             Cold
# 125                    Freeman Ranch- Mesquite Juniper        Temperate
# 77                            Metolius Young Pine Burn             Cold
# 60                              Seto Mixed Forest Site        Temperate
# 67                                       Goodwin Creek        Temperate
# 108                                 UCI-1989 burn site             Cold
# 106                                 UCI-1964 burn site             Cold
# 42                                          Amoladeras             Arid
# 208                                              Lanna             Cold
# 112  Saskatchewan - Western Boreal, Jack Pine fores...             Cold
# 195                                              Lison        Temperate
# 181                                          Siikaneva             Cold
# 14                                              Wombat        Temperate
# 182                                             Varrio             Cold
# 127                       Flagstaff - Unmanaged Forest             Cold
# 173                                            Albuera        Temperate
# 126                         Flagstaff - Managed Forest             Cold
# 85                                    Twitchell Island        Temperate
# 81                                 Santa Rita Creosote             Arid
# 74                     Metolius-second young aged pine             Cold
# 200                           Fyodorovskoye dry spruce             Cold
# 9                                         Sturt Plains             Arid
# 36                                 Bily Kriz grassland             Cold
# 132      Poker Flat Research Range Black Spruce Forest             Cold
# 157                                            Lanzhot             Cold
# 202                                         Hyltemossa             Cold
# 163                                         Hohes Holz             Cold
# 204                                        Rosinedal-3             Cold
# 184                                              Bilos        Temperate
# 61                                         Horstermeer        Temperate
# 27                                 Oensingen grassland             Cold
# 122                             Duke Forest-open field        Temperate
# 177                           Majadas del Tietar South             Arid
# 176                           Majadas del Tietar North             Arid
# 203                                            Norunda             Cold
# 110       Quebec - Eastern Boreal, Mature Black Spruce             Cold
# 124                        Duke Forest - loblolly pine        Temperate
# 188                                              Hesse        Temperate
# 156                                    Kresin u Pacova             Cold
# 69   Fermi National Accelerator Laboratory- Batavia...             Cold
# 123                              Duke Forest-hardwoods        Temperate
# 87                      Walnut Gulch Lucky Hills Shrub             Arid
# 52                                      Castelporziano        Temperate
# 198                                      San Rossore 2        Temperate
# 56                                   Roccarespampani 1        Temperate
# 168                                  Selhausen Juelich        Temperate
# 158                                              Rajec             Cold
# 144                       Valles Caldera Mixed Conifer             Cold
# 66                                               GLEES             Cold
# 57                                   Roccarespampani 2        Temperate
# 101  British Columbia - Pole sapling Douglas-fir stand        Temperate
# 129                               Kansas Field Station             Cold
# 131                                       Oak Openings             Cold
# 130                Mountainair Pinyon-Juniper Woodland             Arid
# 167                                       Rollesbroich             Cold
# 147                                            Dorinne        Temperate
# 138                               Santa Rita Grassland             Arid
# 103  Ontario - Groundhog River, Boreal Mixedwood Fo...             Cold
# 142                                   UMBS Disturbance             Cold
# 179                                           Lettosuo             Cold
# 47                                             Le Bray        Temperate
# 139                                Sevilleta grassland             Arid
# 159                                             Stitna             Cold
# 2                                             Neustift             Cold
# 140                                Sevilleta shrubland             Arid
# 20   Saskatchewan - Western Boreal, Mature Black Sp...             Cold
# 118                       Bartlett Experimental Forest             Cold
# 199                                            Torgnon             Cold
# 99           British Columbia - 1949 Douglas-fir stand        Temperate
# 166                                     Oberbärenburg             Cold
# 58                                         San Rossore        Temperate
# 185                                       Font-Blanche        Temperate
# 133                                     Rosemount- G21             Cold
# 46                                           Sodankyla             Cold
# 102      Ontario - Mixed Deciduous, Borden Forest Site             Cold
# 187                                            Grignon        Temperate
# 153                                         Früebüel             Cold
# 151                                             Chamau             Cold
# 113  Ontario - Turkey Point 1939 Plantation White Pine             Cold
# 19         Saskatchewan - Western Boreal, Mature Aspen             Cold
# 192                                       Borgo Cioffi        Temperate
# 189                                         Lamasquere        Temperate
# 186                              Fontainebleau-Barbeau        Temperate
# 165                                        Klingenberg             Cold
# 155                                   Bily Kriz forest             Cold
# 183                                             Aurade        Temperate
# 161                                        Grillenburg             Cold
# 149                                             Lonzee        Temperate
# 154                                     Oensingen crop             Cold
# 196                                      Monte Bondone             Cold
# 201                  0.91770
# 172                  0.95477
# 150                  0.96636
# 152                  0.98859
# 170                  0.98096

# %%
# Plot gold sample and test sites candidates
train_plot_df = train_site_metadata_df
train_plot_df['start']= pd.to_datetime(train_plot_df['start_time']).dt.date
train_plot_df['end']= pd.to_datetime(train_plot_df['end_time']).dt.date
train_plot_df['IGBP_id'] = train_plot_df['IGBP'].replace(train_site_IGBP, [x for x in range(len(train_site_IGBP))])

test_plot_df = test_site_metadata_df
test_plot_df['start']= pd.to_datetime(test_plot_df['start_time']).dt.date
test_plot_df['end']= pd.to_datetime(test_plot_df['end_time']).dt.date
test_plot_df['IGBP_id'] = test_plot_df['IGBP'].replace(train_site_IGBP, [x for x in range(len(train_site_IGBP))])

train_plot = go.Scattergeo(lat = train_plot_df["lat"], lon = train_plot_df["long"],
                     marker_size=train_plot_df["record_count"]/15000,
                     marker_color=train_plot_df["IGBP_id"],
                     marker_line_color=train_plot_df["IGBP_id"],
                     marker_line_width=2,
                     marker_symbol ="star-open-dot",
                     name = "Train",
                     opacity=1,
                     customdata=train_plot_df[["site_name","site_id",
                                                         "record_count","recorded_day_percentage",
                                                         "start","end",
                                                         "IGBP","koppen_main_name"]])

test_plot = go.Scattergeo(lat = test_plot_df["lat"], lon = test_plot_df["long"],
                     marker_size=test_plot_df["record_count"]/15000,
                     marker_color=test_plot_df["IGBP_id"],
                     opacity=0.75,
                     name = "Test<br>Candidate",
                     customdata=test_plot_df[["site_name","site_id",
                                                         "record_count","recorded_day_percentage",
                                                         "start","end",
                                                         "IGBP","koppen_main_name"]])

fig = go.Figure(data=[train_plot, test_plot])
fig.update_layout(
    title={
        'text': "Gold Sample (Triaining) Sites and Test Site Candidates",
        'y':0.925,
        'x':0},
    geo = go.layout.Geo(
        resolution = 50,
        scope = "world",
        showframe = False,
        showcoastlines = True,
        landcolor = "rgb(229, 229, 229)",
        countrycolor = "white" ,
        coastlinecolor = "white"
    )
)
fig.update_geos(lataxis_range=[-60,90])
fig.update_traces(hovertemplate = "<b>%{customdata[0]} (%{customdata[1]})</b>" +
                                  "<br>(%{customdata[6]}, %{customdata[7]})" + 
                                  "<br>Records: %{customdata[2]} (%{customdata[3]}%)" + 
                                  "<br>%{customdata[4]} ~ %{customdata[5]}")
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0}, height = 500, width = 800)
fig.update_layout(legend=dict(orientation="h", y=0.05, xanchor="left", yanchor="bottom", itemwidth=50))

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="444f3c7b-d847-412d-bdee-7b5f613e38cc" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("444f3c7b-d847-412d-bdee-7b5f613e38cc")) {                    Plotly.newPlot(                        "444f3c7b-d847-412d-bdee-7b5f613e38cc",                        [{"customdata":[["Puechabon","FR-Pue",245760.0,0.97117,"2000-07-26","2014-12-31","EBF","Temperate"],["Niwot Ridge Forest (LTER NWT1)","US-NR1",270768.0,0.98567,"1999-05-02","2014-12-31","ENF","Cold"],["Santa Rita Mesquite","US-SRM",190752.0,0.98905,"2004-01-01","2014-12-31","WSA","Arid"],["Tonzi Ranch","US-Ton",230928.0,0.96801,"2001-05-24","2014-12-31","WSA","Temperate"],["Vaira Ranch- Ione","US-Var",245712.0,0.98937,"2000-11-01","2014-12
# %%
# Export to HTML
file_name= data_dir + os.sep + "figures" + os.sep + "GoldSites_TrainCandiates_WorldMap.html"
pio.write_html(fig, file = file_name, include_plotlyjs = 'cdn')

# %% [markdown]
# # Select Test Sites

# %%
test_sites = ["US-GLE", # ENF, Cold
              "US-AR1", # GRA, Temperate
              "US-Seg", # GRA, Arid
              "US-FR2", # WSA, Temperate
              "ES-LM2", # WSA, Arid
              "CA-Cbo", # DBF, Cold
              "FR-Lam", # CRO, Temperate
              "IT-Cpz", # EBF, Temperate
              "CN-Cha", # MF Cold
              "IT-Lsn", # OSH, Temperate
              ]

# %% [markdown]
# ## Plot Gold Sample Sites and Selected Test Sites

# %%
final_test_plot_df = test_plot_df.loc[test_plot_df['site_id'].isin(test_sites)]

train_plot = go.Scattergeo(lat = train_plot_df["lat"], lon = train_plot_df["long"],
                     marker_size=train_plot_df["record_count"]/15000,
                     marker_color=train_plot_df["IGBP_id"],
                     marker_line_color=train_plot_df["IGBP_id"],
                     marker_line_width=2,
                     marker_symbol ="star-open-dot",
                     name = "Train",
                     opacity=1,
                     customdata=train_plot_df[["site_name","site_id",
                                                         "record_count","recorded_day_percentage",
                                                         "start","end",
                                                         "IGBP","koppen_main_name"]])

test_plot = go.Scattergeo(lat = final_test_plot_df["lat"], lon = final_test_plot_df["long"],
                     marker_size=final_test_plot_df["record_count"]/15000,
                     marker_color=final_test_plot_df["IGBP_id"],
                     name = "Test",
                     customdata=final_test_plot_df[["site_name","site_id",
                                                         "record_count","recorded_day_percentage",
                                                         "start","end",
                                                         "IGBP","koppen_main_name"]])

fig = go.Figure(data=[train_plot, test_plot])
fig.update_layout(
    title={
        'text': "Gold Sample (Triaining) Sites and Selected Test Sites",
        'y':0.925,
        'x':0},
    geo = go.layout.Geo(
        resolution = 50,
        scope = "world",
        showframe = False,
        showcoastlines = True,
        landcolor = "rgb(229, 229, 229)",
        countrycolor = "white" ,
        coastlinecolor = "white"
    )
)
fig.update_geos(lataxis_range=[-60,90])
fig.update_traces(hovertemplate = "<b>%{customdata[0]} (%{customdata[1]})</b>" +
                                  "<br>(%{customdata[6]}, %{customdata[7]})" + 
                                  "<br>Records: %{customdata[2]} (%{customdata[3]}%)" + 
                                  "<br>%{customdata[4]} ~ %{customdata[5]}")
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0}, height = 500, width = 800)
fig.update_layout(legend=dict(orientation="h", y=0.05, xanchor="left", yanchor="bottom", itemwidth=50))

fig.show()

# Export to HTML
file_name= data_dir + os.sep + "figures" + os.sep + "GoldSites_TrainSites_WorldMap.html"
pio.write_html(fig, file = file_name, include_plotlyjs = 'cdn')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="566dbbf0-9117-4f7d-9039-206eecaad4f5" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("566dbbf0-9117-4f7d-9039-206eecaad4f5")) {                    Plotly.newPlot(                        "566dbbf0-9117-4f7d-9039-206eecaad4f5",                        [{"customdata":[["Puechabon","FR-Pue",245760.0,0.97117,"2000-07-26","2014-12-31","EBF","Temperate"],["Niwot Ridge Forest (LTER NWT1)","US-NR1",270768.0,0.98567,"1999-05-02","2014-12-31","ENF","Cold"],["Santa Rita Mesquite","US-SRM",190752.0,0.98905,"2004-01-01","2014-12-31","WSA","Arid"],["Tonzi Ranch","US-Ton",230928.0,0.96801,"2001-05-24","2014-12-31","WSA","Temperate"],["Vaira Ranch- Ione","US-Var",245712.0,0.98937,"2000-11-01","2014-12-31","GRA","Temperate"],["Walnut Gulch Kendall Grasslands","US-Wkg",186768.0,1.0,"2004-05-07","2014-12-31","GRA","Arid"],["ARM Southern Great Plains site- Lamont","US-ARM",259104.0,0.92368,"2003-01-01","2018-12-31","CRO","Temperate"],["Metolius mature ponderosa pine","US-Me2",230688.0,0.82238,"2002-01-01","2017-12-31","ENF","Cold"],["Univ. of Mich. Biological Station","US-UMB",191904.0,0.99502,"2007-01-01","2017-12-31","DBF","Cold"],["Valles Caldera Ponderosa Pine","US-Vcp",174528.0,0.90493,"2007-01-01","2017-12-31","ENF","Cold"],["Laegern","CH-Lae",288384.0,0.9854,"2004-04-09","2020-12-17","MF","Cold"],["Llano de los Juanes","ES-LJu",239616.0,0.82322,"2004-05-26","2020-12-31","OSH","Temperate"],["Hyytiala","FI-Hyy",407472.0,0.94712,"1996-06-18","2020-12-31","ENF","Cold"],["Lavarone","IT-Lav",297840.0,0.94373,"2003-01-01","2020-12-31","ENF","Cold"]],"lat":[43.7413,40.0329,31.8214,38.4316,38.4133,31.7365,36.6058,44.4523,45.5598,35.8624,47.47833,36.92659,61.84741,45.9562],"lon":[3.5957,-105.5464,-110.8661,-120.96598,-120.9507,-109.9419,-97.4888,-121.5574,-84.7138,-106.5974,8.36439,-2.75212,24.29477,11.28132],"marker":{"color":[0,1,2,2,3,3,4,1,5,1,6,7,1,1],"line":{"color":[0,1,2,2,3,3,4,1,5,1,6,7,1,1],"width":2},"size":[16.384,18.0512,12.7168,15.3952,16.3808,12.4512,17.2736,15.3792,12.7936,11.6352,19.2256,15.9744,27.1648,19.856],"symbol":"star-open-dot"},"name":"Train","opacity":1,"type":"scattergeo","hovertemplate":"<b>%{customdata[0]} (%{customdata[1]})</b><br>(%{customdata[6]}, %{customdata[7]})<br>Records: %{customdata[2]} (%{customdata[3]}%)<br>%{customdata[4]} ~ %{customdata[5]}"},{"customdata":[["Changbaishan","CN-Cha",43680.0,0.85126,"2003-01-01","2005-12-04","MF","Cold"],["Castelporziano","IT-Cpz",132720.0,0.86786,"2000-03-21","2008-12-09","EBF","Temperate"],["GLEES","US-GLE",156672.0,0.92256,"2005-04-25","2014-12-31","ENF","Cold"],["Ontario - Mixed Deciduous, Borden Forest Site","CA-Cbo",238944.0,0.80097,"1997-12-26","2014-12-31","DBF","Cold"],["ARM USDA UNL OSU Woodward Switchgrass 1","US-AR1",58848.0,0.91356,"2009-04-30","2012-12-31","GRA","Temperate"],["Freeman Ranch- Mesquite Juniper","US-FR2",65520.0,0.93429,"2005-01-01","2008-12-31","WSA","Temperate"],["Sevilleta grassland","US-Seg",183984.0,0.95396,"2007-01-01","2017-12-31","GRA","Arid"],["Majadas del Tietar South","ES-LM2",117408.0,0.9847,"2014-03-15","2020-12-31","WSA","Arid"],["Lamasquere","FR-Lam",259296.0,0.93574,"2005-03-13","2020-12-31","CRO","Temperate"],["Lison","IT-Lsn",82656.0,0.94253,"2016-01-01","2020-12-31","OSH","Temperate"]],"lat":[42.4025,41.70525,41.36653,44.3167,36.4267,29.9495,34.3623,39.934592,43.496437,45.740482],"lon":[128.0958,12.37611,-106.2399,-79.9333,-99.42,-97.9962,-106.7019,-5.775881,1.237878,12.750297],"marker":{"color":[6,0,1,5,3,2,3,2,4,7],"size":[2.912,8.848,10.4448,15.9296,3.9232,4.368,12.2656,7.8272,17.2864,5.5104]},"name":"Test","type":"scattergeo","hovertemplate":"<b>%{customdata[0]} (%{customdata[1]})</b><br>(%{customdata[6]}, %{customdata[7]})<br>Record ...

# %%
final_test_plot_df
# Out:
#     site_id IGBP      lat       long  \
# 28   CN-Cha   MF 42.40250  128.09580
# 52   IT-Cpz  EBF 41.70525   12.37611
# 66   US-GLE  ENF 41.36653 -106.23990
# 102  CA-Cbo  DBF 44.31670  -79.93330
# 114  US-AR1  GRA 36.42670  -99.42000
# 125  US-FR2  WSA 29.94950  -97.99620
# 139  US-Seg  GRA 34.36230 -106.70190
# 177  ES-LM2  WSA 39.93459   -5.77588
# 189  FR-Lam  CRO 43.49644    1.23788
# 195  IT-Lsn  OSH 45.74048   12.75030
#
#                                          site_name koppen_main_name  \
# 28                                    Changbaishan             Cold
# 52                                  Castelporziano        Temperate
# 66                                           GLEES             Cold
# 102  Ontario - Mixed Deciduous, Borden Forest Site             Cold
# 114        ARM USDA UNL OSU Woodward Switchgrass 1        Temperate
# 125                Freeman Ranch- Mesquite Juniper        Temperate
# 139                            Sevilleta grassland             Arid
# 177                       Majadas del Tietar South             Arid
# 189                                     Lamasquere        Temperate
# 195                                          Lison        Temperate
#
#      record_count           start_time             end_time  \
# 28    43680.00000  2003-01-01 00:00:00  2005-12-04 23:30:00
# 52   132720.00000  2000-03-21 00:00:00  2008-12-09 23:30:00
# 66   156672.00000  2005-04-25 00:00:00  2014-12-31 23:30:00
# 102  238944.00000  1997-12-26 00:00:00  2014-12-31 23:30:00
# 114   58848.00000  2009-04-30 00:00:00  2012-12-31 23:30:00
# 125   65520.00000  2005-01-01 00:00:00  2008-12-31 23:30:00
# 139  183984.00000  2007-01-01 00:00:00  2017-12-31 23:30:00
# 177  117408.00000  2014-03-15 00:00:00  2020-12-31 23:30:00
# 189  259296.00000  2005-03-13 00:00:00  2020-12-31 23:30:00
# 195   82656.00000  2016-01-01 00:00:00  2020-12-31 23:30:00
#
#      recorded_day_percentage       start         end  IGBP_id
# 28                   0.85126  2003-01-01  2005-12-04        6
# 52                   0.86786  2000-03-21  2008-12-09        0
# 66                   0.92256  2005-04-25  2014-12-31        1
# 102                  0.80097  1997-12-26  2014-12-31        5
# 114                  0.91356  2009-04-30  2012-12-31        3
# 125                  0.93429  2005-01-01  2008-12-31        2
# 139                  0.95396  2007-01-01  2017-12-31        3
# 177                  0.98470  2014-03-15  2020-12-31        2
# 189                  0.93574  2005-03-13  2020-12-31        4
# 195                  0.94253  2016-01-01  2020-12-31        7

# %%
#Target test dataset (untrimmed) size: 692044.8
#Target test dataset (untrimmed) size: 346022.4

final_test_plot_df.record_count.sum()
# Out:
# 1339728.0
