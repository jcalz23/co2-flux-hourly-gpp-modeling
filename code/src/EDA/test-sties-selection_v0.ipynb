# %% [markdown]
# # Notesbook Setup

# %%
if 'google.colab' in str(get_ipython()):
  IN_COLLAB = True
else:
  IN_COLLAB = False

#TODO: CHANGE THIS BASED ON YOUR OWN LOCAL SETTINGS
MY_HOME_ABS_PATH = "/content/drive/MyDrive/W210/co2-flux-hourly-gpp-modeling"

if IN_COLLAB:
  from google.colab import drive
  drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %% [markdown]
# ## Import modules

# %%
# install required modules quietly
required_packages = ['azure-storage-blob', 'plotly']

for p in required_packages: 
  try:
      __import__(p)
  except ImportError:
      # %pip install {p} --quiet

# %%
# !pip install plotly==5.13.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: plotly==5.13.0 in /usr/local/lib/python3.9/dist-packages (5.13.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from plotly==5.13.0) (8.2.2)

# %%
import os
os.chdir(MY_HOME_ABS_PATH)

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio

from timeit import default_timer
from datetime import datetime
import gc
import pickle

# Load locale custome modules
os.chdir(MY_HOME_ABS_PATH)
sys.path.append('./.cred')
sys.path.append('./code/src/tools')
sys.path.append(os.path.abspath("./code/src/tools"))
  
from CloudIO.AzStorageClient import AzStorageClient
from data_pipeline_lib import *

pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %% [markdown]
# ## Define Constants

# %%
# Download full data
root_dir =  MY_HOME_ABS_PATH
tmp_dir =  root_dir + os.sep + '.tmp'
data_dir = root_dir + os.sep + 'data'
model_dir = data_dir + os.sep + 'models'
cred_dir = root_dir + os.sep + '.cred'
az_cred_file = cred_dir + os.sep + 'azblobcred.json'

site_metadata_filename = data_dir + os.sep + 'site-metadata.csv'

container = "all-sites-data"
blob_name = "full_2010_2015_v_mvp_raw.parquet"
local_file = tmp_dir + os.sep + blob_name

# %% [markdown]
# # Define Site splits

# %%
SITE_SPLITS =[
      ['AR-SLu', 'AU-ASM', 'AU-Cpr', 'AU-Cum', 'AU-RDF', 'CA-TP3', 'CA-TPD', 'CN-Sw2',
        'DE-SfN', 'NL-Hor', 'US-Me6', 'US-Syv', 'US-WCr', 'US-AR2', 'US-Tw4', 'US-UMB', 
        'US-Vcp', 'CH-Cha', 'CZ-BK1', 'CZ-KrP', 'DE-Obe', 'ES-LJu', 'FI-Let', 'FR-Lam', 
        'IT-Lav', 'SE-Lnn'], 
      ['CZ-BK2', 'DE-Spw', 'FR-Pue', 'IT-CA3', 'IT-Noe', 'IT-Ro2', 'US-IB2', 'US-Myb',
        'US-SRM', 'CA-Ca3', 'US-CRT', 'US-Fmf', 'US-KFS', 'US-Prr', 'US-UMd', 'US-Wjs',
        'BE-Bra', 'BE-Lon', 'CH-Lae', 'CZ-RAJ', 'DE-HoH', 'DE-Kli', 'DE-RuR', 'IL-Yat', 
        'IT-Tor', 'SE-Htm'], 
      ['AR-Vir', 'AT-Neu', 'AU-DaS', 'AU-TTE', 'AU-Wom', 'CA-TP1', 'IT-CA1', 'IT-SRo',
        'US-WPT', 'US-Wkg', 'CA-Ca2', 'CA-Cbo', 'CA-TP4', 'US-ARM', 'US-Ro1', 'US-Rws',
        'US-SRG', 'US-Vcm', 'BE-Dor', 'BE-Vie', 'CZ-Stn', 'DE-Geb', 'ES-LM2', 'FR-Fon', 
        'SE-Ros', 'DE-Hte'],
      ['AU-DaP', 'AU-Emr', 'AU-Gin', 'AU-How', 'AU-Rig', 'US-GLE', 'US-NR1', 'US-Twt',
        'CA-Ca1', 'CA-Gro', 'US-AR1', 'US-Bar', 'US-Mpj', 'US-Ses', 'CH-Fru', 'CH-Oe2',
        'DE-Hai', 'DK-Sor', 'FI-Hyy', 'FR-Aur', 'FR-Hes', 'GF-Guy', 'IT-SR2', 'SE-Deg',
        'SE-Nor', 'NL-Loo'],
      ['AU-Stp', 'AU-Whr', 'CA-Oas', 'DE-Lnf', 'ES-Amo', 'FI-Sod', 'IT-CA2', 'US-Ton',
        'US-Var', 'US-Whs', 'US-Ho1', 'US-Oho', 'US-Seg', 'CH-Dav', 'CZ-Lnz', 'CZ-wet',
        'DE-Gri', 'DE-Tha', 'ES-LM1', 'FR-Bil', 'FR-FBn', 'IT-BCi', 'IT-MBo', 'IT-Ren',
        'RU-Fyo']
    ]

# %% [markdown]
# # Get Target Sites

# %%
target_sites = [item for sublist in SITE_SPLITS for item in sublist]
print(target_sites)
# Out:
# ['AR-SLu', 'AU-ASM', 'AU-Cpr', 'AU-Cum', 'AU-RDF', 'CA-TP3', 'CA-TPD', 'CN-Sw2', 'DE-SfN', 'NL-Hor', 'US-Me6', 'US-Syv', 'US-WCr', 'US-AR2', 'US-Tw4', 'US-UMB', 'US-Vcp', 'CH-Cha', 'CZ-BK1', 'CZ-KrP', 'DE-Obe', 'ES-LJu', 'FI-Let', 'FR-Lam', 'IT-Lav', 'SE-Lnn', 'CZ-BK2', 'DE-Spw', 'FR-Pue', 'IT-CA3', 'IT-Noe', 'IT-Ro2', 'US-IB2', 'US-Myb', 'US-SRM', 'CA-Ca3', 'US-CRT', 'US-Fmf', 'US-KFS', 'US-Prr', 'US-UMd', 'US-Wjs', 'BE-Bra', 'BE-Lon', 'CH-Lae', 'CZ-RAJ', 'DE-HoH', 'DE-Kli', 'DE-RuR', 'IL-Yat', 'IT-Tor', 'SE-Htm', 'AR-Vir', 'AT-Neu', 'AU-DaS', 'AU-TTE', 'AU-Wom', 'CA-TP1', 'IT-CA1', 'IT-SRo', 'US-WPT', 'US-Wkg', 'CA-Ca2', 'CA-Cbo', 'CA-TP4', 'US-ARM', 'US-Ro1', 'US-Rws', 'US-SRG', 'US-Vcm', 'BE-Dor', 'BE-Vie', 'CZ-Stn', 'DE-Geb', 'ES-LM2', 'FR-Fon', 'SE-Ros', 'DE-Hte', 'AU-DaP', 'AU-Emr', 'AU-Gin', 'AU-How', 'AU-Rig', 'US-GLE', 'US-NR1', 'US-Twt', 'CA-Ca1', 'CA-Gro', 'US-AR1', 'US-Bar', 'US-Mpj', 'US-Ses', 'CH-Fru', 'CH-Oe2', 'DE-Hai', 'DK-Sor', 'FI-Hyy', 'FR-Aur', 'FR-Hes', 'GF-Guy', 'IT-SR2', 'SE-Deg', 'SE-Nor', 'NL-Loo', 'AU-Stp', 'AU-Whr', 'CA-Oas', 'DE-Lnf', 'ES-Amo', 'FI-Sod', 'IT-CA2', 'US-Ton', 'US-Var', 'US-Whs', 'US-Ho1', 'US-Oho', 'US-Seg', 'CH-Dav', 'CZ-Lnz', 'CZ-wet', 'DE-Gri', 'DE-Tha', 'ES-LM1', 'FR-Bil', 'FR-FBn', 'IT-BCi', 'IT-MBo', 'IT-Ren', 'RU-Fyo']

# %% [markdown]
# # Get Gold Sample Site Metadata

# %%
# Load site metadata
included_site_features = ['site_id', 'site_name', 'IGBP', 'lat', 'long', 'koppen_main_name', 'start_time','end_time', 'record_count', 'recorded_day_percentage']
train_site_metadata_df = pd.read_csv(site_metadata_filename, usecols = included_site_features)

# only focus on target sites
train_site_metadata_df= train_site_metadata_df.loc[train_site_metadata_df['site_id'].isin(target_sites)]
print(f"size:{train_site_metadata_df.shape}")
train_site_metadata_df.reset_index(inplace=True, drop=True)
train_site_metadata_df=train_site_metadata_df.dropna()
display(train_site_metadata_df)
# Out:
# size:(129, 10)
#     site_id IGBP       lat      long      site_name koppen_main_name  \
# 0    AR-SLu   MF -33.46480 -66.45980       San Luis             Arid
# 1    AR-Vir  ENF -28.23950 -56.18860       Virasoro        Temperate
# 2    AT-Neu  GRA  47.11667  11.31750       Neustift             Cold
# 3    AU-ASM  SAV -22.28300 133.24900  Alice Springs             Arid
# 4    AU-Cpr  SAV -34.00210 140.58910       Calperum             Arid
# ..      ...  ...       ...       ...            ...              ...
# 124  SE-Nor  ENF  60.08650  17.47950        Norunda             Cold
# 125  SE-Ros  ENF  64.17250  19.73800    Rosinedal-3             Cold
# 126  DE-Hte  WET  54.21028  12.17611     Huetelmoor        Temperate
# 127  NL-Loo  ENF  52.16658   5.74356         Loobos        Temperate
# 128  SE-Lnn  CRO  58.34063  13.10177          Lanna             Cold
#
#      record_count           start_time             end_time  \
# 0     22128.00000  2009-12-21 00:00:00  2011-03-26 23:30:00
# 1     33984.00000  2010-02-13 00:00:00  2012-06-13 23:30:00
# 2    188112.00000  2002-01-01 00:00:00  2012-12-31 23:30:00
# 3     74496.00000  2010-09-03 00:00:00  2014-12-31 23:30:00
# 4     72384.00000  2010-08-01 00:00:00  2014-12-31 23:30:00
# ..            ...                  ...                  ...
# 124  120768.00000  2014-01-01 00:00:00  2020-12-31 23:30:00
# 125  111216.00000  2014-07-23 00:00:00  2020-12-31 23:30:00
# 126  141696.00000  2009-01-01 00:00:00  2018-12-01 23:30:00
# 127  353760.00000  1996-07-22 00:00:00  2018-09-11 23:30:00
# 128   80400.00000  2014-01-01 00:00:00  2018-12-31 23:30:00
#
#      recorded_day_percentage
# 0                    1.00000
# 1                    0.83099
# 2                    0.97536
# 3                    0.98166
# 4                    0.93432
# ..                       ...
# 124                  0.98397
# 125                  0.98428
# 126                  0.81502
# 127                  0.91134
# 128                  0.91731
#
# [129 rows x 10 columns]

# %%
train_site_IGBP = list(train_site_metadata_df['IGBP'].unique())
print(train_site_IGBP)
# Out:
# ['MF', 'ENF', 'GRA', 'SAV', 'EBF', 'WSA', 'DBF', 'WET', 'OSH', 'CRO', 'CSH']

# %%
# Target test dataset record count:
print(f"Train dataset (untrimmed) size: {train_site_metadata_df['record_count'].sum()}")
print(f"Target test dataset (untrimmed) size: {train_site_metadata_df['record_count'].sum()*0.2}")
print(f"Target test dataset (untrimmed) size: {train_site_metadata_df['record_count'].sum()*0.1}")
# Out:
# Train dataset (untrimmed) size: 3460224.0
# Target test dataset (untrimmed) size: 692044.8
# Target test dataset (untrimmed) size: 346022.4

# %% [markdown]
# # Plot Folds

# %%
for i, k in enumerate(SITE_SPLITS):
  print(k)
  plot_df = train_site_metadata_df.loc[train_site_metadata_df['site_id'].isin(k)]
  display(plot_df.sort_values(['record_count','recorded_day_percentage'], ascending=[True, False]))
# Out:
# ['AR-SLu', 'AU-ASM', 'AU-Cpr', 'AU-Cum', 'AU-RDF', 'CA-TP3', 'CA-TPD', 'CN-Sw2', 'DE-SfN', 'NL-Hor', 'US-Me6', 'US-Syv', 'US-WCr', 'US-AR2', 'US-Tw4', 'US-UMB', 'US-Vcp', 'CH-Cha', 'CZ-BK1', 'CZ-KrP', 'DE-Obe', 'ES-LJu', 'FI-Let', 'FR-Lam', 'IT-Lav', 'SE-Lnn']
#     site_id IGBP       lat       long  \
# 21   CN-Sw2  GRA  41.79020  111.89710
# 0    AR-SLu   MF -33.46480  -66.45980
# 11   AU-RDF  WSA -14.56360  132.47760
# 5    AU-Cum  EBF -33.61518  150.72362
# 24   DE-SfN  WET  47.80639   11.32750
# 20   CA-TPD  DBF  42.63533  -80.55773
# 57   US-AR2  GRA  36.63580  -99.59750
# 72   US-Tw4  WET  38.10270 -121.64130
# 38   US-Me6  ENF  44.32328 -121.60780
# 4    AU-Cpr  SAV -34.00210  140.58910
# 3    AU-ASM  SAV -22.28300  133.24900
# 128  SE-Lnn  CRO  58.34063   13.10177
# 35   NL-Hor  GRA  52.24035    5.07130
# 42   US-Syv   MF  46.24200  -89.34770
# 88   CZ-KrP  CRO  49.57326   15.07877
# 19   CA-TP3  ENF  42.70681  -80.34831
# 76   US-Vcp  ENF  35.86240 -106.59740
# 106  FI-Let  ENF  60.64183   23.95952
# 46   US-WCr  DBF  45.80590  -90.07990
# 73   US-UMB  DBF  45.55980  -84.71380
# 98   DE-Obe  ENF  50.78666   13.72129
# 102  ES-LJu  OSH  36.92659   -2.75212
# 82   CH-Cha  GRA  47.21022    8.41044
# 112  FR-Lam  CRO  43.49644    1.23788
# 87   CZ-BK1  ENF  49.50208   18.53688
# 116  IT-Lav  ENF  45.95620   11.28132
#
#                                              site_name koppen_main_name  \
# 21                              Siziwang Grazed (SZWG)             Arid
# 0                                             San Luis             Arid
# 11             Red Dirt Melon Farm, Northern Territory         Tropical
# 5                                     Cumberland Plain        Temperate
# 24                                   Schechenfilz Nord             Cold
# 20             Ontario - Turkey Point Mature Deciduous             Cold
# 57             ARM USDA UNL OSU Woodward Switchgrass 2        Temperate
# 72                          Twitchell East End Wetland        Temperate
# 38                            Metolius Young Pine Burn             Cold
# 4                                             Calperum             Arid
# 3                                        Alice Springs             Arid
# 128                                              Lanna             Cold
# 35                                         Horstermeer        Temperate
# 42                            Sylvania Wilderness Area             Cold
# 88                                     Kresin u Pacova             Cold
# 19   Ontario - Turkey Point 1974 Plantation White Pine             Cold
# 76                       Valles Caldera Ponderosa Pine             Cold
# 106                                           Lettosuo             Cold
# 46                                        Willow Creek             Cold
# 73                   Univ. of Mich. Biological Station             Cold
# 98                                      Oberbärenburg             Cold
# 102                                Llano de los Juanes        Temperate
# 82                                              Chamau             Cold
# 112                                         Lamasquere        Temperate
# 87                                    Bily Kriz forest             Cold
# 116                                           Lavarone             Cold
#
#      record_count           start_time             end_time  \
# 21    19200.00000  2010-12-20 00:00:00  2012-01-23 23:30:00
# 0     22128.00000  2009-12-21 00:00:00  2011-03-26 23:30:00
# 11    29808.00000  2011-09-24 00:00:00  2013-07-21 23:30:00
# 5     37728.00000  2012-10-19 00:00:00  2014-12-31 23:30:00
# 24    39360.00000  2012-07-05 00:00:00  2014-12-31 23:30:00
# 20    50592.00000  2012-01-01 00:00:00  2014-12-18 23:30:00
# 57    52416.00000  2009-04-30 00:00:00  2012-08-02 23:30:00
# 72    59808.00000  2013-11-27 00:00:00  2017-12-31 23:30:00
# 38    66672.00000  2010-06-05 00:00:00  2014-12-31 23:30:00
# 4     72384.00000  2010-08-01 00:00:00  2014-12-31 23:30:00
# 3     74496.00000  2010-09-03 00:00:00  2014-12-31 23:30:00
# 128   80400.00000  2014-01-01 00:00:00  2018-12-31 23:30:00
# 35   114240.00000  2004-01-22 00:00:00  2011-09-06 23:30:00
# 42   119664.00000  2001-08-30 00:00:00  2014-12-31 23:30:00
# 88   122736.00000  2014-01-01 00:00:00  2020-12-31 23:30:00
# 19   157152.00000  2002-08-13 00:00:00  2014-12-18 23:30:00
# 76   174528.00000  2007-01-01 00:00:00  2017-12-31 23:30:00
# 106  180096.00000  2009-09-03 00:00:00  2020-12-31 23:30:00
# 46   190704.00000  1999-02-07 00:00:00  2014-12-31 23:30:00
# 73   191904.00000  2007-01-01 00:00:00  2017-12-31 23:30:00
# 98   217488.00000  2008-01-25 00:00:00  2020-12-31 23:30:00
# 102  239616.00000  2004-05-26 00:00:00  2020-12-31 23:30:00
# 82   253872.00000  2005-09-09 00:00:00  2020-12-31 23:30:00
# 112  259296.00000  2005-03-13 00:00:00  2020-12-31 23:30:00
# 87   269760.00000  2004-01-01 00:00:00  2020-12-31 23:30:00
# 116  297840.00000  2003-01-01 00:00:00  2020-12-31 23:30:00
#
#      recorded_day_percentage
# 21                   1.00000
# 0                    1.00000
# 11                   0.93103
# 5                    0.97761
# 24                   0.90110
# 20                   0.97322
# 57                   0.91688
# 72                   0.83289
# 38                   0.83124
# 4                    0.93432
# 3                    0.98166
# 128                  0.91731
# 35                   0.85458
# 42                   0.51170
# 88                   1.00000
# 19                   0.72578
# 76                   0.90493
# 106                  0.90672
# 46                   0.68417
# 73                   0.99502
# 98                   0.95894
# 102                  0.82322
# 82                   0.94565
# 112                  0.93574
# 87                   0.90499
# 116                  0.94373
# ['CZ-BK2', 'DE-Spw', 'FR-Pue', 'IT-CA3', 'IT-Noe', 'IT-Ro2', 'US-IB2', 'US-Myb', 'US-SRM', 'CA-Ca3', 'US-CRT', 'US-Fmf', 'US-KFS', 'US-Prr', 'US-UMd', 'US-Wjs', 'BE-Bra', 'BE-Lon', 'CH-Lae', 'CZ-RAJ', 'DE-HoH', 'DE-Kli', 'DE-RuR', 'IL-Yat', 'IT-Tor', 'SE-Htm']
#     site_id IGBP      lat       long  \
# 31   IT-CA3  DBF 42.38000   12.02220
# 60   US-CRT  CRO 41.62850  -83.34710
# 39   US-Myb  WET 38.04978 -121.76506
# 25   DE-Spw  WET 51.89225   14.03369
# 61   US-Fmf  ENF 35.14260 -111.72730
# 22   CZ-BK2  GRA 49.49443   18.54285
# 66   US-Prr  ENF 65.12370 -147.48760
# 123  SE-Htm  ENF 56.09763   13.41897
# 96   DE-HoH  DBF 52.08656   11.22235
# 37   US-IB2  GRA 41.84062  -88.24103
# 90   CZ-RAJ  ENF 49.44372   16.69651
# 33   IT-Ro2  DBF 42.39026   11.92093
# 52   CA-Ca3  ENF 49.53460 -124.90040
# 63   US-KFS  GRA 39.05610  -95.19070
# 32   IT-Noe  CSH 40.60618    8.15169
# 99   DE-RuR  GRA 50.62191    6.30413
# 77   US-Wjs  SAV 34.42550 -105.86150
# 74   US-UMd  DBF 45.56250  -84.69750
# 41   US-SRM  WSA 31.82140 -110.86610
# 120  IT-Tor  GRA 45.84444    7.57806
# 28   FR-Pue  EBF 43.74130    3.59570
# 97   DE-Kli  CRO 50.89306   13.52238
# 85   CH-Lae   MF 47.47833    8.36439
# 80   BE-Lon  CRO 50.55162    4.74623
# 114  IL-Yat  ENF 31.34504   35.05199
# 78   BE-Bra   MF 51.30761    4.51984
#
#                                              site_name koppen_main_name  \
# 31                                      Castel d'Asso3        Temperate
# 60                      Curtice Walter-Berger cropland             Cold
# 39                                    Mayberry Wetland        Temperate
# 25                                           Spreewald             Cold
# 61                          Flagstaff - Managed Forest             Cold
# 22                                 Bily Kriz grassland             Cold
# 66       Poker Flat Research Range Black Spruce Forest             Cold
# 123                                         Hyltemossa             Cold
# 96                                          Hohes Holz             Cold
# 37   Fermi National Accelerator Laboratory- Batavia...             Cold
# 90                                               Rajec             Cold
# 33                                   Roccarespampani 2        Temperate
# 52   British Columbia - Pole sapling Douglas-fir stand        Temperate
# 63                                Kansas Field Station             Cold
# 32                        Arca di Noe - Le Prigionette        Temperate
# 99                                        Rollesbroich             Cold
# 77                            Willard Juniper Savannah             Arid
# 74                                    UMBS Disturbance             Cold
# 41                                 Santa Rita Mesquite             Arid
# 120                                            Torgnon             Cold
# 28                                           Puechabon        Temperate
# 97                                         Klingenberg             Cold
# 85                                             Laegern             Cold
# 80                                              Lonzee        Temperate
# 114                                              Yatir             Arid
# 78                                          Brasschaat        Temperate
#
#      record_count           start_time             end_time  \
# 31    46512.00000  2011-11-14 00:00:00  2014-11-30 23:30:00
# 60    51936.00000  2011-01-01 00:00:00  2013-12-31 23:30:00
# 39    64320.00000  2011-02-08 00:00:00  2014-12-31 23:30:00
# 25    70608.00000  2010-06-06 00:00:00  2014-12-31 23:30:00
# 61    88848.00000  2005-07-30 00:00:00  2010-12-31 23:30:00
# 22   100224.00000  2006-05-04 00:00:00  2012-12-31 23:30:00
# 66   101040.00000  2010-10-29 00:00:00  2016-12-31 23:30:00
# 123  103488.00000  2015-01-01 00:00:00  2020-12-31 23:30:00
# 96   104736.00000  2015-01-01 00:00:00  2020-12-31 23:30:00
# 37   124560.00000  2004-10-07 00:00:00  2011-12-31 23:30:00
# 90   153984.00000  2012-01-01 00:00:00  2020-12-31 23:30:00
# 33   159792.00000  2002-01-01 00:00:00  2012-12-31 23:30:00
# 52   162480.00000  2001-09-14 00:00:00  2010-12-31 23:30:00
# 63   163440.00000  2007-07-02 00:00:00  2017-12-31 23:30:00
# 32   163584.00000  2004-04-07 00:00:00  2014-10-11 23:30:00
# 99   167328.00000  2011-05-14 00:00:00  2020-12-31 23:30:00
# 77   177168.00000  2007-05-05 00:00:00  2017-12-31 23:30:00
# 74   178464.00000  2007-05-25 00:00:00  2017-12-31 23:30:00
# 41   190752.00000  2004-01-01 00:00:00  2014-12-31 23:30:00
# 120  212592.00000  2008-06-22 00:00:00  2020-12-31 23:30:00
# 28   245760.00000  2000-07-26 00:00:00  2014-12-31 23:30:00
# 97   269136.00000  2004-05-06 00:00:00  2020-12-31 23:30:00
# 85   288384.00000  2004-04-09 00:00:00  2020-12-17 23:30:00
# 80   290880.00000  2004-04-01 00:00:00  2020-12-31 23:30:00
# 114  318048.00000  2000-10-01 00:00:00  2020-12-31 23:30:00
# 78   331920.00000  1999-01-20 00:00:00  2020-12-31 23:30:00
#
#      recorded_day_percentage
# 31                   0.87062
# 60                   0.98723
# 39                   0.94167
# 25                   0.88084
# 61                   0.93438
# 22                   0.85785
# 66                   0.93307
# 123                  0.98358
# 96                   0.99544
# 37                   0.98221
# 90                   0.97567
# 33                   0.82852
# 52                   0.99676
# 63                   0.88764
# 32                   0.88750
# 99                   0.99034
# 77                   0.94787
# 74                   0.95973
# 41                   0.98905
# 120                  0.96788
# 28                   0.97117
# 97                   0.92160
# 85                   0.98540
# 80                   0.99036
# 114                  0.89577
# 78                   0.86254
# ['AR-Vir', 'AT-Neu', 'AU-DaS', 'AU-TTE', 'AU-Wom', 'CA-TP1', 'IT-CA1', 'IT-SRo', 'US-WPT', 'US-Wkg', 'CA-Ca2', 'CA-Cbo', 'CA-TP4', 'US-ARM', 'US-Ro1', 'US-Rws', 'US-SRG', 'US-Vcm', 'BE-Dor', 'BE-Vie', 'CZ-Stn', 'DE-Geb', 'ES-LM2', 'FR-Fon', 'SE-Ros', 'DE-Hte']
#     site_id IGBP       lat       long  \
# 1    AR-Vir  ENF -28.23950  -56.18860
# 14   AU-TTE  GRA -22.28700  133.64000
# 47   US-WPT  WET  41.46464  -82.99616
# 68   US-Rws  OSH  43.16750 -116.71320
# 29   IT-CA1  DBF  42.38041   12.02656
# 16   AU-Wom  EBF -37.42220  144.09440
# 51   CA-Ca2  ENF  49.87050 -125.29090
# 125  SE-Ros  ENF  64.17250   19.73800
# 7    AU-DaS  SAV -14.15930  131.38810
# 104  ES-LM2  WSA  39.93459   -5.77588
# 18   CA-TP1  ENF  42.66094  -80.55952
# 126  DE-Hte  WET  54.21028   12.17611
# 75   US-Vcm  ENF  35.88840 -106.53210
# 79   BE-Dor  GRA  50.31135    4.96859
# 69   US-SRG  GRA  31.78940 -110.82770
# 49   US-Wkg  GRA  31.73650 -109.94190
# 91   CZ-Stn  DBF  49.03598   17.96990
# 2    AT-Neu  GRA  47.11667   11.31750
# 34   IT-SRo  ENF  43.72786   10.28444
# 67   US-Ro1  CRO  44.71430  -93.08980
# 53   CA-Cbo  DBF  44.31670  -79.93330
# 55   CA-TP4  ENF  42.71020  -80.35740
# 58   US-ARM  CRO  36.60580  -97.48880
# 110  FR-Fon  DBF  48.47636    2.78010
# 93   DE-Geb  CRO  51.09973   10.91463
# 81   BE-Vie   MF  50.30493    5.99812
#
#                                              site_name koppen_main_name  \
# 1                                             Virasoro        Temperate
# 14                                        Ti Tree East             Arid
# 47                            Winous Point North Marsh             Cold
# 68                Reynolds Creek Wyoming big sagebrush             Arid
# 29                                      Castel d'Asso1        Temperate
# 16                                              Wombat        Temperate
# 51   British Columbia - Clearcut Douglas-fir stand ...        Temperate
# 125                                        Rosinedal-3             Cold
# 7                                   Daly River Cleared         Tropical
# 104                           Majadas del Tietar South             Arid
# 18   Ontario - Turkey Point 2002 Plantation White Pine             Cold
# 126                                         Huetelmoor        Temperate
# 75                        Valles Caldera Mixed Conifer             Cold
# 79                                             Dorinne        Temperate
# 69                                Santa Rita Grassland             Arid
# 49                     Walnut Gulch Kendall Grasslands             Arid
# 91                                              Stitna             Cold
# 2                                             Neustift             Cold
# 34                                         San Rossore        Temperate
# 67                                      Rosemount- G21             Cold
# 53       Ontario - Mixed Deciduous, Borden Forest Site             Cold
# 55   Ontario - Turkey Point 1939 Plantation White Pine             Cold
# 58              ARM Southern Great Plains site- Lamont        Temperate
# 110                              Fontainebleau-Barbeau        Temperate
# 93                                             Gebesee             Cold
# 81                                            Vielsalm             Cold
#
#      record_count           start_time             end_time  \
# 1     33984.00000  2010-02-13 00:00:00  2012-06-13 23:30:00
# 14    42576.00000  2012-07-18 00:00:00  2014-12-31 23:30:00
# 47    52608.00000  2011-01-01 00:00:00  2013-12-31 23:30:00
# 68    55200.00000  2014-10-03 00:00:00  2017-12-31 23:30:00
# 29    56016.00000  2011-06-08 00:00:00  2014-12-17 23:30:00
# 16    83856.00000  2010-01-23 00:00:00  2014-12-31 23:30:00
# 51   110352.00000  2001-01-23 00:00:00  2010-12-31 23:30:00
# 125  111216.00000  2014-07-23 00:00:00  2020-12-31 23:30:00
# 7    115392.00000  2008-01-01 00:00:00  2014-12-31 23:30:00
# 104  117408.00000  2014-03-15 00:00:00  2020-12-31 23:30:00
# 18   134448.00000  2003-01-06 00:00:00  2014-12-18 23:30:00
# 126  141696.00000  2009-01-01 00:00:00  2018-12-01 23:30:00
# 75   154512.00000  2007-01-01 00:00:00  2017-12-31 23:30:00
# 79   167568.00000  2011-01-01 00:00:00  2020-12-31 23:30:00
# 69   171312.00000  2008-03-10 00:00:00  2017-12-31 23:30:00
# 49   186768.00000  2004-05-07 00:00:00  2014-12-31 23:30:00
# 91   187872.00000  2010-01-01 00:00:00  2020-12-31 23:30:00
# 2    188112.00000  2002-01-01 00:00:00  2012-12-31 23:30:00
# 34   218544.00000  1999-01-01 00:00:00  2012-12-31 23:30:00
# 67   223200.00000  2004-01-01 00:00:00  2016-12-31 23:30:00
# 53   238944.00000  1997-12-26 00:00:00  2014-12-31 23:30:00
# 55   255744.00000  2003-04-12 00:00:00  2017-12-31 23:30:00
# 58   259104.00000  2003-01-01 00:00:00  2018-12-31 23:30:00
# 110  262224.00000  2005-03-11 00:00:00  2020-12-31 23:30:00
# 93   346656.00000  2001-01-17 00:00:00  2020-12-31 23:30:00
# 81   413712.00000  1996-08-01 00:00:00  2020-12-31 23:30:00
#
#      recorded_day_percentage
# 1                    0.83099
# 14                   0.98885
# 47                   1.00000
# 68                   0.96965
# 29                   0.90535
# 16                   0.96840
# 51                   0.63333
# 125                  0.98428
# 7                    0.94016
# 104                  0.98470
# 18                   0.64170
# 126                  0.81502
# 75                   0.80114
# 79                   0.95565
# 69                   0.99581
# 49                   1.00000
# 91                   0.97412
# 2                    0.97536
# 34                   0.89030
# 67                   0.97915
# 53                   0.80097
# 55                   0.99070
# 58                   0.92368
# 110                  0.94597
# 93                   0.99081
# 81                   0.96636
# ['AU-DaP', 'AU-Emr', 'AU-Gin', 'AU-How', 'AU-Rig', 'US-GLE', 'US-NR1', 'US-Twt', 'CA-Ca1', 'CA-Gro', 'US-AR1', 'US-Bar', 'US-Mpj', 'US-Ses', 'CH-Fru', 'CH-Oe2', 'DE-Hai', 'DK-Sor', 'FI-Hyy', 'FR-Aur', 'FR-Hes', 'GF-Guy', 'IT-SR2', 'SE-Deg', 'SE-Nor', 'NL-Loo']
#     site_id IGBP       lat       long  \
# 8    AU-Emr  GRA -23.85870  148.47460
# 9    AU-Gin  WSA -31.37640  115.71380
# 56   US-AR1  GRA  36.42670  -99.42000
# 12   AU-Rig  GRA -36.64990  145.57590
# 44   US-Twt  CRO  38.10872 -121.65310
# 6    AU-DaP  GRA -14.06330  131.31810
# 124  SE-Nor  ENF  60.08650   17.47950
# 111  FR-Hes  DBF  48.67410    7.06465
# 119  IT-SR2  ENF  43.73202   10.29091
# 36   US-GLE  ENF  41.36653 -106.23990
# 64   US-Mpj  OSH  34.43840 -106.23770
# 54   CA-Gro   MF  48.21670  -82.15560
# 71   US-Ses  OSH  34.33490 -106.74420
# 10   AU-How  WSA -12.49430  131.15230
# 59   US-Bar  DBF  44.06460  -71.28810
# 50   CA-Ca1  ENF  49.86730 -125.33360
# 84   CH-Fru  GRA  47.11583    8.53778
# 107  FR-Aur  CRO  43.54965    1.10610
# 40   US-NR1  ENF  40.03290 -105.54640
# 113  GF-Guy  EBF   5.27877  -52.92486
# 86   CH-Oe2  CRO  47.28642    7.73375
# 122  SE-Deg  WET  64.18203   19.55654
# 95   DE-Hai  DBF  51.07921   10.45217
# 127  NL-Loo  ENF  52.16658    5.74356
# 105  FI-Hyy  ENF  61.84741   24.29477
# 101  DK-Sor  DBF  55.48587   11.64464
#
#                                              site_name koppen_main_name  \
# 8                                              Emerald             Arid
# 9                                               Gingin        Temperate
# 56             ARM USDA UNL OSU Woodward Switchgrass 1        Temperate
# 12                                         Riggs Creek        Temperate
# 44                                    Twitchell Island        Temperate
# 6                                   Daly River Savanna         Tropical
# 124                                            Norunda             Cold
# 111                                              Hesse        Temperate
# 119                                      San Rossore 2        Temperate
# 36                                               GLEES             Cold
# 64                 Mountainair Pinyon-Juniper Woodland             Arid
# 54   Ontario - Groundhog River, Boreal Mixedwood Fo...             Cold
# ['AU-Stp', 'AU-Whr', 'CA-Oas', 'DE-Lnf', 'ES-Amo', 'FI-Sod', 'IT-CA2', 'US-Ton', 'US-Var', 'US-Whs', 'US-Ho1', 'US-Oho', 'US-Seg', 'CH-Dav', 'CZ-Lnz', 'CZ-wet', 'DE-Gri', 'DE-Tha', 'ES-LM1', 'FR-Bil', 'FR-FBn', 'IT-BCi', 'IT-MBo', 'IT-Ren', 'RU-Fyo']
#     site_id IGBP       lat       long  \
# 15   AU-Whr  EBF -36.67320  145.02940
# 30   IT-CA2  CRO  42.37722   12.02604
# 26   ES-Amo  OSH  36.83361   -2.25232
# 13   AU-Stp  GRA -17.15070  133.35020
# 89   CZ-Lnz  DBF  48.68155   16.94633
# 108  FR-Bil  ENF  44.49365   -0.95609
# 103  ES-LM1  WSA  39.94269   -5.77868
# 48   US-Whs  OSH  31.74380 -110.05220
# 23   DE-Lnf  DBF  51.32822   10.36780
# 65   US-Oho  DBF  41.55450  -83.84380
# 70   US-Seg  GRA  34.36230 -106.70190
# 109  FR-FBn   MF  43.24079    5.67865
# 43   US-Ton  WSA  38.43160 -120.96598
# 27   FI-Sod  ENF  67.36239   26.63859
# 45   US-Var  GRA  38.41330 -120.95070
# 92   CZ-wet  WET  49.02465   14.77035
# 17   CA-Oas  DBF  53.62889 -106.19779
# 115  IT-BCi  CRO  40.52375   14.95744
# 94   DE-Gri  GRA  50.95004   13.51259
# 117  IT-MBo  GRA  46.01468   11.04583
# 62   US-Ho1  ENF  45.20410  -68.74020
# 118  IT-Ren  ENF  46.58686   11.43369
# 121  RU-Fyo  ENF  56.46153   32.92208
# 83   CH-Dav  ENF  46.81533    9.85591
# 100  DE-Tha  ENF  50.96256   13.56515
#
#                                        site_name koppen_main_name  \
# 15                                         Whroo             Arid
# 30                                Castel d'Asso2        Temperate
# 26                                    Amoladeras             Arid
# 13                                  Sturt Plains             Arid
# 89                                       Lanzhot             Cold
# 108                                        Bilos        Temperate
# 103                     Majadas del Tietar North             Arid
# 48                Walnut Gulch Lucky Hills Shrub             Arid
# 23                                    Leinefelde             Cold
# 65                                  Oak Openings             Cold
# 70                           Sevilleta grassland             Arid
# 109                                 Font-Blanche        Temperate
# 43                                   Tonzi Ranch        Temperate
# 27                                     Sodankyla             Cold
# 45                             Vaira Ranch- Ione        Temperate
# 92                             Trebon (CZECHWET)             Cold
# 17   Saskatchewan - Western Boreal, Mature Aspen             Cold
# 115                                 Borgo Cioffi        Temperate
# 94                                   Grillenburg             Cold
# 117                                Monte Bondone             Cold
# 62                   Howland Forest (main tower)             Cold
# 118                                        Renon             Cold
# 121                                Fyodorovskoye             Cold
# 83                                         Davos             Cold
# 100                                     Tharandt             Cold
#
#      record_count           start_time             end_time  \
# 15    54048.00000  2011-12-02 00:00:00  2014-12-31 23:30:00
# 30    55536.00000  2011-07-13 00:00:00  2014-12-17 23:30:00
# 26    78576.00000  2007-07-03 00:00:00  2012-12-31 23:30:00
# 13   100176.00000  2008-08-28 00:00:00  2014-12-31 23:30:00
# 89   102384.00000  2015-01-01 00:00:00  2020-12-31 23:30:00
# 108  111216.00000  2014-07-14 00:00:00  2020-12-31 23:30:00
# 103  119232.00000  2014-03-15 00:00:00  2020-12-31 23:30:00
# 48   131616.00000  2007-06-30 00:00:00  2014-12-31 23:30:00
# 23   132144.00000  2002-04-11 00:00:00  2012-12-31 23:30:00
# 65   163824.00000  2004-01-01 00:00:00  2013-12-31 23:30:00
# 70   183984.00000  2007-01-01 00:00:00  2017-12-31 23:30:00
# 109  220560.00000  2008-01-15 00:00:00  2020-12-31 23:30:00
# 43   230928.00000  2001-05-24 00:00:00  2014-12-31 23:30:00
# 27   232032.00000  2001-01-01 00:00:00  2014-12-31 23:30:00
# 45   245712.00000  2000-11-01 00:00:00  2014-12-31 23:30:00
# 92   255792.00000  2006-04-29 00:00:00  2020-12-31 23:30:00
# 17   256896.00000  1996-04-23 00:00:00  2010-12-31 23:30:00
# 115  258720.00000  2004-05-22 00:00:00  2020-12-31 23:30:00
# 94   283536.00000  2004-01-01 00:00:00  2020-12-31 23:30:00
# 117  298752.00000  2003-01-01 00:00:00  2020-10-15 23:30:00
# 62   324000.00000  1996-01-31 00:00:00  2018-06-30 23:30:00
# 118  325632.00000  1999-01-01 00:00:00  2020-12-31 23:30:00
# 121  361824.00000  1998-07-07 00:00:00  2020-12-31 23:30:00
# 83   415968.00000  1997-01-01 00:00:00  2020-12-31 23:30:00
# 100  420480.00000  1996-06-30 00:00:00  2020-12-10 23:30:00
#
#      recorded_day_percentage
# 15                   1.00000
# 30                   0.92265
# 26                   0.81483
# 13                   0.90073
# 89                   0.97308
# 108                  0.98053
# 103                  1.00000
# 48                   1.00000
# 23                   0.70265
# 65                   0.93430
# 70                   0.95396
# 109                  0.97043
# 43                   0.96801
# 27                   0.94543
# 45                   0.98937
# 92                   0.99403
# 17                   0.99739
# 115                  0.88827
# 94                   0.95121
# 117                  0.95783
# 62                   0.82448
# 118                  0.84420
# 121                  0.91770
# 83                   0.98859
# 100                  0.98096

# %%
for i, k in enumerate(SITE_SPLITS):

  # Plot gold sample and test sites candidates
  plot_df = train_site_metadata_df.loc[train_site_metadata_df['site_id'].isin(k)]
  plot_df = plot_df.sort_values(['record_count','recorded_day_percentage'], ascending=[False, False])
  plot_df['start']= pd.to_datetime(plot_df['start_time']).dt.date
  plot_df['end']= pd.to_datetime(plot_df['end_time']).dt.date
  plot_df['IGBP_id'] = plot_df['IGBP'].replace(train_site_IGBP, [x for x in range(len(train_site_IGBP))])

  fold_plot = go.Scattergeo(lat = plot_df["lat"], lon = plot_df["long"],
                      marker_size=plot_df["record_count"]/7500,
                      marker_color=plot_df["IGBP_id"],
                      marker_line_color=plot_df["IGBP_id"],
                      marker_line_width=2,
                      opacity=0.75,
                      customdata=plot_df[["site_name","site_id",
                                                          "record_count","recorded_day_percentage",
                                                          "start","end",
                                                          "IGBP","koppen_main_name"]])
  
  fig = go.Figure(data=[fold_plot])
  fig.update_layout(
      title={
          'text': f"Fold {i+1} Sites Locations",
          'y':0.93,
          'x':0},
      geo = go.layout.Geo(
          resolution = 50,
          scope = "world",
          showframe = True,
          showcoastlines = True,
          landcolor = "rgb(229, 229, 229)",
          countrycolor = "white" ,
          coastlinecolor = "white"
      )
  )
  fig.update_geos(lataxis_range=[-60,90])
  fig.update_traces(hovertemplate = "<b>%{customdata[0]} (%{customdata[1]})</b>" +
                                    "<br>(%{customdata[6]}, %{customdata[7]})" + 
                                    "<br>Records: %{customdata[2]} (%{customdata[3]}%)" + 
                                    "<br>%{customdata[4]} ~ %{customdata[5]}")
  fig.update_layout(margin={"r":0,"t":0,"l":0,"b":
A","Temperate"],["Font-Blanche","FR-FBn",220560.0,0.97043,"2008-01-15","2020-12-31","MF","Temperate"],["Sevilleta grassland","US-Seg",183984.0,0.95396,"2007-01-01","2017-12-31","GRA","Arid"],["Oak Openings","US-Oho",163824.0,0.9343,"2004-01-01","2013-12-31","DBF","Cold"],["Leinefelde","DE-Lnf",132144.0,0.70265,"2002-04-11","2012-12-31","DBF","Cold"],["Walnut Gulch Lucky Hills Shrub","US-Whs",131616.0,1.0,"2007-06-30","2014-12-31","OSH","Arid"],["Majadas del Tietar North","ES-LM1",119232.0,1.0,"2014-03-15","2020-12-31","WSA","Arid"],["Bilos","FR-Bil",111216.0,0.98053,"2014-07-14","2020-12-31","ENF","Temperate"],["Lanzhot","CZ-Lnz",102384.0,0.97308,"2015-01-01","2020-12-31","DBF","Cold"],["Sturt Plains","AU-Stp",100176.0,0.90073,"2008-08-28","2014-12-31","GRA","Arid"],["Amoladeras","ES-Amo",78576.0,0.81483,"2007-07-03","2012-12-31","OSH","Arid"],["Castel d'Asso2","IT-CA2",55536.0,0.92265,"2011-07-13","2014-12-17","CRO","Temperate"],["Whroo","AU-Whr",54048.0,1.0,"2011-12-02","2014-12-31","EBF","Arid"]],"lat":[50.96256,46.81533,56.46153,46.58686,45.2041,46.01468,50.95004,40.52375,53.62889,49.02465,38.4133,67.36239,38.4316,43.24079,34.3623,41.5545,51.32822,31.7438,39.94269,44.493652,48.68155,-17.1507,36.83361,42.37722,-36.6732],"lon":[13.56515,9.85591,32.92208,11.43369,-68.7402,11.04583,13.51259,14.95744,-106.19779,14.77035,-120.9507,26.63859,-120.96598,5.67865,-106.7019,-83.8438,10.3678,-110.0522,-5.778683,-0.956092,16.946331,133.3502,-2.25232,12.02604,145.0294],"marker":{"color":[1,1,1,1,1,2,2,9,6,7,2,1,5,0,2,6,6,8,5,1,6,2,8,9,4],"line":{"color":[1,1,1,1,1,2,2,9,6,7,2,1,5,0,2,6,6,8,5,1,6,2,8,9,4],"width":2},"size":[56.064,55.4624,48.2432,43.4176,43.2,39.8336,37.8048,34.496,34.2528,34.1056,32.7616,30.9376,30.7904,29.408,24.5312,21.8432,17.6192,17.5488,15.8976,14.8288,13.6512,13.3568,10.4768,7.4048,7.2064]},"opacity":0.75,"type":"scattergeo","hovertemplate":"<b>%{customdata[0]} (%{customdata[1]})</b><br>(%{customdata[6]}, %{customdata[7]})<br>Records: %{customdata[2]} (%{customdata[3]}%)<br>%{customdata[4]} ~ %{customdata[5]}"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.444444444444444 ...

# %%
# Export to HTML
file_name= data_dir + os.sep + "figures" + os.sep + "GoldSites_TrainCandiates_WorldMap.html"
pio.write_html(fig, file = file_name, include_plotlyjs = 'cdn')

# %% [markdown]
# # Select Test Sites

# %%
test_sites = ["US-GLE", # ENF, Cold
              "US-AR1", # GRA, Temperate
              "US-Seg", # GRA, Arid
              "US-FR2", # WSA, Temperate
              "ES-LM2", # WSA, Arid
              "CA-Cbo", # DBF, Cold
              "FR-Lam", # CRO, Temperate
              "IT-Cpz", # EBF, Temperate
              #"CN-Cha", # MF Cold
              "IT-Lsn", # OSH, Temperate
              ]

# %% [markdown]
# ## Plot Gold Sample Sites and Selected Test Sites

# %%
final_test_plot_df = test_plot_df.loc[test_plot_df['site_id'].isin(test_sites)]

colormap = px.colors.qualitative.Plotly
final_test_plot_df['color'] = [ colormap[x] for x in final_test_plot_df["IGBP_id"]]
train_plot_df['color'] = [ colormap[x] for x in train_plot_df["IGBP_id"]]

text_template= "<b>%{customdata[1]}</b>" + \
          "<br>(%{customdata[6]}, %{customdata[7]})"

train_plot = go.Scattergeo(lat = train_plot_df["lat"], lon = train_plot_df["long"],
                     marker_size=train_plot_df["record_count"]/8000,
                     marker_color=train_plot_df["color"],
                     marker_line_color="#3E3E3E",
                     marker_line_width=1,
                     marker_symbol ="arrow",
                     name = "Train",
                     mode = "markers+text",
                     textposition = "bottom center", texttemplate = "TRAIN: " + text_template,
                     textfont=dict(color="#3E3E3E", size=14),
                     customdata=train_plot_df[["site_name","site_id",
                                              "record_count","recorded_day_percentage",
                                              "start","end",
                                              "IGBP","koppen_main_name"]])

test_plot = go.Scattergeo(lat = final_test_plot_df["lat"], lon = final_test_plot_df["long"],
                     marker_size=final_test_plot_df["record_count"]/8000,
                     marker_color=final_test_plot_df["color"],
                     marker_line_color="#20603C",
                     marker_line_width=1,
                     name = "Test",
                     mode = "markers+text",
                     textposition = "top center", texttemplate = "TEST: " + text_template,
                     textfont=dict(color="#20603C", size=14),
                     customdata=final_test_plot_df[["site_name","site_id",
                                                    "record_count","recorded_day_percentage",
                                                    "start","end",
                                                    "IGBP","koppen_main_name"]])

fig = go.Figure(data=[train_plot, test_plot])
fig.update_layout(
    title={
        'text': "Gold Sample (Triaining) Sites and Selected Test Sites",
        'y':1,
        'x':0},
    geo = go.layout.Geo(
        resolution = 110,
        scope = "world",
        projection_type="mercator",
        projection_scale=0.8,
        showframe = True,
        showcoastlines = True,
        landcolor = "rgb(229, 229, 229)",
        showcountries=True, countrycolor = "white" ,
        coastlinecolor = "white"
    )
)
#fig.update_geos(lataxis_range=[-60,90], lonaxis_range=[-120,-60])
fig.update_traces(hovertemplate = "<b>%{customdata[0]} (%{customdata[1]})</b>" +
                                  "<br>(%{customdata[6]}, %{customdata[7]})" + 
                                  "<br>Records: %{customdata[2]} (%{customdata[3]}%)" + 
                                  "<br>%{customdata[4]} ~ %{customdata[5]}")
fig.update_layout(margin={"r":0,"t":50,"l":0,"b":0}, height = 1000, width = 1200)
fig.update_layout(legend=dict(orientation="h", y=0.97, xanchor="left", yanchor="top", itemwidth=50))

fig.show()
# Out:
# <ipython-input-149-f4e4220ba5fa>:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.0.min.js"></script>                <div id="ca77f22e-44c0-4ebd-89c8-b4226a721ed5" class="plotly-graph-div" style="height:1000px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ca77f22e-44c0-4ebd-89c8-b4226a721ed5")) {                    Plotly.newPlot(                        "ca77f22e-44c0-4ebd-89c8-b4226a721ed5",                        [{"customdata":[["Puechabon","FR-Pue",245760.0,0.97117,"2000-07-26","2014-12-31","EBF","Temperate"],["Niwot Ridge Forest (LTER NWT1)","US-NR1",270768.0,0.98567,"1999-05-02","2014-12-31","ENF","Cold"],["Santa Rita Mesquite","US-SRM",190752.0,0.98905,"2004-01-01","2014-12-31","WSA","Arid"],["Tonzi Ranch","US-Ton",230928.0,0.96801,"2001-05-24","2014-12-31","WSA","Temperate"],["Vaira Ranch- Ione","US-Var",245712.0,0.98937,"2000-11-01","2014-12-31","GRA","Temperate"],["Walnut Gulch Kendall Grasslands","US-Wkg",186768.0,1.0,"2004-05-07","2014-12-31","GRA","Arid"],["ARM Southern Great Plains site- Lamont","US-ARM",259104.0,0.92368,"2003-01-01","2018-12-31","CRO","Temperate"],["Metolius mature ponderosa pine","US-Me2",230688.0,0.82238,"2002-01-01","2017-12-31","ENF","Cold"],["Univ. of Mich. Biological Station","US-UMB",191904.0,0.99502,"2007-01-01","2017-12-31","DBF","Cold"],["Valles Caldera Ponderosa Pine","US-Vcp",174528.0,0.90493,"2007-01-01","2017-12-31","ENF","Cold"],["Laegern","CH-Lae",288384.0,0.9854,"2004-04-09","2020-12-17","MF","Cold"],["Llano de los Juanes","ES-LJu",239616.0,0.82322,"2004-05-26","2020-12-31","OSH","Temperate"],["Hyytiala","FI-Hyy",407472.0,0.94712,"1996-06-18","2020-12-31","ENF","Cold"],["Lavarone","IT-Lav",297840.0,0.94373,"2003-01-01","2020-12-31","ENF","Cold"]],"lat":[43.7413,40.0329,31.8214,38.4316,38.4133,31.7365,36.6058,44.4523,45.5598,35.8624,47.47833,36.92659,61.84741,45.9562],"lon":[3.5957,-105.5464,-110.8661,-120.96598,-120.9507,-109.9419,-97.4888,-121.5574,-84.7138,-106.5974,8.36439,-2.75212,24.29477,11.28132],"marker":{"color":["#636EFA","#EF553B","#00CC96","#00CC96","#AB63FA","#AB63FA","#FFA15A","#EF553B","#19D3F3","#EF553B","#FF6692","#B6E880","#EF553B","#EF553B"],"line":{"color":"#3E3E3E","width":1},"size":[30.72,33.846,23.844,28.866,30.714,23.346,32.388,28.836,23.988,21.816,36.048,29.952,50.934,37.23],"symbol":"arrow"},"mode":"markers+text","name":"Train","textfont":{"color":"#3E3E3E","size":14},"textposition":"bottom center","texttemplate":"TRAIN: <b>%{customdata[1]}</b><br>(%{customdata[6]}, %{customdata[7]})","type":"scattergeo","hovertemplate":"<b>%{customdata[0]} (%{customdata[1]})</b><br>(%{customdata[6]}, %{customdata[7]})<br>Records: %{customdata[2]} (%{customdata[3]}%)<br>%{customdata[4]} ~ %{customdata[5]}"},{"customdata":[["Castelporziano","IT-Cpz",132720.0,0.86786,"2000-03-21","2008-12-09","EBF","Temperate"],["GLEES","US-GLE",156672.0,0.92256,"2005-04-25","2014-12-31","ENF","Cold"],["Ontario - Mixed Deciduous, Borden Forest Site","CA-Cbo",238944.0,0.80097,"1997-12-26","2014-12-31","DBF","Cold"],["ARM USDA UNL OSU Woodward Switchgrass 1","US-AR1",58848.0,0.91356,"2009-04-30","2012-12-31","GRA","Temperate"],["Freeman Ranch- Mesquite Juniper","US-FR2",65520.0,0.93429,"2005-01-01","2008-12-31","WSA","Temperate"],["Sevilleta grassland","US-Seg",183984.0,0.95396,"2007-01-01","2017-12-31","GRA","Arid"],["Majadas del Tietar South","ES-LM2",117408.0,0.9847,"2014-03-15","2020-12-31","WSA","Arid"],["Lamasquere","FR-Lam",259296.0,0.93574,"2005-03-13","2020-12-31","CRO","Temperate"],["Lison","IT-Lsn",82656.0,0.94253,"2016-01-01","2020-12-31","OSH","Temperate"]],"lat":[41.70525,41.36653,44.3167,36.4267,29.9495,34.3623,39.934592,43.496437,45.740482],"lon":[12.37611,-106.2399,-79.9333,-99.42,-97.9962,-106.7019,-5.775881,1.237878,12.750297],"marker":{"color":["#636EFA","#EF553B","#19D3F3","#AB63FA","#00CC96","#AB63FA","#00CC96","#FFA15A","#B6E880"],"line":{ ...

# %%
# Export to HTML
file_name= data_dir + os.sep + "figures" + os.sep + "GoldSites_TrainSites_WorldMap.html"
pio.write_html(fig, file = file_name, include_plotlyjs = 'cdn')

# %%
final_test_plot_df
# Out:
#     site_id IGBP      lat       long  \
# 28   CN-Cha   MF 42.40250  128.09580
# 52   IT-Cpz  EBF 41.70525   12.37611
# 66   US-GLE  ENF 41.36653 -106.23990
# 102  CA-Cbo  DBF 44.31670  -79.93330
# 114  US-AR1  GRA 36.42670  -99.42000
# 125  US-FR2  WSA 29.94950  -97.99620
# 139  US-Seg  GRA 34.36230 -106.70190
# 177  ES-LM2  WSA 39.93459   -5.77588
# 189  FR-Lam  CRO 43.49644    1.23788
# 195  IT-Lsn  OSH 45.74048   12.75030
#
#                                          site_name koppen_main_name  \
# 28                                    Changbaishan             Cold
# 52                                  Castelporziano        Temperate
# 66                                           GLEES             Cold
# 102  Ontario - Mixed Deciduous, Borden Forest Site             Cold
# 114        ARM USDA UNL OSU Woodward Switchgrass 1        Temperate
# 125                Freeman Ranch- Mesquite Juniper        Temperate
# 139                            Sevilleta grassland             Arid
# 177                       Majadas del Tietar South             Arid
# 189                                     Lamasquere        Temperate
# 195                                          Lison        Temperate
#
#      record_count           start_time             end_time  \
# 28    43680.00000  2003-01-01 00:00:00  2005-12-04 23:30:00
# 52   132720.00000  2000-03-21 00:00:00  2008-12-09 23:30:00
# 66   156672.00000  2005-04-25 00:00:00  2014-12-31 23:30:00
# 102  238944.00000  1997-12-26 00:00:00  2014-12-31 23:30:00
# 114   58848.00000  2009-04-30 00:00:00  2012-12-31 23:30:00
# 125   65520.00000  2005-01-01 00:00:00  2008-12-31 23:30:00
# 139  183984.00000  2007-01-01 00:00:00  2017-12-31 23:30:00
# 177  117408.00000  2014-03-15 00:00:00  2020-12-31 23:30:00
# 189  259296.00000  2005-03-13 00:00:00  2020-12-31 23:30:00
# 195   82656.00000  2016-01-01 00:00:00  2020-12-31 23:30:00
#
#      recorded_day_percentage       start         end  IGBP_id
# 28                   0.85126  2003-01-01  2005-12-04        6
# 52                   0.86786  2000-03-21  2008-12-09        0
# 66                   0.92256  2005-04-25  2014-12-31        1
# 102                  0.80097  1997-12-26  2014-12-31        5
# 114                  0.91356  2009-04-30  2012-12-31        3
# 125                  0.93429  2005-01-01  2008-12-31        2
# 139                  0.95396  2007-01-01  2017-12-31        3
# 177                  0.98470  2014-03-15  2020-12-31        2
# 189                  0.93574  2005-03-13  2020-12-31        4
# 195                  0.94253  2016-01-01  2020-12-31        7

# %%
#Target test dataset (untrimmed) size: 692044.8
#Target test dataset (untrimmed) size: 346022.4

final_test_plot_df.record_count.sum()
# Out:
# 1339728.0
