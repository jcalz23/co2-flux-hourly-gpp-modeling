# %% [markdown]
# # 0. Preparation

# %%
MY_HOME_ABS_PATH = "/root/co2-flux-hourly-gpp-modeling"

# %% [markdown]
# ## Import libraries

# %%
import os
import sys
import warnings
warnings.filterwarnings("ignore")
import copy
import json
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import pytorch_lightning as pl
from pytorch_lightning.callbacks import EarlyStopping, LearningRateMonitor
from pytorch_lightning.loggers import TensorBoardLogger
import torch
import torch.nn as nn

from pytorch_forecasting import Baseline, TemporalFusionTransformer, TimeSeriesDataSet
from pytorch_forecasting.data import GroupNormalizer
from pytorch_forecasting.metrics import SMAPE, PoissonLoss, QuantileLoss
from pytorch_forecasting.models.temporal_fusion_transformer.tuning import optimize_hyperparameters
from pytorch_forecasting import BaseModel, MAE
from pytorch_forecasting.metrics.point import RMSE
from pytorch_forecasting.data.encoders import NaNLabelEncoder

# Load locale custome modules
os.chdir(MY_HOME_ABS_PATH)
sys.path.append('./.cred')
sys.path.append('./code/src/tools')
sys.path.append('./code/src/tools/CloudIO')

from eval_functions import *
from azure.storage.blob import BlobServiceClient
from CloudIO.AzStorageClient import AzStorageClient
from data_pipeline_lib import *

pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', lambda x: '%.5f' % x)
pl.seed_everything(42)
# Out:
# Global seed set to 42
# 42

# %% [markdown]
# # Load data from Azure blob

# %%
root_dir =  MY_HOME_ABS_PATH
tmp_dir =  root_dir + os.sep + '.tmp'
raw_data_dir = tmp_dir
data_dir = root_dir + os.sep + 'data'
cred_dir = root_dir + os.sep + '.cred'
az_cred_file = cred_dir + os.sep + 'azblobcred.json'

# %%
# AzStorageClient.listBlobs(container)
container = "baseline-data"
cred_file = az_cred_file
ext = "parquet"

# Container and file name
blob_name_train = "baseline-train-v-1-i-knn.parquet"
blob_name_val = "baseline-test-v-1-i-knn.parquet"

# %%
if os.path.exists(cred_file):
  connect_str = ""
  with open(cred_file, "rb") as f:
      data = json.load(f)
      connect_str = data['connectionstr']
      blob_svc_client = BlobServiceClient.from_connection_string(connect_str)
      tokens = connect_str.split(';')
      for t in tokens:
        if "AccountName=" in t:
          AccountName = t[len("AccountName="):]
        elif "AccountKey=" in t:
          AccountKey = t[len("AccountKey="):]

# Download train file
train_df = None
if not (os.path.exists(tmp_dir+blob_name_train)):
    azStorageClient = AzStorageClient(az_cred_file)
    file_stream = azStorageClient.downloadBlob2Stream(container, blob_name_train)
    train_df = pd.read_parquet(file_stream, engine='pyarrow')
    train_df.to_parquet(tmp_dir + blob_name_train)
else:
    train_df = pd.read_parquet(tmp_dir + blob_name_train)


# Load Test Data
test_df = None
if not (os.path.exists(tmp_dir+blob_name_val)):
    azStorageClient = AzStorageClient(az_cred_file)
    file_stream = azStorageClient.downloadBlob2Stream(container, blob_name_val)
    test_df = pd.read_parquet(file_stream, engine='pyarrow')
    test_df.to_parquet(tmp_dir + blob_name_val)
else:
    test_df = pd.read_parquet(tmp_dir + blob_name_val)

print(f"Train size: {train_df.shape}")
print(f"Test size: {test_df.shape}")
# Out:
# Train size: (631032, 49)
# Test size: (234888, 49)

# %% [markdown]
# # Data Preprocessing
# For development, subsetting to a few sites, and ~300 days for each site

# %%
train_sites = ['CH-Lae', 'FR-Pue']
val_sites = ['FI-Hyy', 'ES-LJu']

# Subset train_df to save some time
print(f"Initial Train Sites: {train_df['site_id'].unique()}")
print(f"Initial num train timesteps: {len(train_df)}")
val_df_split1 = train_df.loc[train_df['site_id'].isin(val_sites), ].copy()
train_df = train_df.loc[train_df['site_id'].isin(train_sites), ].copy()
print(f"Trimmed Train Sites: {train_df['site_id'].unique()}")
print(f"Val Sites: {val_df_split1['site_id'].unique()}")
print(f"Test Sites: {test_df['site_id'].unique()}")

# Subset the time series within sites to save more time (300 days)
train_df = train_df.loc[train_df['timestep_idx_local'] < 300, ].copy()
print(f"Subset num train timesteps: {len(train_df)}")
val_df_split1 = val_df_split1.loc[val_df_split1['timestep_idx_local'] < 300, ].copy()
print(f"Subset num val timesteps: {len(val_df_split1)}")
# Out:
# Initial Train Sites: ['CH-Lae' 'ES-LJu' 'FI-Hyy' 'FR-Pue' 'IT-Lav' 'US-ARM' 'US-NR1' 'US-SRM'
#  'US-Ton' 'US-UMB' 'US-Var' 'US-Vcp' 'US-Wkg']
# Initial num train timesteps: 631032
# Trimmed Train Sites: ['CH-Lae' 'FR-Pue']
# Val Sites: ['ES-LJu' 'FI-Hyy']
# Test Sites: ['CA-Cbo' 'ES-LM2' 'FR-Lam' 'US-AR1' 'US-GLE' 'US-Seg']
# Subset num train timesteps: 600
# Subset num val timesteps: 600

# %%
# Convert Dtypes
cat_cols = ["year", "month", "day", "hour", "IGBP", "koppen_main", "koppen_sub"]
for col in cat_cols:
  train_df[col] = train_df[col].astype(str).astype("category")
  val_df_split1[col] = val_df_split1[col].astype(str).astype("category")
  test_df[col] = test_df[col].astype(str).astype("category")

# %% [markdown]
# ## Initialize TS Dataset

# %%
# Define encoder, decoder lengths
max_prediction_length = 1
max_encoder_length = 24*7

# %%
training = TimeSeriesDataSet(
    train_df, 
    time_idx="timestep_idx_global",
    target="GPP_NT_VUT_REF",
    group_ids=["site_id"],
    allow_missing_timesteps=False, 
    min_encoder_length=max_encoder_length,
    max_encoder_length=max_encoder_length,
    min_prediction_length=max_prediction_length,
    max_prediction_length=max_prediction_length,
    static_categoricals=["IGBP","koppen_main","koppen_sub"],
    static_reals=[], #elevation
    time_varying_known_categoricals=["year", "month", "day", "hour"],
    time_varying_known_reals=["timestep_idx_local", 'TA_ERA', 'SW_IN_ERA',
                              'LW_IN_ERA', 'VPD_ERA','P_ERA', 'PA_ERA', 'EVI', 
                              'NDVI', 'NIRv', 'b1', 'b2', 'b3', 'b4', 'b5',
                              'b6', 'b7'],
    time_varying_unknown_categoricals=[], 
    time_varying_unknown_reals=["GPP_NT_VUT_REF", "gap_flag_hour"], # <--- added for masking metrics
    target_normalizer=None,
    categorical_encoders={'IGBP': NaNLabelEncoder(add_nan=True),
                          'koppen_main': NaNLabelEncoder(add_nan=True),
                          'koppen_sub': NaNLabelEncoder(add_nan=True),
                          'year': NaNLabelEncoder(add_nan=True), 
                          'month': NaNLabelEncoder(add_nan=True),
                          'day': NaNLabelEncoder(add_nan=True),
                          },
    add_relative_time_idx=True,
    add_target_scales=False,
    add_encoder_length=False, 
)

# create validation set (predict=True) using the full site sequence for val sites
validation = TimeSeriesDataSet.from_dataset(training, val_df_split1, predict=False, stop_randomization=True)

# create dataloaders for model
batch_size = 1  # set this between 32 to 128
train_dataloader = training.to_dataloader(train=True, batch_size=batch_size, num_workers=0)
val_dataloader = validation.to_dataloader(train=False, batch_size=batch_size, num_workers=0) # <--- removed the batch_size*10

# %% [markdown]
# # Temporal Fusion Transformer

# %%
tft = TemporalFusionTransformer.from_dataset(
    training,
    learning_rate=1e-3,
    hidden_size=16,  # most important hyperparameter apart from learning rate
    attention_head_size=1, #Set to up to 4 for large datasets
    dropout=0.1,  # between 0.1 and 0.3 are good values
    hidden_continuous_size=8,  # set to <= hidden_size
    output_size=7,  # 7 quantiles by default
    loss=QuantileLoss(),
    logging_metrics=nn.ModuleList([MAE(), RMSE()]), #SMAPE(), #MAPE() #<---- added metrics to report in TensorBoard
    reduce_on_plateau_patience=4, # reduce learning rate if no improvement in validation loss after x epochs
    optimizer="adam"
    )
print(f"Number of parameters in network: {tft.size()/1e3:.1f}k")
# Out:
# Number of parameters in network: 43.3k

# %%
# configure network and trainer
early_stop_callback = EarlyStopping(monitor="val_loss", min_delta=1e-4, patience=10, verbose=False, mode="min")
lr_logger = LearningRateMonitor()  # log the learning rate
logger = TensorBoardLogger("lightning_logs")  # logging results to a tensorboard

trainer = pl.Trainer(
    max_epochs=1,
    enable_model_summary=False,
    gradient_clip_val=0.1,
    fast_dev_run=False,  # comment in to check that network or dataset has no serious bugs
    accelerator="gpu",
    gpus=1,
    callbacks=[lr_logger, early_stop_callback],
    logger=logger,
)

trainer.fit(
    tft,
    train_dataloaders=train_dataloader,
    val_dataloaders=val_dataloader,
)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Epoch 0:  18%|█▊        | 94/528 [01:35<07:21,  1.02s/it, loss=3.49, v_num=0, train_loss_step=0.624]
# Epoch 1:  16%|█▌        | 84/528 [00:27<02:26,  3.02it/s, loss=1.28, v_num=1, train_loss_step=0.125, val_loss=0.622, train_loss_epoch=2.080]
# Epoch 0:  50%|█████     | 264/528 [00:37<00:37,  7.01it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/264 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/264 [00:00<?, ?it/s]
# Epoch 0:  50%|█████     | 265/528 [00:37<00:37,  7.02it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  50%|█████     | 266/528 [00:37<00:37,  7.04it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  51%|█████     | 267/528 [00:37<00:36,  7.06it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  51%|█████     | 268/528 [00:37<00:36,  7.09it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  51%|█████     | 269/528 [00:37<00:36,  7.11it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  51%|█████     | 270/528 [00:37<00:36,  7.13it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  51%|█████▏    | 271/528 [00:37<00:35,  7.15it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  52%|█████▏    | 272/528 [00:37<00:35,  7.17it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  52%|█████▏    | 273/528 [00:37<00:35,  7.19it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  52%|█████▏    | 274/528 [00:38<00:35,  7.21it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  52%|█████▏    | 275/528 [00:38<00:34,  7.23it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  52%|█████▏    | 276/528 [00:38<00:34,  7.25it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  52%|█████▏    | 277/528 [00:38<00:34,  7.27it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  53%|█████▎    | 278/528 [00:38<00:34,  7.29it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  53%|█████▎    | 279/528 [00:38<00:34,  7.31it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  53%|█████▎    | 280/528 [00:38<00:33,  7.33it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  53%|█████▎    | 281/528 [00:38<00:33,  7.35it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  53%|█████▎    | 282/528 [00:38<00:33,  7.38it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  54%|█████▎    | 283/528 [00:38<00:33,  7.40it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  54%|█████▍    | 284/528 [00:38<00:32,  7.42it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  54%|█████▍    | 285/528 [00:38<00:32,  7.44it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  54%|█████▍    | 286/528 [00:38<00:32,  7.46it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  54%|█████▍    | 287/528 [00:38<00:32,  7.48it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  55%|█████▍    | 288/528 [00:38<00:32,  7.50it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  55%|█████▍    | 289/528 [00:38<00:31,  7.52it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  55%|█████▍    | 290/528 [00:38<00:31,  7.54it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  55%|█████▌    | 291/528 [00:38<00:31,  7.56it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  55%|█████▌    | 292/528 [00:38<00:31,  7.58it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  55%|█████▌    | 293/528 [00:38<00:30,  7.60it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  56%|█████▌    | 294/528 [00:38<00:30,  7.62it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  56%|█████▌    | 295/528 [00:38<00:30,  7.64it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  56%|█████▌    | 296/528 [00:38<00:30,  7.66it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  56%|█████▋    | 297/528 [00:38<00:30,  7.68it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  56%|█████▋    | 298/528 [00:38<00:29,  7.70it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  57%|█████▋    | 299/528 [00:38<00:29,  7.72it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  57%|█████▋    | 300/528 [00:38<00:29,  7.74it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  57%|█████▋    | 301/528 [00:38<00:29,  7.76it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  57%|█████▋    | 302/528 [00:38<00:29,  7.78it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  57%|█████▋    | 303/528 [00:38<00:28,  7.80it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  58%|█████▊    | 304/528 [00:38<00:28,  7.82it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  58%|█████▊    | 305/528 [00:38<00:28,  7.84it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  58%|█████▊    | 306/528 [00:38<00:28,  7.86it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  58%|█████▊    | 307/528 [00:38<00:28,  7.88it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  58%|█████▊    | 308/528 [00:38<00:27,  7.90it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  59%|█████▊    | 309/528 [00:39<00:27,  7.92it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  59%|█████▊    | 310/528 [00:39<00:27,  7.94it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  59%|█████▉    | 311/528 [00:39<00:27,  7.96it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  59%|█████▉    | 312/528 [00:39<00:27,  7.98it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  59%|█████▉    | 313/528 [00:39<00:26,  8.00it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  59%|█████▉    | 314/528 [00:39<00:26,  8.02it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  60%|█████▉    | 315/528 [00:39<00:26,  8.04it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  60%|█████▉    | 316/528 [00:39<00:26,  8.06it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  60%|██████    | 317/528 [00:39<00:26,  8.08it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  60%|██████    | 318/528 [00:39<00:25,  8.09it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  60%|██████    | 319/528 [00:39<00:25,  8.11it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  61%|██████    | 320/528 [00:39<00:25,  8.13it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  61%|██████    | 321/528 [00:39<00:25,  8.15it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  61%|██████    | 322/528 [00:39<00:25,  8.17it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  61%|██████    | 323/528 [00:39<00:25,  8.19it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  61%|██████▏   | 324/528 [00:39<00:24,  8.21it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  62%|██████▏   | 325/528 [00:39<00:24,  8.23it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  62%|██████▏   | 326/528 [00:39<00:24,  8.25it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  62%|██████▏   | 327/528 [00:39<00:24,  8.27it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  62%|██████▏   | 328/528 [00:39<00:24,  8.29it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  62%|██████▏   | 329/528 [00:39<00:23,  8.30it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  62%|██████▎   | 330/528 [00:39<00:23,  8.32it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  63%|██████▎   | 331/528 [00:39<00:23,  8.34it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  63%|██████▎   | 332/528 [00:39<00:23,  8.36it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  63%|██████▎   | 333/528 [00:39<00:23,  8.38it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  63%|██████▎   | 334/528 [00:39<00:23,  8.40it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  63%|██████▎   | 335/528 [00:39<00:22,  8.42it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  64%|██████▎   | 336/528 [00:39<00:22,  8.44it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  64%|██████▍   | 337/528 [00:39<00:22,  8.45it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  64%|██████▍   | 338/528 [00:39<00:22,  8.47it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  64%|██████▍   | 339/528 [00:39<00:22,  8.49it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  64%|██████▍   | 340/528 [00:39<00:22,  8.51it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  65%|██████▍   | 341/528 [00:39<00:21,  8.53it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  65%|██████▍   | 342/528 [00:40<00:21,  8.55it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  65%|██████▍   | 343/528 [00:40<00:21,  8.57it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  65%|██████▌   | 344/528 [00:40<00:21,  8.58it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  65%|██████▌   | 345/528 [00:40<00:21,  8.60it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  66%|██████▌   | 346/528 [00:40<00:21,  8.62it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  66%|██████▌   | 347/528 [00:40<00:20,  8.64it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  66%|██████▌   | 348/528 [00:40<00:20,  8.66it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  66%|██████▌   | 349/528 [00:40<00:20,  8.68it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  66%|██████▋   | 350/528 [00:40<00:20,  8.70it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  66%|██████▋   | 351/528 [00:40<00:20,  8.71it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  67%|██████▋   | 352/528 [00:40<00:20,  8.73it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  67%|██████▋   | 353/528 [00:40<00:20,  8.75it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  67%|██████▋   | 354/528 [00:40<00:19,  8.77it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  67%|██████▋   | 355/528 [00:40<00:19,  8.78it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  67%|██████▋   | 356/528 [00:40<00:19,  8.80it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  68%|██████▊   | 357/528 [00:40<00:19,  8.82it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  68%|██████▊   | 358/528 [00:40<00:19,  8.84it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  68%|██████▊   | 359/528 [00:40<00:19,  8.86it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  68%|██████▊   | 360/528 [00:40<00:18,  8.87it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  68%|██████▊   | 361/528 [00:40<00:18,  8.89it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  69%|██████▊   | 362/528 [00:40<00:18,  8.91it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  69%|██████▉   | 363/528 [00:40<00:18,  8.93it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  69%|██████▉   | 364/528 [00:40<00:18,  8.94it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  69%|██████▉   | 365/528 [00:40<00:18,  8.96it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  69%|██████▉   | 366/528 [00:40<00:18,  8.98it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  70%|██████▉   | 367/528 [00:40<00:17,  9.00it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  70%|██████▉   | 368/528 [00:40<00:17,  9.02it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  70%|██████▉   | 369/528 [00:40<00:17,  9.03it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  70%|███████   | 370/528 [00:40<00:17,  9.05it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  70%|███████   | 371/528 [00:40<00:17,  9.07it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  70%|███████   | 372/528 [00:40<00:17,  9.09it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  71%|███████   | 373/528 [00:40<00:17,  9.11it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  71%|███████   | 374/528 [00:40<00:16,  9.12it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  71%|███████   | 375/528 [00:41<00:16,  9.14it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  71%|███████   | 376/528 [00:41<00:16,  9.16it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  71%|███████▏  | 377/528 [00:41<00:16,  9.18it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  72%|███████▏  | 378/528 [00:41<00:16,  9.20it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  72%|███████▏  | 379/528 [00:41<00:16,  9.21it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  72%|███████▏  | 380/528 [00:41<00:16,  9.23it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  72%|███████▏  | 381/528 [00:41<00:15,  9.25it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  72%|███████▏  | 382/528 [00:41<00:15,  9.27it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  73%|███████▎  | 383/528 [00:41<00:15,  9.29it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  73%|███████▎  | 384/528 [00:41<00:15,  9.30it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  73%|███████▎  | 385/528 [00:41<00:15,  9.32it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  73%|███████▎  | 386/528 [00:41<00:15,  9.34it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  73%|███████▎  | 387/528 [00:41<00:15,  9.36it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  73%|███████▎  | 388/528 [00:41<00:14,  9.38it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  74%|███████▎  | 389/528 [00:41<00:14,  9.39it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  74%|███████▍  | 390/528 [00:41<00:14,  9.41it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  74%|███████▍  | 391/528 [00:41<00:14,  9.43it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  74%|███████▍  | 392/528 [00:41<00:14,  9.45it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  74%|███████▍  | 393/528 [00:41<00:14,  9.46it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  75%|███████▍  | 394/528 [00:41<00:14,  9.48it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  75%|███████▍  | 395/528 [00:41<00:14,  9.50it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  75%|███████▌  | 396/528 [00:41<00:13,  9.51it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  75%|███████▌  | 397/528 [00:41<00:13,  9.53it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  75%|███████▌  | 398/528 [00:41<00:13,  9.55it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  76%|███████▌  | 399/528 [00:41<00:13,  9.57it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  76%|███████▌  | 400/528 [00:41<00:13,  9.58it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  76%|███████▌  | 401/528 [00:41<00:13,  9.60it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  76%|███████▌  | 402/528 [00:41<00:13,  9.62it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  76%|███████▋  | 403/528 [00:41<00:12,  9.63it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  77%|███████▋  | 404/528 [00:41<00:12,  9.65it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  77%|███████▋  | 405/528 [00:41<00:12,  9.67it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  77%|███████▋  | 406/528 [00:41<00:12,  9.68it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  77%|███████▋  | 407/528 [00:41<00:12,  9.70it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  77%|███████▋  | 408/528 [00:41<00:12,  9.72it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  77%|███████▋  | 409/528 [00:42<00:12,  9.73it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  78%|███████▊  | 410/528 [00:42<00:12,  9.75it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  78%|███████▊  | 411/528 [00:42<00:11,  9.77it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  78%|███████▊  | 412/528 [00:42<00:11,  9.78it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  78%|███████▊  | 413/528 [00:42<00:11,  9.80it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  78%|███████▊  | 414/528 [00:42<00:11,  9.82it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  79%|███████▊  | 415/528 [00:42<00:11,  9.83it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  79%|███████▉  | 416/528 [00:42<00:11,  9.85it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  79%|███████▉  | 417/528 [00:42<00:11,  9.87it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  79%|███████▉  | 418/528 [00:42<00:11,  9.88it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  79%|███████▉  | 419/528 [00:42<00:11,  9.90it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  80%|███████▉  | 420/528 [00:42<00:10,  9.92it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  80%|███████▉  | 421/528 [00:42<00:10,  9.93it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  80%|███████▉  | 422/528 [00:42<00:10,  9.95it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  80%|████████  | 423/528 [00:42<00:10,  9.97it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  80%|████████  | 424/528 [00:42<00:10,  9.98it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  80%|████████  | 425/528 [00:42<00:10, 10.00it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  81%|████████  | 426/528 [00:42<00:10, 10.02it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  81%|████████  | 427/528 [00:42<00:10, 10.03it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  81%|████████  | 428/528 [00:42<00:09, 10.05it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  81%|████████▏ | 429/528 [00:42<00:09, 10.06it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  81%|████████▏ | 430/528 [00:42<00:09, 10.08it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  82%|████████▏ | 431/528 [00:42<00:09, 10.10it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  82%|████████▏ | 432/528 [00:42<00:09, 10.11it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  82%|████████▏ | 433/528 [00:42<00:09, 10.13it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  82%|████████▏ | 434/528 [00:42<00:09, 10.14it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  82%|████████▏ | 435/528 [00:42<00:09, 10.16it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  83%|████████▎ | 436/528 [00:42<00:09, 10.18it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  83%|████████▎ | 437/528 [00:42<00:08, 10.19it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  83%|████████▎ | 438/528 [00:42<00:08, 10.21it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  83%|████████▎ | 439/528 [00:42<00:08, 10.22it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  83%|████████▎ | 440/528 [00:42<00:08, 10.24it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  84%|████████▎ | 441/528 [00:43<00:08, 10.26it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  84%|████████▎ | 442/528 [00:43<00:08, 10.27it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  84%|████████▍ | 443/528 [00:43<00:08, 10.29it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  84%|████████▍ | 444/528 [00:43<00:08, 10.30it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  84%|████████▍ | 445/528 [00:43<00:08, 10.32it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  84%|████████▍ | 446/528 [00:43<00:07, 10.33it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  85%|████████▍ | 447/528 [00:43<00:07, 10.35it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  85%|████████▍ | 448/528 [00:43<00:07, 10.36it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  85%|████████▌ | 449/528 [00:43<00:07, 10.38it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  85%|████████▌ | 450/528 [00:43<00:07, 10.40it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  85%|████████▌ | 451/528 [00:43<00:07, 10.41it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  86%|████████▌ | 452/528 [00:43<00:07, 10.43it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  86%|████████▌ | 453/528 [00:43<00:07, 10.44it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  86%|████████▌ | 454/528 [00:43<00:07, 10.46it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  86%|████████▌ | 455/528 [00:43<00:06, 10.47it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  86%|████████▋ | 456/528 [00:43<00:06, 10.49it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  87%|████████▋ | 457/528 [00:43<00:06, 10.51it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  87%|████████▋ | 458/528 [00:43<00:06, 10.52it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  87%|████████▋ | 459/528 [00:43<00:06, 10.54it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  87%|████████▋ | 460/528 [00:43<00:06, 10.55it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  87%|████████▋ | 461/528 [00:43<00:06, 10.57it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  88%|████████▊ | 462/528 [00:43<00:06, 10.58it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  88%|████████▊ | 463/528 [00:43<00:06, 10.60it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  88%|████████▊ | 464/528 [00:43<00:06, 10.61it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  88%|████████▊ | 465/528 [00:43<00:05, 10.63it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  88%|████████▊ | 466/528 [00:43<00:05, 10.65it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  88%|████████▊ | 467/528 [00:43<00:05, 10.66it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  89%|████████▊ | 468/528 [00:43<00:05, 10.68it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  89%|████████▉ | 469/528 [00:43<00:05, 10.69it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  89%|████████▉ | 470/528 [00:43<00:05, 10.71it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  89%|████████▉ | 471/528 [00:43<00:05, 10.72it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  89%|████████▉ | 472/528 [00:43<00:05, 10.74it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  90%|████████▉ | 473/528 [00:43<00:05, 10.75it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  90%|████████▉ | 474/528 [00:44<00:05, 10.77it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  90%|████████▉ | 475/528 [00:44<00:04, 10.79it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  90%|█████████ | 476/528 [00:44<00:04, 10.80it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  90%|█████████ | 477/528 [00:44<00:04, 10.82it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  91%|█████████ | 478/528 [00:44<00:04, 10.83it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  91%|█████████ | 479/528 [00:44<00:04, 10.85it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  91%|█████████ | 480/528 [00:44<00:04, 10.86it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  91%|█████████ | 481/528 [00:44<00:04, 10.88it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  91%|█████████▏| 482/528 [00:44<00:04, 10.89it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  91%|█████████▏| 483/528 [00:44<00:04, 10.91it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  92%|█████████▏| 484/528 [00:44<00:04, 10.93it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  92%|█████████▏| 485/528 [00:44<00:03, 10.94it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  92%|█████████▏| 486/528 [00:44<00:03, 10.96it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  92%|█████████▏| 487/528 [00:44<00:03, 10.97it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  92%|█████████▏| 488/528 [00:44<00:03, 10.99it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  93%|█████████▎| 489/528 [00:44<00:03, 11.00it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  93%|█████████▎| 490/528 [00:44<00:03, 11.02it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  93%|█████████▎| 491/528 [00:44<00:03, 11.03it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  93%|█████████▎| 492/528 [00:44<00:03, 11.05it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  93%|█████████▎| 493/528 [00:44<00:03, 11.06it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  94%|█████████▎| 494/528 [00:44<00:03, 11.08it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  94%|█████████▍| 495/528 [00:44<00:02, 11.10it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  94%|█████████▍| 496/528 [00:44<00:02, 11.11it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  94%|█████████▍| 497/528 [00:44<00:02, 11.13it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  94%|█████████▍| 498/528 [00:44<00:02, 11.14it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  95%|█████████▍| 499/528 [00:44<00:02, 11.16it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  95%|█████████▍| 500/528 [00:44<00:02, 11.17it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  95%|█████████▍| 501/528 [00:44<00:02, 11.19it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  95%|█████████▌| 502/528 [00:44<00:02, 11.20it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  95%|█████████▌| 503/528 [00:44<00:02, 11.22it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  95%|█████████▌| 504/528 [00:44<00:02, 11.23it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  96%|█████████▌| 505/528 [00:44<00:02, 11.25it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  96%|█████████▌| 506/528 [00:44<00:01, 11.26it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  96%|█████████▌| 507/528 [00:44<00:01, 11.28it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  96%|█████████▌| 508/528 [00:44<00:01, 11.29it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  96%|█████████▋| 509/528 [00:45<00:01, 11.31it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  97%|█████████▋| 510/528 [00:45<00:01, 11.32it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  97%|█████████▋| 511/528 [00:45<00:01, 11.34it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  97%|█████████▋| 512/528 [00:45<00:01, 11.35it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  97%|█████████▋| 513/528 [00:45<00:01, 11.37it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  97%|█████████▋| 514/528 [00:45<00:01, 11.38it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  98%|█████████▊| 515/528 [00:45<00:01, 11.40it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  98%|█████████▊| 516/528 [00:45<00:01, 11.41it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  98%|█████████▊| 517/528 [00:45<00:00, 11.42it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  98%|█████████▊| 518/528 [00:45<00:00, 11.44it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  98%|█████████▊| 519/528 [00:45<00:00, 11.45it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  98%|█████████▊| 520/528 [00:45<00:00, 11.47it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  99%|█████████▊| 521/528 [00:45<00:00, 11.48it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  99%|█████████▉| 522/528 [00:45<00:00, 11.50it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  99%|█████████▉| 523/528 [00:45<00:00, 11.51it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  99%|█████████▉| 524/528 [00:45<00:00, 11.53it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0:  99%|█████████▉| 525/528 [00:45<00:00, 11.54it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0: 100%|█████████▉| 526/528 [00:45<00:00, 11.56it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0: 100%|█████████▉| 527/528 [00:45<00:00, 11.57it/s, loss=1.57, v_num=2, train_loss_step=0.404]
# Epoch 0: 100%|██████████| 528/528 [00:45<00:00, 11.59it/s, loss=1.57, v_num=2, train_loss_step=0.404, val_loss=0.497]
# Epoch 0: 100%|██████████| 528/528 [00:45<00:00, 11.58it/s, loss=1.57, v_num=2, train_loss_step=0.404, val_loss=0.497, train_loss_epoch=1.930]
# `Trainer.fit` stopped: `max_epochs=1` reached.
# Epoch 0: 100%|██████████| 528/528 [00:45<00:00, 11.54it/s, loss=1.57, v_num=2, train_loss_step=0.404, val_loss=0.497, train_loss_epoch=1.930]

# %% [markdown]
# # Evaluate performance + CHECK NEW FUNCTIONS

# %%
# Run
masked_rmse, masked_mae, masked_nse, masked_r2 = masked_eval_metrics(val_dataloader, tft)
print(f"masked_rmse: {masked_rmse}")
print(f"masked_mae: {masked_mae}")
print(f"masked_nse: {masked_nse}")
print(f"masked_r2: {masked_r2}")
# Out:
# masked_rmse: 0.6350937485694885
# masked_mae: 0.45401236414909363
# masked_nse: -8.897841996772776
# masked_r2: -1.0731758742542987

# %%
## CHECK NEW FUNCTION MANUALLY
# Subset val df to the timesteps that get preds
val_results = pd.DataFrame()
for site in ['ES-LJu', 'FI-Hyy']:
    site_df = val_df_split1.loc[val_df_split1['site_id']==site, ].copy()
    site_df_results = site_df.iloc[-132:, ].copy()
    val_results = pd.concat([val_results, site_df_results], axis=0)

# Append preds to df row
y_pred = tft.predict(val_dataloader).reshape(-1)
val_results['prediction'] = y_pred
val_results['mask'] = np.abs(val_results['gap_flag_hour'] - 1)

# Make timestep-level calcs
masked_val_results = val_results.loc[val_results['mask']==1, ].copy()
masked_val_results['ae'] = np.abs(val_results['GPP_NT_VUT_REF'] - val_results['prediction'])

# Get aggregate metric
check_mae = masked_val_results['ae'].mean()
print(f"Check Mask MAE: {check_mae}")
print(f"Function Mask MAE: {masked_mae}")
# Out:
# Check Mask MAE: 0.4540123451107527
# Function Mask MAE: 0.45401236414909363

# %%
## COMPARE TO UNMASKED
# calcualte mean absolute error on validation set
actuals = torch.cat([y[0] for x, y in iter(val_dataloader)])
predictions = tft.predict(val_dataloader)
mae = (actuals - predictions).abs().mean()
print(f"Val MAE: {mae}")

# Derive Val RMSE
criterion = nn.MSELoss()
rmse = torch.sqrt(criterion(actuals, predictions))
print(f"Val RMSE: {rmse}")

# NSE metric
nse = he.nse(actuals.reshape(-1).numpy(), predictions.reshape(-1).numpy())
print(f"NSE: {nse}")

# R-Squared
r2 = r2_score(actuals.reshape(-1).numpy(), predictions.reshape(-1).numpy())
print(f"R2: {r2}")
# Out:
# Val MAE: 0.8530687093734741
# Val RMSE: 1.3808634281158447
# NSE: -29.040090860943412
# R2: 0.18292750869969865
