# %% [markdown]
# # 0. Preparation

# %% [markdown]
# ## (Optoinal) mount google drive
# - Make sure that available access is the user's own drive(no access across files in shared folder)

# %%
if 'google.colab' in str(get_ipython()):
    IN_COLLAB = True
else:
    IN_COLLAB = False

if IN_COLLAB:
    #TODO: CHANGE THIS BASED ON YOUR OWN LOCAL SETTINGS
    MY_HOME_ABS_PATH = "/content/drive/MyDrive/W210/co2-flux-hourly-gpp-modeling"
    from google.colab import drive
    drive.mount('/content/drive/')
else:
    MY_HOME_ABS_PATH = "/root/co2-flux-hourly-gpp-modeling/"

# %% [markdown]
# ## Import libraries

# %%
import os
import sys
import warnings
warnings.filterwarnings("ignore")
import copy
import json
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import pytorch_lightning as pl
import torch
import torch.nn as nn

from pytorch_forecasting import Baseline, TemporalFusionTransformer, TimeSeriesDataSet
from pytorch_forecasting.data import GroupNormalizer
from pytorch_forecasting.metrics import SMAPE, PoissonLoss, QuantileLoss
from pytorch_forecasting.models.temporal_fusion_transformer.tuning import optimize_hyperparameters
from pytorch_forecasting import BaseModel, MAE
from pytorch_forecasting.metrics.point import RMSE
from pytorch_forecasting.data.encoders import NaNLabelEncoder

from sklearn.metrics import r2_score
from timeit import default_timer
from datetime import datetime
import gc
import pickle

# Load locale custome modules
os.chdir(MY_HOME_ABS_PATH)
if IN_COLLAB:
     sys.path.insert(0,os.path.abspath("./code/src/tools"))
else:
    sys.path.append('./.cred')
    sys.path.append('./code/src/tools')
    sys.path.append(os.path.abspath("./code/src/tools"))

from CloudIO.AzStorageClient import AzStorageClient
from data_pipeline_lib import *
from model_pipeline_lib import *

pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', lambda x: '%.5f' % x)
pl.seed_everything(42)
# Out:
# 2023-03-30 01:55:43.247819: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-03-30 01:55:43.295197: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-03-30 01:55:43.296262: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-30 01:55:44.061693: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Global seed set to 42
# Global seed set to 42
# 42

# %% [markdown]
# # Load data from Azure blob

# %%
root_dir =  MY_HOME_ABS_PATH
tmp_dir =  root_dir + os.sep + '.tmp'
model_dir = root_dir + os.sep + 'data' + os.sep + 'models'
cred_dir = root_dir + os.sep + '.cred'
az_cred_file = cred_dir + os.sep + 'azblobcred.json'

container = "all-sites-data"
blob_name = "full_2010_2015_v_mvp_raw.parquet"
local_file = tmp_dir + os.sep + blob_name

# %%
# Download full data
root_dir  = MY_HOME_ABS_PATH
tmp_dir   = root_dir + os.sep + '.tmp'
model_dir = root_dir + os.sep + 'data' + os.sep + 'models'

container = "all-sites-data"
blob_name = "full_2010_2015_v_mvp_raw.parquet"
local_file = tmp_dir + os.sep + blob_name

data_df = get_raw_datasets(container, blob_name)
# Out:
# Data size: (4862712, 51)
# Data Columns: Index(['GPP_NT_VUT_REF', 'site_id', 'timestep_idx_local',
#        'timestep_idx_global', 'datetime', 'date', 'year', 'month', 'day',
#        'hour', 'TA_ERA', 'SW_IN_ERA', 'LW_IN_ERA', 'VPD_ERA', 'P_ERA',
#        'PA_ERA', 'EVI', 'NDVI', 'NIRv', 'b1', 'b2', 'b3', 'b4', 'b5', 'b6',
#        'b7', 'IGBP', 'lat', 'long', 'koppen_sub', 'koppen_main', 'c3c4',
#        'c4_percent', 'BESS-PAR', 'BESS-PARdiff', 'BESS-RSDN', 'CSIF-SIFdaily',
#        'PET', 'Ts', 'ESACCI-sm', 'MODIS_LC', 'NDWI', 'Percent_Snow', 'Fpar',
#        'Lai', 'LST_Day', 'LST_Night', 'MODIS_IGBP', 'MODIS_PFT',
#        'gap_flag_hour', 'gap_flag_month'],
#       dtype='object')
# NA count: 0

# %% [markdown]
# # Eval Model

# %%
exp_model_dir = "/root/co2-flux-hourly-gpp-modeling/data/models/tft_model_5YrTrain_3DEncode_SmallNetwork_SlimFeatures_NoGPP_230327_0111" # TODO: Replace to your model dir
best_model_path = "/root/co2-flux-hourly-gpp-modeling/data/models/tft_model_5YrTrain_3DEncode_SmallNetwork_SlimFeatures_NoGPP_230327_0111/lightning_logs/version_0/checkpoints/epoch=7-step=20104.ckpt"
best_tft = TemporalFusionTransformer.load_from_checkpoint(best_model_path)
print(f"Quantiles: {best_tft.loss.quantiles}") # [0.02, 0.1, 0.25, 0.5, 0.75, 0.9, 0.98]

# Experiment constants
VAL_INDEX  = 3
TEST_INDEX = 4
SUBSET_LEN = 24*365*5 # 1 year
ENCODER_LEN = 24*3   # 3 days
print(f"Training timestemp length = {SUBSET_LEN}.")

# create dataloaders for model
# ref: https://pytorch-lightning.readthedocs.io/en/stable/guides/speed.html#dataloaders
batch_size = 128  # set this between 32 to 128
cpu_count = os.cpu_count()
# Out:
# Quantiles: [0.02, 0.1, 0.25, 0.5, 0.75, 0.9, 0.98]
# Training timestemp length = 43800.

# %%
def setup_tsdataset_nogpp(train_df, val_df, test_df, min_encoder_len):
    # create training and validation TS dataset 
    training = TimeSeriesDataSet(
      train_df, # <------ no longer subsetting, option 1 split can use entire train site sequence
      time_idx="timestep_idx_global",
      target="GPP_NT_VUT_REF",
      group_ids=["site_id"],
      allow_missing_timesteps=False, # <---- turned on bc some rows are removed.
      min_encoder_length=min_encoder_len,
      max_encoder_length=min_encoder_len,
      min_prediction_length=1,
      max_prediction_length=1,
      static_categoricals=["koppen_main"],
      static_reals=[],
      time_varying_known_categoricals=["month", "hour"],
      time_varying_known_reals=['TA_ERA', 'SW_IN_ERA', 'LW_IN_ERA', 'VPD_ERA', 'P_ERA', 'PA_ERA',
                                'EVI', 'NDVI', 'NIRv', 'b1', 'b2', 'b3', 'b4', 'b5', 'b6', 'b7'],
      time_varying_unknown_categoricals=[], 
      time_varying_unknown_reals=[],
      target_normalizer=None,
      categorical_encoders={'koppen_main': NaNLabelEncoder(add_nan=True),
                            },
      add_relative_time_idx=True,
      add_target_scales=False, # <------- turned off
      add_encoder_length=False, # <------- turned off
    )

    validation = TimeSeriesDataSet.from_dataset(training, val_df, predict=False, stop_randomization=True)
    
    if test_df is not None:
        testing = TimeSeriesDataSet.from_dataset(training, test_df, predict=False, stop_randomization=True)
    else:
        testing = None

    return (training, validation, testing)

# %%
# Setup dataset
train_df, val_df, _ = get_splited_datasets(data_df, VAL_INDEX, TEST_INDEX)
train_df, val_df, _ = subset_data(train_df, val_df, None, SUBSET_LEN)
_, validation, _ = setup_tsdataset_nogpp(train_df, val_df, None, ENCODER_LEN)
# Out:
# Subest length: 43800 timesteps for each sites
# Subset num train timesteps: 2579424
# Subset num val timesteps: 952752

# %% [markdown]
# ## Default Evaluation (1 year of validation data)

# %%
# Eval on Validation set
val_dataloader = validation.to_dataloader(train=False, batch_size=batch_size, num_workers=cpu_count)

# Print Model Eval on Validation Set
start = default_timer()
print(f"Start eval on validation.")
val_actuals = torch.cat([y[0] for x, y in iter(val_dataloader)])
val_q_predictions = best_tft.predict(val_dataloader, mode="quantiles", show_progress_bar=True, return_x=False)
eval_time = default_timer() - start
print(f"Val eval time: {eval_time}")

# save eval results - also we can resume eval at a later point in time
with open(exp_model_dir + os.sep + "val_actuals.pkl", "wb") as fout:
    pickle.dump(val_actuals, fout)

with open(exp_model_dir + os.sep + "val_q_predictions.pkl", "wb") as fout:
    pickle.dump(val_q_predictions, fout)

# %%
# load eval results - also we can resume eval at a later point in time
# with open(exp_model_dir + os.sep + "val_actuals.pkl", "rb") as fin:
#     val_acutals = pickle.load(fin)

# with open(exp_model_dir + os.sep + "val_q_predictions.pkl", "rb") as fin:
#     val_q_predictions = pickle.load(fin)

# Eval on Validation set
val_dataloader = validation.to_dataloader(train=False, batch_size=batch_size, num_workers=cpu_count)

val_predictions = val_q_predictions[:, :, 3] # p50 == estimation
val_p90 = val_q_predictions[:, :,5] # p90 == estimation
#del val_q_predictions

# Unmasked evaltaion
eval_metric = get_eval_metrics(val_actuals, val_predictions, None, val_p90)
print(f"Unmasked Val eval evaluation: {eval_metric}")

# Masked evlationa
start = default_timer()
mask = torch.logical_not(torch.cat([x['decoder_cat'][:, :, -1].reshape(-1) for x, y in iter(val_dataloader)]))
masked_eval_metric = get_eval_metrics(val_actuals, val_predictions, mask, val_p90)
eval_time = default_timer() - start
print(f"Masked Val eval time: {eval_time}")
print(f"Masked Val eval evaluation: {masked_eval_metric}")
# Out:
# Unmasked Val eval evaluation: {'rmse': 3.6963117122650146, 'mae': 2.034262180328369, 'nse': 0.7267818450927734, 'r2': 0.7267818118600462, 'p50_loss': 0.5044232606887817, 'p90_loss': 0.28162509202957153}
# Masked Val eval time: 51.08380620800017
# Masked Val eval evaluation: {'rmse': 1.5254271030426025, 'mae': 0.8380093574523926, 'nse': 0.17887413501739502, 'r2': 0.1788742221373929, 'p50_loss': 0.9253355860710144, 'p90_loss': 0.5865048766136169}

# %% [markdown]
# ## Eval 5 Years of Validation Data

# %%
# split data
train_df, val_df, _ = get_splited_datasets(data_df, VAL_INDEX, TEST_INDEX)
train_df, _, _ = subset_data(train_df, val_df, None, SUBSET_LEN)
_, validation, _ = setup_tsdataset_nogpp(train_df, val_df, None, ENCODER_LEN)
print(f"validation timesteps: {len(val_df)}")

del train_df
gc.collect()

# Eval on Validation set
val_dataloader = validation.to_dataloader(train=False, batch_size=128, num_workers=os.cpu_count())

start = default_timer()
val_actuals = torch.cat([y[0] for x, y in iter(val_dataloader)])
val_q_predictions = best_tft.predict(val_dataloader, mode="quantiles", show_progress_bar=True)
print(f"Val eval time: {default_timer() - start}")

# save eval results - also we can resume tuning at a later point in time
with open(exp_model_dir + os.sep + "val5yr_actuals.pkl", "wb") as fout:
    pickle.dump(val_actuals, fout)

with open(exp_model_dir + os.sep + "val5yr_q_predictions.pkl", "wb") as fout:
    pickle.dump(val_q_predictions, fout)
# Out:
# Subest length: 43800 timesteps for each sites
# Subset num train timesteps: 2579424
# Subset num val timesteps: 952752
# validation timesteps: 1056072
# Predict:   0%|          | 0/8236 [00:00<?, ? batches/s]
# Predict:   0%|          | 1/8236 [00:01<2:34:34,  1.13s/ batches]
# Predict:   0%|          | 3/8236 [00:01<48:08,  2.85 batches/s]
# Predict:   0%|          | 5/8236 [00:01<29:18,  4.68 batches/s]
# Predict:   0%|          | 7/8236 [00:01<22:11,  6.18 batches/s]
# Predict:   0%|          | 9/8236 [00:01<18:40,  7.34 batches/s]
# Predict:   0%|          | 11/8236 [00:01<16:06,  8.51 batches/s]
# Predict:   0%|          | 13/8236 [00:02<14:50,  9.23 batches/s]
# Predict:   0%|          | 15/8236 [00:02<13:39, 10.03 batches/s]
# Predict:   0%|          | 17/8236 [00:02<13:10, 10.39 batches/s]
# Predict:   0%|          | 19/8236 [00:02<12:24, 11.04 batches/s]
# Predict:   0%|          | 21/8236 [00:02<11:56, 11.46 batches/s]
# Predict:   0%|          | 23/8236 [00:02<11:52, 11.53 batches/s]
# Predict:   0%|          | 25/8236 [00:03<11:19, 12.08 batches/s]
# Predict:   0%|          | 27/8236 [00:03<11:13, 12.18 batches/s]
# Predict:   0%|          | 29/8236 [00:03<11:06, 12.31 batches/s]
# Predict:   0%|          | 31/8236 [00:03<11:12, 12.19 batches/s]
# Predict:   0%|          | 33/8236 [00:03<11:10, 12.23 batches/s]
# Predict:   0%|          | 35/8236 [00:03<10:56, 12.50 batches/s]
# Predict:   0%|          | 37/8236 [00:04<10:55, 12.51 batches/s]
# Predict:   0%|          | 39/8236 [00:04<11:27, 11.92 batches/s]
# Predict:   0%|          | 41/8236 [00:04<11:33, 11.81 batches/s]
# Predict:   1%|          | 43/8236 [00:04<11:40, 11.69 batches/s]
# Predict:   1%|          | 45/8236 [00:04<11:37, 11.75 batches/s]
# Predict:   1%|          | 47/8236 [00:04<11:41, 11.67 batches/s]
# Predict:   1%|          | 49/8236 [00:05<11:36, 11.75 batches/s]
# Predict:   1%|          | 51/8236 [00:05<11:09, 12.23 batches/s]
# Predict:   1%|          | 53/8236 [00:05<11:16, 12.10 batches/s]
# Predict:   1%|          | 55/8236 [00:05<11:37, 11.73 batches/s]
# Predict:   1%|          | 57/8236 [00:05<11:43, 11.62 batches/s]
# Predict:   1%|          | 59/8236 [00:05<11:32, 11.80 batches/s]
# Predict:   1%|          | 61/8236 [00:06<11:14, 12.11 batches/s]
# Predict:   1%|          | 63/8236 [00:06<11:10, 12.18 batches/s]
# Predict:   1%|          | 65/8236 [00:06<11:13, 12.13 batches/s]
# Predict:   1%|          | 67/8236 [00:06<11:31, 11.82 batches/s]
# Predict:   1%|          | 69/8236 [00:06<11:21, 11.98 batches/s]
# Predict:   1%|          | 71/8236 [00:06<11:09, 12.20 batches/s]
# Predict:   1%|          | 73/8236 [00:07<11:10, 12.17 batches/s]
# Predict:   1%|          | 75/8236 [00:07<11:10, 12.17 batches/s]
# Predict:   1%|          | 77/8236 [00:07<11:12, 12.14 batches/s]
# Predict:   1%|          | 79/8236 [00:07<11:20, 11.99 batches/s]
# Predict:   1%|          | 81/8236 [00:07<11:07, 12.22 batches/s]
# Predict:   1%|          | 83/8236 [00:07<11:13, 12.11 batches/s]
# Predict:   1%|          | 85/8236 [00:08<11:26, 11.87 batches/s]
# Predict:   1%|          | 87/8236 [00:08<11:17, 12.02 batches/s]
# Predict:   1%|          | 89/8236 [00:08<11:11, 12.13 batches/s]
# Predict:   1%|          | 91/8236 [00:08<11:10, 12.15 batches/s]
# Predict:   1%|          | 93/8236 [00:08<11:17, 12.02 batches/s]
# Predict:   1%|          | 95/8236 [00:08<11:07, 12.20 batches/s]
# Predict:   1%|          | 97/8236 [00:09<10:52, 12.48 batches/s]
# Predict:   1%|          | 99/8236 [00:09<11:05, 12.23 batches/s]
# Predict:   1%|          | 101/8236 [00:09<10:47, 12.56 batches/s]
# Predict:   1%|▏         | 103/8236 [00:09<10:49, 12.53 batches/s]
# Predict:   1%|▏         | 105/8236 [00:09<11:26, 11.84 batches/s]
# Predict:   1%|▏         | 107/8236 [00:09<11:25, 11.86 batches/s]
# Predict:   1%|▏         | 109/8236 [00:10<11:14, 12.04 batches/s]
# Predict:   1%|▏         | 111/8236 [00:10<11:10, 12.12 batches/s]
# Predict:   1%|▏         | 113/8236 [00:10<11:01, 12.28 batches/s]
# Predict:   1%|▏         | 115/8236 [00:10<11:00, 12.29 batches/s]
# Predict:   1%|▏         | 117/8236 [00:10<11:22, 11.89 batches/s]
# Predict:   1%|▏         | 119/8236 [00:10<11:18, 11.97 batches/s]
# Predict:   1%|▏         | 121/8236 [00:11<11:14, 12.03 batches/s]
# Predict:   1%|▏         | 123/8236 [00:11<11:14, 12.03 batches/s]
# Predict:   2%|▏         | 125/8236 [00:11<11:03, 12.22 batches/s]
# Predict:   2%|▏         | 127/8236 [00:11<11:02, 12.25 batches/s]
# Predict:   2%|▏         | 129/8236 [00:11<11:22, 11.87 batches/s]
# Predict:   2%|▏         | 131/8236 [00:11<11:19, 11.93 batches/s]
# Predict:   2%|▏         | 133/8236 [00:12<11:11, 12.07 batches/s]
# Predict:   2%|▏         | 135/8236 [00:12<11:29, 11.74 batches/s]
# Predict:   2%|▏         | 137/8236 [00:12<11:21, 11.88 batches/s]
# Predict:   2%|▏         | 139/8236 [00:12<11:21, 11.88 batches/s]
# Predict:   2%|▏         | 141/8236 [00:12<11:20, 11.89 batches/s]
# Predict:   2%|▏         | 143/8236 [00:12<11:12, 12.04 batches/s]
# Predict:   2%|▏         | 145/8236 [00:13<11:22, 11.85 batches/s]
# Predict:   2%|▏         | 147/8236 [00:13<11:12, 12.03 batches/s]
# Predict:   2%|▏         | 149/8236 [00:13<11:31, 11.69 batches/s]
# Predict:   2%|▏         | 151/8236 [00:13<11:15, 11.96 batches/s]
# Predict:   2%|▏         | 153/8236 [00:13<11:20, 11.87 batches/s]
# Predict:   2%|▏         | 155/8236 [00:13<11:16, 11.95 batches/s]
# Predict:   2%|▏         | 157/8236 [00:14<11:38, 11.57 batches/s]
# Predict:   2%|▏         | 159/8236 [00:14<11:21, 11.85 batches/s]
# Predict:   2%|▏         | 161/8236 [00:14<11:25, 11.78 batches/s]
# Predict:   2%|▏         | 163/8236 [00:14<11:24, 11.80 batches/s]
# Predict:   2%|▏         | 165/8236 [00:14<11:27, 11.75 batches/s]
# Predict:   2%|▏         | 167/8236 [00:14<11:27, 11.74 batches/s]
# Predict:   2%|▏         | 169/8236 [00:15<11:28, 11.72 batches/s]
# Predict:   2%|▏         | 171/8236 [00:15<11:10, 12.03 batches/s]
# Predict:   2%|▏         | 173/8236 [00:15<11:03, 12.15 batches/s]
# Predict:   2%|▏         | 175/8236 [00:15<11:20, 11.84 batches/s]
# Predict:   2%|▏         | 177/8236 [00:15<11:51, 11.33 batches/s]
# Predict:   2%|▏         | 179/8236 [00:16<11:36, 11.57 batches/s]
# Predict:   2%|▏         | 181/8236 [00:16<11:13, 11.96 batches/s]
# Predict:   2%|▏         | 183/8236 [00:16<11:13, 11.95 batches/s]
# Predict:   2%|▏         | 185/8236 [00:16<10:59, 12.21 batches/s]
# Predict:   2%|▏         | 187/8236 [00:16<11:09, 12.03 batches/s]
# Predict:   2%|▏         | 189/8236 [00:16<11:20, 11.82 batches/s]
# Predict:   2%|▏         | 191/8236 [00:16<11:04, 12.10 batches/s]
# Predict:   2%|▏         | 193/8236 [00:17<10:55, 12.28 batches/s]
# Predict:   2%|▏         | 195/8236 [00:17<10:44, 12.47 batches/s]
# Predict:   2%|▏         | 197/8236 [00:17<10:42, 12.51 batches/s]
# Predict:   2%|▏         | 199/8236 [00:17<10:44, 12.47 batches/s]
# Predict:   2%|▏         | 201/8236 [00:17<10:51, 12.33 batches/s]
# Predict:   2%|▏         | 203/8236 [00:17<10:49, 12.37 batches/s]
# Predict:   2%|▏         | 205/8236 [00:18<10:58, 12.20 batches/s]
# Predict:   3%|▎         | 207/8236 [00:18<11:05, 12.06 batches/s]
# Predict:   3%|▎         | 209/8236 [00:18<11:10, 11.98 batches/s]
# Predict:   3%|▎         | 211/8236 [00:18<10:46, 12.41 batches/s]
# Predict:   3%|▎         | 213/8236 [00:18<10:47, 12.39 batches/s]
# Predict:   3%|▎         | 215/8236 [00:18<10:49, 12.36 batches/s]
# Predict:   3%|▎         | 217/8236 [00:19<10:46, 12.41 batches/s]
# Predict:   3%|▎         | 219/8236 [00:19<11:02, 12.10 batches/s]
# Predict:   3%|▎         | 221/8236 [00:19<10:50, 12.32 batches/s]
# Predict:   3%|▎         | 223/8236 [00:19<10:46, 12.39 batches/s]
# Predict:   3%|▎         | 225/8236 [00:19<10:50, 12.32 batches/s]
# Predict:   3%|▎         | 227/8236 [00:19<10:37, 12.56 batches/s]
# Predict:   3%|▎         | 229/8236 [00:20<10:35, 12.59 batches/s]
# Predict:   3%|▎         | 231/8236 [00:20<10:37, 12.56 batches/s]
# Predict:   3%|▎         | 233/8236 [00:20<10:39, 12.51 batches/s]
# Predict:   3%|▎         | 235/8236 [00:20<10:56, 12.19 batches/s]
# Predict:   3%|▎         | 237/8236 [00:20<11:03, 12.06 batches/s]
# Predict:   3%|▎         | 239/8236 [00:20<10:58, 12.15 batches/s]
# Predict:   3%|▎         | 241/8236 [00:21<10:38, 12.52 batches/s]
# Predict:   3%|▎         | 243/8236 [00:21<10:33, 12.61 batches/s]
# Predict:   3%|▎         | 245/8236 [00:21<10:30, 12.67 batches/s]
# Predict:   3%|▎         | 247/8236 [00:21<10:26, 12.76 batches/s]
# Predict:   3%|▎         | 249/8236 [00:21<10:36, 12.55 batches/s]
# Predict:   3%|▎         | 251/8236 [00:21<10:44, 12.39 batches/s]
# Predict:   3%|▎         | 253/8236 [00:21<10:33, 12.60 batches/s]
# Predict:   3%|▎         | 255/8236 [00:22<10:28, 12.71 batches/s]
# Predict:   3%|▎         | 257/8236 [00:22<10:28, 12.70 batches/s]
# Predict:   3%|▎         | 259/8236 [00:22<10:31, 12.63 batches/s]
# Predict:   3%|▎         | 261/8236 [00:22<10:36, 12.52 batches/s]
# Predict:   3%|▎         | 263/8236 [00:22<10:47, 12.31 batches/s]
# Predict:   3%|▎         | 265/8236 [00:22<10:51, 12.23 batches/s]
# Predict:   3%|▎         | 267/8236 [00:23<10:59, 12.08 batches/s]
# Predict:   3%|▎         | 269/8236 [00:23<10:50, 12.24 batches/s]
# Predict:   3%|▎         | 271/8236 [00:23<10:38, 12.48 batches/s]
# Predict:   3%|▎         | 273/8236 [00:23<10:37, 12.49 batches/s]
# Predict:   3%|▎         | 275/8236 [00:23<10:40, 12.43 batches/s]
# Predict:   3%|▎         | 277/8236 [00:23<10:48, 12.28 batches/s]
# Predict:   3%|▎         | 279/8236 [00:24<10:56, 12.11 batches/s]
# Predict:   3%|▎         | 281/8236 [00:24<10:44, 12.33 batches/s]
# Predict:   3%|▎         | 283/8236 [00:24<10:35, 12.51 batches/s]
# Predict:   3%|▎         | 285/8236 [00:24<10:56, 12.10 batches/s]
# Predict:   3%|▎         | 287/8236 [00:24<10:51, 12.20 batches/s]
# Predict:   4%|▎         | 289/8236 [00:24<10:31, 12.59 batches/s]
# Predict:   4%|▎         | 291/8236 [00:25<10:25, 12.70 batches/s]
# Predict:   4%|▎         | 293/8236 [00:25<10:22, 12.76 batches/s]
# Predict:   4%|▎         | 295/8236 [00:25<10:17, 12.86 batches/s]
# Predict:   4%|▎         | 297/8236 [00:25<10:27, 12.64 batches/s]
# Predict:   4%|▎         | 299/8236 [00:25<10:42, 12.36 batches/s]
# Predict:   4%|▎         | 301/8236 [00:25<10:46, 12.28 batches/s]
# Predict:   4%|▎         | 303/8236 [00:25<10:29, 12.60 batches/s]
# Predict:   4%|▎         | 305/8236 [00:26<10:43, 12.32 batches/s]
# Predict:   4%|▎         | 307/8236 [00:26<10:50, 12.19 batches/s]
# Predict:   4%|▍         | 309/8236 [00:26<10:43, 12.32 batches/s]
# Predict:   4%|▍         | 311/8236 [00:26<10:43, 12.32 batches/s]
# Predict:   4%|▍         | 313/8236 [00:26<10:44, 12.30 batches/s]
# Predict:   4%|▍         | 315/8236 [00:27<11:25, 11.55 batches/s]
# Predict:   4%|▍         | 317/8236 [00:27<11:13, 11.76 batches/s]
# Predict:   4%|▍         | 319/8236 [00:27<10:58, 12.02 batches/s]
# Predict:   4%|▍         | 321/8236 [00:27<10:46, 12.24 batches/s]
# Predict:   4%|▍         | 323/8236 [00:27<11:13, 11.75 batches/s]
# Predict:   4%|▍         | 325/8236 [00:27<11:01, 11.96 batches/s]
# Predict:   4%|▍         | 327/8236 [00:27<10:54, 12.07 batches/s]
# Predict:   4%|▍         | 329/8236 [00:28<10:51, 12.13 batches/s]
# Predict:   4%|▍         | 331/8236 [00:28<10:40, 12.35 batches/s]
# Predict:   4%|▍         | 333/8236 [00:28<10:41, 12.33 batches/s]
# Predict:   4%|▍         | 335/8236 [00:28<10:36, 12.42 batches/s]
# Predict:   4%|▍         | 337/8236 [00:28<10:27, 12.60 batches/s]
# Predict:   4%|▍         | 339/8236 [00:28<10:24, 12.65 batches/s]
# Predict:   4%|▍         | 341/8236 [00:29<10:32, 12.48 batches/s]
# Predict:   4%|▍         | 343/8236 [00:29<10:29, 12.53 batches/s]
# Predict:   4%|▍         | 345/8236 [00:29<10:21, 12.69 batches/s]
# Predict:   4%|▍         | 347/8236 [00:29<10:34, 12.43 batches/s]
# Predict:   4%|▍         | 349/8236 [00:29<10:25, 12.61 batches/s]
# Predict:   4%|▍         | 351/8236 [00:29<10:24, 12.62 batches/s]
# Predict:   4%|▍         | 353/8236 [00:30<10:26, 12.59 batches/s]
# Predict:   4%|▍         | 355/8236 [00:30<10:34, 12.43 batches/s]
# Predict:   4%|▍         | 357/8236 [00:30<10:20, 12.70 batches/s]
# Predict:   4%|▍         | 359/8236 [00:30<10:21, 12.68 batches/s]
# Predict:   4%|▍         | 361/8236 [00:30<10:38, 12.34 batches/s]
# Predict:   4%|▍         | 363/8236 [00:30<10:52, 12.06 batches/s]
# Predict:   4%|▍         | 365/8236 [00:31<10:59, 11.94 batches/s]
# Predict:   4%|▍         | 367/8236 [00:31<10:44, 12.21 batches/s]
# Predict:   4%|▍         | 369/8236 [00:31<10:49, 12.12 batches/s]
# Predict:   5%|▍         | 371/8236 [00:31<11:23, 11.50 batches/s]
# Predict:   5%|▍         | 373/8236 [00:31<11:00, 11.91 batches/s]
# Predict:   5%|▍         | 375/8236 [00:31<10:45, 12.18 batches/s]
# Predict:   5%|▍         | 377/8236 [00:32<10:38, 12.30 batches/s]
# Predict:   5%|▍         | 379/8236 [00:32<10:35, 12.36 batches/s]
# Predict:   5%|▍         | 381/8236 [00:32<10:33, 12.40 batches/s]
# Predict:   5%|▍         | 383/8236 [00:32<10:35, 12.36 batches/s]
# Predict:   5%|▍         | 385/8236 [00:32<10:59, 11.90 batches/s]
# Predict:   5%|▍         | 387/8236 [00:32<11:02, 11.85 batches/s]
# Predict:   5%|▍         | 389/8236 [00:33<11:05, 11.80 batches/s]
# Predict:   5%|▍         | 391/8236 [00:33<10:53, 12.01 batches/s]
# Predict:   5%|▍         | 393/8236 [00:33<10:58, 11.91 batches/s]
# Predict:   5%|▍         | 395/8236 [00:33<10:53, 12.01 batches/s]
# Predict:   5%|▍         | 397/8236 [00:33<10:54, 11.97 batches/s]
# Predict:   5%|▍         | 399/8236 [00:33<10:54, 11.97 batches/s]
# Predict:   5%|▍         | 401/8236 [00:34<10:50, 12.04 batches/s]
# Predict:   5%|▍         | 403/8236 [00:34<10:41, 12.22 batches/s]
# Predict:   5%|▍         | 405/8236 [00:34<10:52, 12.01 batches/s]
# Predict:   5%|▍         | 407/8236 [00:34<10:39, 12.24 batches/s]
# Predict:   5%|▍         | 409/8236 [00:34<10:33, 12.36 batches/s]
# Predict:   5%|▍         | 411/8236 [00:34<10:25, 12.51 batches/s]
# Predict:   5%|▌         | 413/8236 [00:34<10:21, 12.58 batches/s]
# Predict:   5%|▌         | 415/8236 [00:35<10:27, 12.46 batches/s]
# Predict:   5%|▌         | 417/8236 [00:35<10:29, 12.43 batches/s]
# Predict:   5%|▌         | 419/8236 [00:35<10:33, 12.34 batches/s]
# Predict:   5%|▌         | 421/8236 [00:35<10:25, 12.50 batches/s]
# Predict:   5%|▌         | 423/8236 [00:35<10:20, 12.59 batches/s]
# Predict:   5%|▌         | 425/8236 [00:35<10:44, 12.11 batches/s]
# Predict:   5%|▌         | 427/8236 [00:36<10:54, 11.93 batches/s]
# Predict:   5%|▌         | 429/8236 [00:36<10:36, 12.27 batches/s]
# Predict:   5%|▌         | 431/8236 [00:36<10:38, 12.23 batches/s]
# Predict:   5%|▌         | 433/8236 [00:36<10:47, 12.05 batches/s]
# Predict:   5%|▌         | 435/8236 [00:36<10:36, 12.25 batches/s]
# Predict:   5%|▌         | 437/8236 [00:36<10:44, 12.09 batches/s]
# Predict:   5%|▌         | 439/8236 [00:37<10:34, 12.29 batches/s]
# Predict:   5%|▌         | 441/8236 [00:37<10:47, 12.05 batches/s]
# Predict:   5%|▌         | 443/8236 [00:37<11:03, 11.75 batches/s]
# Predict:   5%|▌         | 445/8236 [00:37<10:51, 11.96 batches/s]
# Predict:   5%|▌         | 447/8236 [00:37<10:38, 12.19 batches/s]
# Predict:   5%|▌         | 449/8236 [00:37<10:28, 12.39 batches/s]
# Predict:   5%|▌         | 451/8236 [00:38<10:23, 12.48 batches/s]
# Predict:   6%|▌         | 453/8236 [00:38<10:13, 12.68 batches/s]
# Predict:   6%|▌         | 455/8236 [00:38<10:12, 12.71 batches/s]
# Predict:   6%|▌         | 457/8236 [00:38<10:13, 12.68 batches/s]
# Predict:   6%|▌         | 459/8236 [00:38<10:13, 12.67 batches/s]
# Predict:   6%|▌         | 461/8236 [00:38<10:12, 12.69 batches/s]
# Predict:   6%|▌         | 463/8236 [00:39<10:12, 12.69 batches/s]
# Predict:   6%|▌         | 465/8236 [00:39<10:19, 12.54 batches/s]
# Predict:   6%|▌         | 467/8236 [00:39<10:15, 12.62 batches/s]
# Predict:   6%|▌         | 469/8236 [00:39<10:13, 12.67 batches/s]
# Predict:   6%|▌         | 471/8236 [00:39<10:16, 12.60 batches/s]
# Predict:   6%|▌         | 473/8236 [00:39<10:21, 12.50 batches/s]
# Predict:   6%|▌         | 475/8236 [00:40<10:12, 12.68 batches/s]
# Predict:   6%|▌         | 477/8236 [00:40<10:36, 12.18 batches/s]
# Predict:   6%|▌         | 479/8236 [00:40<10:39, 12.13 batches/s]
# Predict:   6%|▌         | 481/8236 [00:40<10:48, 11.95 batches/s]
# Predict:   6%|▌         | 483/8236 [00:40<10:53, 11.86 batches/s]
# Predict:   6%|▌         | 485/8236 [00:40<10:52, 11.88 batches/s]
# Predict:   6%|▌         | 487/8236 [00:41<10:43, 12.04 batches/s]
# Predict:   6%|▌         | 489/8236 [00:41<10:52, 11.87 batches/s]
# Predict:   6%|▌         | 491/8236 [00:41<10:53, 11.85 batches/s]
# Predict:   6%|▌         | 493/8236 [00:41<10:39, 12.10 batches/s]
# Predict:   6%|▌         | 495/8236 [00:41<10:33, 12.22 batches/s]
# Predict:   6%|▌         | 497/8236 [00:41<10:22, 12.44 batches/s]
# Predict:   6%|▌         | 499/8236 [00:41<10:21, 12.44 batches/s]
# Predict:   6%|▌         | 501/8236 [00:42<10:19, 12.48 batches/s]
# Predict:   6%|▌         | 503/8236 [00:42<10:27, 12.33 batches/s]
# Predict:   6%|▌         | 505/8236 [00:42<10:26, 12.34 batches/s]
# Predict:   6%|▌         | 507/8236 [00:42<10:26, 12.33 batches/s]
# Predict:   6%|▌         | 509/8236 [00:42<10:23, 12.40 batches/s]
# Predict:   6%|▌         | 511/8236 [00:42<10:07, 12.71 batches/s]
# Predict:   6%|▌         | 513/8236 [00:43<10:06, 12.73 batches/s]
# Predict:   6%|▋         | 515/8236 [00:43<10:09, 12.66 batches/s]
# Predict:   6%|▋         | 517/8236 [00:43<09:58, 12.90 batches/s]
# Predict:   6%|▋         | 519/8236 [00:43<10:17, 12.50 batches/s]
# Predict:   6%|▋         | 521/8236 [00:43<10:33, 12.18 batches/s]
# Predict:   6%|▋         | 523/8236 [00:43<10:35, 12.13 batches/s]
# Predict:   6%|▋         | 525/8236 [00:44<10:30, 12.24 batches/s]
# Predict:   6%|▋         | 527/8236 [00:44<10:20, 12.43 batches/s]
# Predict:   6%|▋         | 529/8236 [00:44<10:09, 12.64 batches/s]
# Predict:   6%|▋         | 531/8236 [00:44<10:12, 12.58 batches/s]
# Predict:   6%|▋         | 533/8236 [00:44<10:20, 12.42 batches/s]
# Predict:   6%|▋         | 535/8236 [00:44<11:03, 11.61 batches/s]
# Predict:   7%|▋         | 537/8236 [00:45<10:48, 11.86 batches/s]
# Predict:   7%|▋         | 539/8236 [00:45<10:45, 11.93 batches/s]
# Predict:   7%|▋         | 541/8236 [00:45<10:31, 12.18 batches/s]
# Predict:   7%|▋         | 543/8236 [00:45<10:47, 11.89 batches/s]
# Predict:   7%|▋         | 545/8236 [00:45<10:33, 12.14 batches/s]
# Predict:   7%|▋         | 547/8236 [00:45<10:26, 12.27 batches/s]
# Predict:   7%|▋         | 549/8236 [00:46<10:25, 12.29 batches/s]
# Predict:   7%|▋         | 551/8236 [00:46<10:12, 12.55 batches/s]
# Predict:   7%|▋         | 553/8236 [00:46<10:31, 12.17 batches/s]
# Predict:   7%|▋         | 555/8236 [00:46<10:30, 12.19 batches/s]
# Predict:   7%|▋         | 557/8236 [00:46<10:26, 12.26 batches/s]
# Predict:   7%|▋         | 559/8236 [00:46<10:27, 12.23 batches/s]
# Predict:   7%|▋         | 561/8236 [00:47<10:25, 12.27 batches/s]
# Predict:   7%|▋         | 563/8236 [00:47<10:28, 12.21 batches/s]
# Predict:   7%|▋         | 565/8236 [00:47<10:32, 12.13 batches/s]
# Predict:   7%|▋         | 567/8236 [00:47<10:17, 12.42 batches/s]
# Predict:   7%|▋         | 569/8236 [00:47<10:17, 12.41 batches/s]
# Predict:   7%|▋         | 571/8236 [00:47<10:14, 12.48 batches/s]
# Predict:   7%|▋         | 573/8236 [00:47<10:08, 12.59 batches/s]
# Predict:   7%|▋         | 575/8236 [00:48<10:05, 12.64 batches/s]
# Predict:   7%|▋         | 577/8236 [00:48<10:03, 12.69 batches/s]
# Predict:   7%|▋         | 579/8236 [00:48<10:05, 12.64 batches/s]
# Predict:   7%|▋         | 581/8236 [00:48<10:22, 12.29 batches/s]
# Predict:   7%|▋         | 583/8236 [00:48<10:15, 12.44 batches/s]
# Predict:   7%|▋         | 585/8236 [00:48<10:10, 12.54 batches/s]
# Predict:   7%|▋         | 587/8236 [00:49<10:07, 12.58 batches/s]
# Predict:   7%|▋         | 589/8236 [00:49<10:04, 12.64 batches/s]
# Predict:   7%|▋         | 591/8236 [00:49<10:23, 12.27 batches/s]
# Predict:   7%|▋         | 593/8236 [00:49<10:21, 12.30 batches/s]
# Predict:   7%|▋         | 595/8236 [00:49<10:28, 12.15 batches/s]
# Predict:   7%|▋         | 597/8236 [00:49<10:26, 12.20 batches/s]
# Predict:   7%|▋         | 599/8236 [00:50<10:38, 11.97 batches/s]
# Predict:   7%|▋         | 601/8236 [00:50<10:27, 12.17 batches/s]
# Predict:   7%|▋         | 603/8236 [00:50<10:33, 12.04 batches/s]
# Predict:   7%|▋         | 605/8236 [00:50<10:27, 12.15 batches/s]
# Predict:   7%|▋         | 607/8236 [00:50<10:17, 12.36 batches/s]
# Predict:   7%|▋         | 609/8236 [00:50<10:04, 12.62 batches/s]
# Predict:   7%|▋         | 611/8236 [00:51<10:10, 12.48 batches/s]
# Predict:   7%|▋         | 613/8236 [00:51<10:20, 12.28 batches/s]
# Predict:   7%|▋         | 615/8236 [00:51<10:31, 12.07 batches/s]
# Predict:   7%|▋         | 617/8236 [00:51<10:34, 12.02 batches/s]
# Predict:   8%|▊         | 619/8236 [00:51<10:31, 12.07 batches/s]
# Predict:   8%|▊         | 621/8236 [00:51<10:20, 12.27 batches/s]
# Predict:   8%|▊         | 623/8236 [00:52<10:14, 12.39 batches/s]
# Predict:   8%|▊         | 625/8236 [00:52<10:10, 12.47 batches/s]
# Predict:   8%|▊         | 627/8236 [00:52<10:18, 12.30 batches/s]
# Predict:   8%|▊         | 629/8236 [00:52<10:15, 12.37 batches/s]
# Predict:   8%|▊         | 631/8236 [00:52<10:30, 12.07 batches/s]
# Predict:   8%|▊         | 633/8236 [00:52<10:45, 11.79 batches/s]
# Predict:   8%|▊         | 635/8236 [00:53<10:43, 11.82 batches/s]
# Predict:   8%|▊         | 637/8236 [00:53<10:25, 12.14 batches/s]
# Predict:   8%|▊         | 639/8236 [00:53<10:37, 11.91 batches/s]
# Predict:   8%|▊         | 641/8236 [00:53<10:20, 12.24 batches/s]
# Predict:   8%|▊         | 643/8236 [00:53<10:41, 11.83 batches/s]
# Predict:   8%|▊         | 645/8236 [00:53<10:34, 11.97 batches/s]
# Predict:   8%|▊         | 647/8236 [00:54<10:20, 12.22 batches/s]
# Predict:   8%|▊         | 649/8236 [00:54<10:29, 12.05 batches/s]
# Predict:   8%|▊         | 651/8236 [00:54<10:46, 11.73 batches/s]
# Predict:   8%|▊         | 653/8236 [00:54<10:30, 12.02 batches/s]
# Predict:   8%|▊         | 655/8236 [00:54<10:18, 12.26 batches/s]
# Predict:   8%|▊         | 657/8236 [00:54<10:05, 12.51 batches/s]
# Predict:   8%|▊         | 659/8236 [00:55<10:05, 12.51 batches/s]
# Predict:   8%|▊         | 661/8236 [00:55<10:08, 12.45 batches/s]
# Predict:   8%|▊         | 663/8236 [00:55<10:10, 12.41 batches/s]
# Predict:   8%|▊         | 665/8236 [00:55<09:57, 12.66 batches/s]
# Predict:   8%|▊         | 667/8236 [00:55<09:50, 12.82 batches/s]
# Predict:   8%|▊         | 669/8236 [00:55<10:00, 12.60 batches/s]
# Predict:   8%|▊         | 671/8236 [00:55<09:53, 12.75 batches/s]
# Predict:   8%|▊         | 673/8236 [00:56<10:01, 12.57 batches/s]
# Predict:   8%|▊         | 675/8236 [00:56<10:46, 11.69 batches/s]
# Predict:   8%|▊         | 677/8236 [00:56<10:45, 11.71 batches/s]
# Predict:   8%|▊         | 679/8236 [00:56<10:31, 11.97 batches/s]
# Predict:   8%|▊         | 681/8236 [00:56<10:26, 12.06 batches/s]
# Predict:   8%|▊         | 683/8236 [00:56<10:29, 11.99 batches/s]
# Predict:   8%|▊         | 685/8236 [00:57<10:41, 11.76 batches/s]
# Predict:   8%|▊         | 687/8236 [00:57<10:47, 11.65 batches/s]
# Predict:   8%|▊         | 689/8236 [00:57<10:29, 12.00 batches/s]
# Predict:   8%|▊         | 691/8236 [00:57<10:19, 12.18 batches/s]
# Predict:   8%|▊         | 693/8236 [00:57<10:27, 12.02 batches/s]
# Predict:   8%|▊         | 695/8236 [00:58<10:28, 11.99 batches/s]
# Predict:   8%|▊         | 697/8236 [00:58<10:25, 12.04 batches/s]
# Predict:   8%|▊         | 699/8236 [00:58<10:19, 12.17 batches/s]
# Predict:   9%|▊         | 701/8236 [00:58<10:24, 12.06 batches/s]
# Predict:   9%|▊         | 703/8236 [00:58<10:18, 12.18 batches/s]
# Predict:   9%|▊         | 705/8236 [00:58<10:06, 12.42 batches/s]
# Predict:   9%|▊         | 707/8236 [00:58<10:14, 12.26 batches/s]
# Predict:   9%|▊         | 709/8236 [00:59<09:59, 12.55 batches/s]
# Predict:   9%|▊         | 711/8236 [00:59<10:15, 12.23 batches/s]
# Predict:   9%|▊         | 713/8236 [00:59<10:10, 12.31 batches/s]
# Predict:   9%|▊         | 715/8236 [00:59<10:06, 12.39 batches/s]
# Predict:   9%|▊         | 717/8236 [00:59<10:09, 12.33 batches/s]
# Predict:   9%|▊         | 719/8236 [00:59<10:10, 12.30 batches/s]
# Predict:   9%|▉         | 721/8236 [01:00<10:03, 12.45 batches/s]
# Predict:   9%|▉         | 723/8236 [01:00<10:06, 12.38 batches/s]
# Predict:   9%|▉         | 725/8236 [01:00<10:07, 12.37 batches/s]
# Predict:   9%|▉         | 727/8236 [01:00<09:53, 12.65 batches/s]
# Predict:   9%|▉         | 729/8236 [01:00<09:58, 12.55 batches/s]
# Predict:   9%|▉         | 731/8236 [01:00<09:46, 12.79 batches/s]
# Predict:   9%|▉         | 733/8236 [01:01<10:02, 12.46 batches/s]
# Predict:   9%|▉         | 735/8236 [01:01<10:13, 12.22 batches/s]
# Predict:   9%|▉         | 737/8236 [01:01<10:28, 11.93 batches/s]
# Predict:   9%|▉         | 739/8236 [01:01<10:27, 11.95 batches/s]
# Predict:   9%|▉         | 741/8236 [01:01<10:27, 11.94 batches/s]
# Predict:   9%|▉         | 743/8236 [01:01<10:08, 12.32 batches/s]
# Predict:   9%|▉         | 745/8236 [01:02<10:15, 12.16 batches/s]
# Predict:   9%|▉         | 747/8236 [01:02<10:40, 11.70 batches/s]
# Predict:   9%|▉         | 749/8236 [01:02<10:20, 12.06 batches/s]
# Predict:   9%|▉         | 751/8236 [01:02<10:15, 12.15 batches/s]
# Predict:   9%|▉         | 753/8236 [01:02<10:01, 12.45 batches/s]
# Predict:   9%|▉         | 755/8236 [01:02<09:56, 12.54 batches/s]
# Predict:   9%|▉         | 757/8236 [01:03<10:23, 11.99 batches/s]
# Predict:   9%|▉         | 759/8236 [01:03<10:21, 12.03 batches/s]
# Predict:   9%|▉         | 761/8236 [01:03<10:18, 12.08 batches/s]
# Predict:   9%|▉         | 763/8236 [01:03<10:11, 12.22 batches/s]
# Predict:   9%|▉         | 765/8236 [01:03<09:59, 12.47 batches/s]
# Predict:   9%|▉         | 767/8236 [01:03<09:54, 12.57 batches/s]
# Predict:   9%|▉         | 769/8236 [01:04<09:46, 12.74 batches/s]
# Predict:   9%|▉         | 771/8236 [01:04<09:42, 12.82 batches/s]
# Predict:   9%|▉         | 773/8236 [01:04<09:50, 12.63 batches/s]
# Predict:   9%|▉         | 775/8236 [01:04<09:45, 12.75 batches/s]
# Predict:   9%|▉         | 777/8236 [01:04<09:49, 12.66 batches/s]
# Predict:   9%|▉         | 779/8236 [01:04<09:53, 12.57 batches/s]
# Predict:   9%|▉         | 781/8236 [01:04<09:45, 12.73 batches/s]
# Predict:  10%|▉         | 783/8236 [01:05<10:07, 12.28 batches/s]
# Predict:  10%|▉         | 785/8236 [01:05<10:09, 12.23 batches/s]
# Predict:  10%|▉         | 787/8236 [01:05<10:15, 12.11 batches/s]
# Predict:  10%|▉         | 789/8236 [01:05<10:10, 12.20 batches/s]
# Predict:  10%|▉         | 791/8236 [01:05<10:23, 11.93 batches/s]
# Predict:  10%|▉         | 793/8236 [01:05<10:13, 12.14 batches/s]
# Predict:  10%|▉         | 795/8236 [01:06<09:57, 12.46 batches/s]
# Predict:  10%|▉         | 797/8236 [01:06<10:01, 12.36 batches/s]
# Predict:  10%|▉         | 799/8236 [01:06<09:58, 12.43 batches/s]
# Predict:  10%|▉         | 801/8236 [01:06<10:01, 12.36 batches/s]
# Predict:  10%|▉         | 803/8236 [01:06<10:26, 11.86 batches/s]
# Predict:  10%|▉         | 805/8236 [01:06<10:38, 11.64 batches/s]
# Predict:  10%|▉         | 807/8236 [01:07<10:22, 11.94 batches/s]
# Predict:  10%|▉         | 809/8236 [01:07<10:09, 12.18 batches/s]
# Predict:  10%|▉         | 811/8236 [01:07<10:10, 12.17 batches/s]
# Predict:  10%|▉         | 813/8236 [01:07<09:54, 12.49 batches/s]
# Predict:  10%|▉         | 815/8236 [01:07<09:57, 12.43 batches/s]
# Predict:  10%|▉         | 817/8236 [01:07<10:00, 12.35 batches/s]
# Predict:  10%|▉         | 819/8236 [01:08<09:54, 12.48 batches/s]
# Predict:  10%|▉         | 821/8236 [01:08<09:49, 12.57 batches/s]
# Predict:  10%|▉         | 823/8236 [01:08<09:46, 12.64 batches/s]
# Predict:  10%|█         | 825/8236 [01:08<10:07, 12.20 batches/s]
# Predict:  10%|█         | 827/8236 [01:08<10:03, 12.28 batches/s]
# Predict:  10%|█         | 829/8236 [01:08<10:07, 12.20 batches/s]
# Predict:  10%|█         | 831/8236 [01:09<10:15, 12.02 batches/s]
# Predict:  10%|█         | 833/8236 [01:09<10:00, 12.32 batches/s]
# Predict:  10%|█         | 835/8236 [01:09<10:21, 11.91 batches/s]
# Predict:  10%|█         | 837/8236 [01:09<10:21, 11.90 batches/s]
# Predict:  10%|█         | 839/8236 [01:09<10:14, 12.04 batches/s]
# Predict:  10%|█         | 841/8236 [01:09<10:00, 12.31 batches/s]
# Predict:  10%|█         | 843/8236 [01:10<09:53, 12.46 batches/s]
# Predict:  10%|█         | 845/8236 [01:10<09:51, 12.49 batches/s]
# Predict:  10%|█         | 847/8236 [01:10<09:58, 12.34 batches/s]
# Predict:  10%|█         | 849/8236 [01:10<09:53, 12.44 batches/s]
# Predict:  10%|█         | 851/8236 [01:10<09:47, 12.56 batches/s]
# Predict:  10%|█         | 853/8236 [01:10<09:50, 12.49 batches/s]
# Predict:  10%|█         | 855/8236 [01:11<10:09, 12.12 batches/s]
# Predict:  10%|█         | 857/8236 [01:11<10:07, 12.15 batches/s]
# Predict:  10%|█         | 859/8236 [01:11<10:06, 12.16 batches/s]
# Predict:  10%|█         | 861/8236 [01:11<10:07, 12.14 batches/s]
# Predict:  10%|█         | 863/8236 [01:11<10:24, 11.80 batches/s]
# Predict:  11%|█         | 865/8236 [01:11<10:12, 12.03 batches/s]
# Predict:  11%|█         | 867/8236 [01:12<10:03, 12.22 batches/s]
# Predict:  11%|█         | 869/8236 [01:12<09:56, 12.36 batches/s]
# Predict:  11%|█         | 871/8236 [01:12<10:11, 12.04 batches/s]
# Predict:  11%|█         | 873/8236 [01:12<10:04, 12.19 batches/s]
# Predict:  11%|█         | 875/8236 [01:12<09:53, 12.40 batches/s]
# Predict:  11%|█         | 877/8236 [01:12<09:48, 12.50 batches/s]
# Predict:  11%|█         | 879/8236 [01:12<09:42, 12.62 batches/s]
# Predict:  11%|█         | 881/8236 [01:13<09:38, 12.72 batches/s]
# Predict:  11%|█         | 883/8236 [01:13<09:39, 12.68 batches/s]
# Predict:  11%|█         | 885/8236 [01:13<09:39, 12.68 batches/s]
# Predict:  11%|█         | 887/8236 [01:13<09:43, 12.60 batches/s]
# Predict:  11%|█         | 889/8236 [01:13<09:45, 12.54 batches/s]
# Predict:  11%|█         | 891/8236 [01:13<09:53, 12.38 batches/s]
# Predict:  11%|█         | 893/8236 [01:14<09:49, 12.45 batches/s]
# Predict:  11%|█         | 895/8236 [01:14<09:43, 12.58 batches/s]
# Predict:  11%|█         | 897/8236 [01:14<09:48, 12.46 batches/s]
# Predict:  11%|█         | 899/8236 [01:14<09:42, 12.60 batches/s]
# Predict:  11%|█         | 901/8236 [01:14<09:47, 12.49 batches/s]
# Predict:  11%|█         | 903/8236 [01:14<09:43, 12.57 batches/s]
# Predict:  11%|█         | 905/8236 [01:15<09:41, 12.60 batches/s]
# Predict:  11%|█         | 907/8236 [01:15<10:05, 12.11 batches/s]
# Predict:  11%|█         | 909/8236 [01:15<10:08, 12.05 batches/s]
# Predict:  11%|█         | 911/8236 [01:15<10:05, 12.10 batches/s]
# Predict:  11%|█         | 913/8236 [01:15<10:09, 12.02 batches/s]
# Predict:  11%|█         | 915/8236 [01:15<09:53, 12.34 batches/s]
# Predict:  11%|█         | 917/8236 [01:16<09:52, 12.35 batches/s]
# Predict:  11%|█         | 919/8236 [01:16<10:05, 12.09 batches/s]
# Predict:  11%|█         | 921/8236 [01:16<09:58, 12.22 batches/s]
# Predict:  11%|█         | 923/8236 [01:16<10:17, 11.84 batches/s]
# Predict:  11%|█         | 925/8236 [01:16<10:12, 11.93 batches/s]
# Predict:  11%|█▏        | 927/8236 [01:16<10:13, 11.91 batches/s]
# Predict:  11%|█▏        | 929/8236 [01:17<09:56, 12.25 batches/s]
# Predict:  11%|█▏        | 931/8236 [01:17<09:47, 12.43 batches/s]
# Predict:  11%|█▏        | 933/8236 [01:17<09:56, 12.25 batches/s]
# Predict:  11%|█▏        | 935/8236 [01:17<09:49, 12.39 batches/s]
# Predict:  11%|█▏        | 937/8236 [01:17<09:52, 12.31 batches/s]
# Predict:  11%|█▏        | 939/8236 [01:17<10:12, 11.92 batches/s]
# Predict:  11%|█▏        | 941/8236 [01:18<09:57, 12.20 batches/s]
# Predict:  11%|█▏        | 943/8236 [01:18<10:09, 11.97 batches/s]
# Predict:  11%|█▏        | 945/8236 [01:18<09:57, 12.20 batches/s]
# Predict:  11%|█▏        | 947/8236 [01:18<09:55, 12.23 batches/s]
# Predict:  12%|█▏        | 949/8236 [01:18<10:01, 12.11 batches/s]
# Predict:  12%|█▏        | 951/8236 [01:18<09:46, 12.42 batches/s]
# Predict:  12%|█▏        | 953/8236 [01:18<09:48, 12.37 batches/s]
# Predict:  12%|█▏        | 955/8236 [01:19<09:48, 12.38 batches/s]
# Predict:  12%|█▏        | 957/8236 [01:19<09:44, 12.45 batches/s]
# Predict:  12%|█▏        | 959/8236 [01:19<09:58, 12.16 batches/s]
# Predict:  12%|█▏        | 961/8236 [01:19<09:45, 12.44 batches/s]
# Predict:  12%|█▏        | 963/8236 [01:19<09:37, 12.60 batches/s]
# Predict:  12%|█▏        | 965/8236 [01:19<09:47, 12.37 batches/s]
# Predict:  12%|█▏        | 967/8236 [01:20<09:38, 12.56 batches/s]
# Predict:  12%|█▏        | 969/8236 [01:20<09:37, 12.58 batches/s]
# Predict:  12%|█▏        | 971/8236 [01:20<09:36, 12.61 batches/s]
# Predict:  12%|█▏        | 973/8236 [01:20<09:41, 12.50 batches/s]
# Predict:  12%|█▏        | 975/8236 [01:20<09:39, 12.53 batches/s]
# Predict:  12%|█▏        | 977/8236 [01:20<09:34, 12.63 batches/s]
# Predict:  12%|█▏        | 979/8236 [01:21<09:38, 12.55 batches/s]
# Predict:  12%|█▏        | 981/8236 [01:21<09:39, 12.52 batches/s]
# Predict:  12%|█▏        | 983/8236 [01:21<09:34, 12.62 batches/s]
# Predict:  12%|█▏        | 985/8236 [01:21<09:38, 12.53 batches/s]
# Predict:  12%|█▏        | 987/8236 [01:21<09:44, 12.39 batches/s]
# Predict:  12%|█▏        | 989/8236 [01:21<09:40, 12.49 batches/s]
# Predict:  12%|█▏        | 991/8236 [01:22<09:29, 12.73 batches/s]
# Predict:  12%|█▏        | 993/8236 [01:22<09:31, 12.66 batches/s]
# Predict:  12%|█▏        | 995/8236 [01:22<09:53, 12.20 batches/s]
# Predict:  12%|█▏        | 997/8236 [01:22<09:52, 12.21 batches/s]
# Predict:  12%|█▏        | 999/8236 [01:22<10:00, 12.05 batches/s]
# Predict:  12%|█▏        | 1001/8236 [01:22<10:10, 11.86 batches/s]
# Predict:  12%|█▏        | 1003/8236 [01:23<10:09, 11.87 batches/s]
# Predict:  12%|█▏        | 1005/8236 [01:23<10:01, 12.02 batches/s]
# Predict:  12%|█▏        | 1007/8236 [01:23<09:51, 12.22 batches/s]
# Predict:  12%|█▏        | 1009/8236 [01:23<09:50, 12.24 batches/s]
# Predict:  12%|█▏        | 1011/8236 [01:23<09:40, 12.44 batches/s]
# Predict:  12%|█▏        | 1013/8236 [01:23<09:39, 12.47 batches/s]
# Predict:  12%|█▏        | 1015/8236 [01:23<09:39, 12.47 batches/s]
# Predict:  12%|█▏        | 1017/8236 [01:24<09:36, 12.51 batches/s]
# Predict:  12%|█▏        | 1019/8236 [01:24<09:35, 12.53 batches/s]
# Predict:  12%|█▏        | 1021/8236 [01:24<09:43, 12.37 batches/s]
# Predict:  12%|█▏        | 1023/8236 [01:24<09:41, 12.40 batches/s]
# Predict:  12%|█▏        | 1025/8236 [01:24<09:40, 12.43 batches/s]
# Predict:  12%|█▏        | 1027/8236 [01:24<09:30, 12.63 batches/s]
# Predict:  12%|█▏        | 1029/8236 [01:25<09:42, 12.38 batches/s]
# Predict:  13%|█▎        | 1031/8236 [01:25<09:40, 12.41 batches/s]
# Predict:  13%|█▎        | 1033/8236 [01:25<09:42, 12.36 batches/s]
# Predict:  13%|█▎        | 1035/8236 [01:25<09:48, 12.24 batches/s]
# Predict:  13%|█▎        | 1037/8236 [01:25<09:53, 12.12 batches/s]
# Predict:  13%|█▎        | 1039/8236 [01:25<09:46, 12.27 batches/s]
# Predict:  13%|█▎        | 1041/8236 [01:26<09:44, 12.32 batches/s]
# Predict:  13%|█▎        | 1043/8236 [01:26<09:34, 12.52 batches/s]
# Predict:  13%|█▎        | 1045/8236 [01:26<09:42, 12.35 batches/s]
# Predict:  13%|█▎        | 1047/8236 [01:26<10:02, 11.94 batches/s]
# Predict:  13%|█▎        | 1049/8236 [01:26<10:19, 11.61 batches/s]
# Predict:  13%|█▎        | 1051/8236 [01:26<10:10, 11.77 batches/s]
# Predict:  13%|█▎        | 1053/8236 [01:27<10:08, 11.80 batches/s]
# Predict:  13%|█▎        | 1055/8236 [01:27<10:04, 11.88 batches/s]
# Predict:  13%|█▎        | 1057/8236 [01:27<09:59, 11.97 batches/s]
# Predict:  13%|█▎        | 1059/8236 [01:27<09:54, 12.07 batches/s]
# Predict:  13%|█▎        | 1061/8236 [01:27<09:47, 12.22 batches/s]
# Predict:  13%|█▎        | 1063/8236 [01:27<10:01, 11.93 batches/s]
# Predict:  13%|█▎        | 1065/8236 [01:28<10:07, 11.80 batches/s]
# Predict:  13%|█▎        | 1067/8236 [01:28<10:07, 11.81 batches/s]
# Predict:  13%|█▎        | 1069/8236 [01:28<09:52, 12.09 batches/s]
# Predict:  13%|█▎        | 1071/8236 [01:28<09:47, 12.19 batches/s]
# Predict:  13%|█▎        | 1073/8236 [01:28<09:45, 12.24 batches/s]
# Predict:  13%|█▎        | 1075/8236 [01:28<09:41, 12.32 batches/s]
# Predict:  13%|█▎        | 1077/8236 [01:29<09:24, 12.69 batches/s]
# Predict:  13%|█▎        | 1079/8236 [01:29<09:33, 12.48 batches/s]
# Predict:  13%|█▎        | 1081/8236 [01:29<09:19, 12.79 batches/s]
# Predict:  13%|█▎        | 1083/8236 [01:29<09:31, 12.51 batches/s]
# Predict:  13%|█▎        | 1085/8236 [01:29<09:16, 12.85 batches/s]
# Predict:  13%|█▎        | 1087/8236 [01:29<09:28, 12.57 batches/s]
# Predict:  13%|█▎        | 1089/8236 [01:30<09:34, 12.43 batches/s]
# Predict:  13%|█▎        | 1091/8236 [01:30<09:29, 12.54 batches/s]
# Predict:  13%|█▎        | 1093/8236 [01:30<09:19, 12.77 batches/s]
# Predict:  13%|█▎        | 1095/8236 [01:30<09:46, 12.17 batches/s]
# Predict:  13%|█▎        | 1097/8236 [01:30<10:02, 11.84 batches/s]
# Predict:  13%|█▎        | 1099/8236 [01:30<09:57, 11.95 batches/s]
# Predict:  13%|█▎        | 1101/8236 [01:31<09:42, 12.25 batches/s]
# Predict:  13%|█▎        | 1103/8236 [01:31<09:47, 12.14 batches/s]
# Predict:  13%|█▎        | 1105/8236 [01:31<09:42, 12.24 batches/s]
# Predict:  13%|█▎        | 1107/8236 [01:31<09:55, 11.96 batches/s]
# Predict:  13%|█▎        | 1109/8236 [01:31<09:45, 12.18 batches/s]
# Predict:  13%|█▎        | 1111/8236 [01:31<09:57, 11.92 batches/s]
# Predict:  14%|█▎        | 1113/8236 [01:32<09:57, 11.92 batches/s]
# Predict:  14%|█▎        | 1115/8236 [01:32<09:49, 12.08 batches/s]
# Predict:  14%|█▎        | 1117/8236 [01:32<09:56, 11.93 batches/s]
# Predict:  14%|█▎        | 1119/8236 [01:32<09:54, 11.97 batches/s]
# Predict:  14%|█▎        | 1121/8236 [01:32<09:52, 12.00 batches/s]
# Predict:  14%|█▎        | 1123/8236 [01:32<09:50, 12.05 batches/s]
# Predict:  14%|█▎        | 1125/8236 [01:33<09:42, 12.21 batches/s]
# Predict:  14%|█▎        | 1127/8236 [01:33<09:40, 12.25 batches/s]
# Predict:  14%|█▎        | 1129/8236 [01:33<09:43, 12.19 batches/s]
# Predict:  14%|█▎        | 1131/8236 [01:33<09:39, 12.26 batches/s]
# Predict:  14%|█▍        | 1133/8236 [01:33<09:51, 12.01 batches/s]
# Predict:  14%|█▍        | 1135/8236 [01:33<09:52, 11.98 batches/s]
# Predict:  14%|█▍        | 1137/8236 [01:33<09:42, 12.18 batches/s]
# Predict:  14%|█▍        | 1139/8236 [01:34<09:47, 12.09 batches/s]
# Predict:  14%|█▍        | 1141/8236 [01:34<09:31, 12.41 batches/s]
# Predict:  14%|█▍        | 1143/8236 [01:34<09:42, 12.19 batches/s]
# Predict:  14%|█▍        | 1145/8236 [01:34<09:40, 12.22 batches/s]
# Predict:  14%|█▍        | 1147/8236 [01:34<09:28, 12.47 batches/s]
# Predict:  14%|█▍        | 1149/8236 [01:34<09:22, 12.59 batches/s]
# Predict:  14%|█▍        | 1151/8236 [01:35<09:22, 12.59 batches/s]
# Predict:  14%|█▍        | 1153/8236 [01:35<09:32, 12.38 batches/s]
# Predict:  14%|█▍        | 1155/8236 [01:35<09:41, 12.19 batches/s]
# Predict:  14%|█▍        | 1157/8236 [01:35<09:34, 12.33 batches/s]
# Predict:  14%|█▍        | 1159/8236 [01:35<09:27, 12.46 batches/s]
# Predict:  14%|█▍        | 1161/8236 [01:35<09:10, 12.86 batches/s]
# Predict:  14%|█▍        | 1163/8236 [01:36<09:06, 12.95 batches/s]
# Predict:  14%|█▍        | 1165/8236 [01:36<09:03, 13.00 batches/s]
# Predict:  14%|█▍        | 1167/8236 [01:36<09:05, 12.96 batches/s]
# Predict:  14%|█▍        | 1169/8236 [01:36<09:02, 13.02 batches/s]
# Predict:  14%|█▍        | 1171/8236 [01:36<09:20, 12.61 batches/s]
# Predict:  14%|█▍        | 1173/8236 [01:36<09:08, 12.88 batches/s]
# Predict:  14%|█▍        | 1175/8236 [01:36<09:09, 12.85 batches/s]
# Predict:  14%|█▍        | 1177/8236 [01:37<09:08, 12.86 batches/s]
# Predict:  14%|█▍        | 1179/8236 [01:37<09:07, 12.89 batches/s]
# Predict:  14%|█▍        | 1181/8236 [01:37<09:18, 12.63 batches/s]
# Predict:  14%|█▍        | 1183/8236 [01:37<09:30, 12.36 batches/s]
# Predict:  14%|█▍        | 1185/8236 [01:37<09:24, 12.49 batches/s]
# Predict:  14%|█▍        | 1187/8236 [01:37<09:15, 12.70 batches/s]
# Predict:  14%|█▍        | 1189/8236 [01:38<09:12, 12.76 batches/s]
# Predict:  14%|█▍        | 1191/8236 [01:38<09:09, 12.83 batches/s]
# Predict:  14%|█▍        | 1193/8236 [01:38<09:07, 12.87 batches/s]
# Predict:  15%|█▍        | 1195/8236 [01:38<09:15, 12.67 batches/s]
# Predict:  15%|█▍        | 1197/8236 [01:38<09:18, 12.61 batches/s]
# Predict:  15%|█▍        | 1199/8236 [01:38<09:20, 12.56 batches/s]
# Predict:  15%|█▍        | 1201/8236 [01:39<09:21, 12.52 batches/s]
# Predict:  15%|█▍        | 1203/8236 [01:39<09:19, 12.56 batches/s]
# Predict:  15%|█▍        | 1205/8236 [01:39<09:28, 12.37 batches/s]
# Predict:  15%|█▍        | 1207/8236 [01:39<09:23, 12.47 batches/s]
# Predict:  15%|█▍        | 1209/8236 [01:39<09:30, 12.31 batches/s]
# Predict:  15%|█▍        | 1211/8236 [01:39<09:24, 12.45 batches/s]
# Predict:  15%|█▍        | 1213/8236 [01:40<09:20, 12.52 batches/s]
# Predict:  15%|█▍        | 1215/8236 [01:40<09:37, 12.15 batches/s]
# Predict:  15%|█▍        | 1217/8236 [01:40<09:27, 12.36 batches/s]
# Predict:  15%|█▍        | 1219/8236 [01:40<09:18, 12.55 batches/s]
# Predict:  15%|█▍        | 1221/8236 [01:40<09:17, 12.59 batches/s]
# Predict:  15%|█▍        | 1223/8236 [01:40<09:34, 12.22 batches/s]
# Predict:  15%|█▍        | 1225/8236 [01:40<09:27, 12.35 batches/s]
# Predict:  15%|█▍        | 1227/8236 [01:41<09:22, 12.47 batches/s]
# Predict:  15%|█▍        | 1229/8236 [01:41<09:16, 12.59 batches/s]
# Predict:  15%|█▍        | 1231/8236 [01:41<09:36, 12.15 batches/s]
# Predict:  15%|█▍        | 1233/8236 [01:41<09:54, 11.78 batches/s]
# Predict:  15%|█▍        | 1235/8236 [01:41<09:52, 11.81 batches/s]
# Predict:  15%|█▌        | 1237/8236 [01:41<09:38, 12.09 batches/s]
# Predict:  15%|█▌        | 1239/8236 [01:42<09:43, 11.99 batches/s]
# Predict:  15%|█▌        | 1241/8236 [01:42<09:37, 12.11 batches/s]
# Predict:  15%|█▌        | 1243/8236 [01:42<09:22, 12.43 batches/s]
# Predict:  15%|█▌        | 1245/8236 [01:42<09:14, 12.60 batches/s]
# Predict:  15%|█▌        | 1247/8236 [01:42<09:12, 12.64 batches/s]
# Predict:  15%|█▌        | 1249/8236 [01:42<09:14, 12.60 batches/s]
# Predict:  15%|█▌        | 1251/8236 [01:43<09:22, 12.42 batches/s]
# Predict:  15%|█▌        | 1253/8236 [01:43<09:33, 12.18 batches/s]
# Predict:  15%|█▌        | 1255/8236 [01:43<09:40, 12.03 batches/s]
# Predict:  15%|█▌        | 1257/8236 [01:43<09:41, 12.00 batches/s]
# Predict:  15%|█▌        | 1259/8236 [01:43<09:32, 12.20 batches/s]
# Predict:  15%|█▌        | 1261/8236 [01:43<09:40, 12.02 batches/s]
# Predict:  15%|█▌        | 1263/8236 [01:44<09:29, 12.25 batches/s]
# Predict:  15%|█▌        | 1265/8236 [01:44<09:29, 12.24 batches/s]
# Predict:  15%|█▌        | 1267/8236 [01:44<09:33, 12.16 batches/s]
# Predict:  15%|█▌        | 1269/8236 [01:44<09:21, 12.41 batches/s]
# Predict:  15%|█▌        | 1271/8236 [01:44<09:27, 12.28 batches/s]
# Predict:  15%|█▌        | 1273/8236 [01:44<09:17, 12.49 batches/s]
# Predict:  15%|█▌        | 1275/8236 [01:45<09:15, 12.53 batches/s]
# Predict:  16%|█▌        | 1277/8236 [01:45<09:19, 12.44 batches/s]
# Predict:  16%|█▌        | 1279/8236 [01:45<09:28, 12.24 batches/s]
# Predict:  16%|█▌        | 1281/8236 [01:45<09:29, 12.22 batches/s]
# Predict:  16%|█▌        | 1283/8236 [01:45<09:23, 12.34 batches/s]
# Predict:  16%|█▌        | 1285/8236 [01:45<09:17, 12.47 batches/s]
# Predict:  16%|█▌        | 1287/8236 [01:46<09:14, 12.54 batches/s]
# Predict:  16%|█▌        | 1289/8236 [01:46<09:13, 12.56 batches/s]
# Predict:  16%|█▌        | 1291/8236 [01:46<09:21, 12.36 batches/s]
# Predict:  16%|█▌        | 1293/8236 [01:46<09:37, 12.01 batches/s]
# Predict:  16%|█▌        | 1295/8236 [01:46<09:40, 11.96 batches/s]
# Predict:  16%|█▌        | 1297/8236 [01:46<09:43, 11.89 batches/s]
# Predict:  16%|█▌        | 1299/8236 [01:47<09:39, 11.97 batches/s]
# Predict:  16%|█▌        | 1301/8236 [01:47<09:30, 12.17 batches/s]
# Predict:  16%|█▌        | 1303/8236 [01:47<09:25, 12.26 batches/s]
# Predict:  16%|█▌        | 1305/8236 [01:47<09:41, 11.93 batches/s]
# Predict:  16%|█▌        | 1307/8236 [01:47<09:42, 11.89 batches/s]
# Predict:  16%|█▌        | 1309/8236 [01:47<09:33, 12.07 batches/s]
# Predict:  16%|█▌        | 1311/8236 [01:48<09:40, 11.92 batches/s]
# Predict:  16%|█▌        | 1313/8236 [01:48<09:50, 11.72 batches/s]
# Predict:  16%|█▌        | 1315/8236 [01:48<09:39, 11.94 batches/s]
# Predict:  16%|█▌        | 1317/8236 [01:48<09:32, 12.09 batches/s]
# Predict:  16%|█▌        | 1319/8236 [01:48<09:25, 12.23 batches/s]
# Predict:  16%|█▌        | 1321/8236 [01:48<09:26, 12.21 batches/s]
# Predict:  16%|█▌        | 1323/8236 [01:49<09:22, 12.29 batches/s]
# Predict:  16%|█▌        | 1325/8236 [01:49<09:07, 12.63 batches/s]
# Predict:  16%|█▌        | 1327/8236 [01:49<09:12, 12.51 batches/s]
# Predict:  16%|█▌        | 1329/8236 [01:49<09:14, 12.45 batches/s]
# Predict:  16%|█▌        | 1331/8236 [01:49<09:11, 12.53 batches/s]
# Predict:  16%|█▌        | 1333/8236 [01:49<09:37, 11.95 batches/s]
# Predict:  16%|█▌        | 1335/8236 [01:49<09:20, 12.32 batches/s]
# Predict:  16%|█▌        | 1337/8236 [01:50<09:15, 12.41 batches/s]
# Predict:  16%|█▋        | 1339/8236 [01:50<09:10, 12.52 batches/s]
# Predict:  16%|█▋        | 1341/8236 [01:50<09:12, 12.49 batches/s]
# Predict:  16%|█▋        | 1343/8236 [01:50<09:02, 12.72 batches/s]
# Predict:  16%|█▋        | 1345/8236 [01:50<09:19, 12.32 batches/s]
# Predict:  16%|█▋        | 1347/8236 [01:50<09:16, 12.39 batches/s]
# Predict:  16%|█▋        | 1349/8236 [01:51<09:10, 12.51 batches/s]
# Predict:  16%|█▋        | 1351/8236 [01:51<09:02, 12.69 batches/s]
# Predict:  16%|█▋        | 1353/8236 [01:51<09:27, 12.13 batches/s]
# Predict:  16%|█▋        | 1355/8236 [01:51<09:42, 11.81 batches/s]
# Predict:  16%|█▋        | 1357/8236 [01:51<09:46, 11.74 batches/s]
# Predict:  17%|█▋        | 1359/8236 [01:51<09:39, 11.87 batches/s]
# Predict:  17%|█▋        | 1361/8236 [01:52<09:35, 11.94 batches/s]
# Predict:  17%|█▋        | 1363/8236 [01:52<09:12, 12.45 batches/s]
# Predict:  17%|█▋        | 1365/8236 [01:52<09:16, 12.34 batches/s]
# Predict:  17%|█▋        | 1367/8236 [01:52<09:25, 12.15 batches/s]
# Predict:  17%|█▋        | 1369/8236 [01:52<09:26, 12.13 batches/s]
# Predict:  17%|█▋        | 1371/8236 [01:52<09:21, 12.22 batches/s]
# Predict:  17%|█▋        | 1373/8236 [01:53<09:11, 12.45 batches/s]
# Predict:  17%|█▋        | 1375/8236 [01:53<09:06, 12.55 batches/s]
# Predict:  17%|█▋        | 1377/8236 [01:53<09:07, 12.54 batches/s]
# Predict:  17%|█▋        | 1379/8236 [01:53<09:23, 12.17 batches/s]
# Predict:  17%|█▋        | 1381/8236 [01:53<09:25, 12.11 batches/s]
# Predict:  17%|█▋        | 1383/8236 [01:53<09:33, 11.94 batches/s]
# Predict:  17%|█▋        | 1385/8236 [01:54<09:44, 11.73 batches/s]
# Predict:  17%|█▋        | 1387/8236 [01:54<09:27, 12.06 batches/s]
# Predict:  17%|█▋        | 1389/8236 [01:54<09:23, 12.15 batches/s]
# Predict:  17%|█▋        | 1391/8236 [01:54<09:30, 12.00 batches/s]
# Predict:  17%|█▋        | 1393/8236 [01:54<09:15, 12.33 batches/s]
# Predict:  17%|█▋        | 1395/8236 [01:54<09:18, 12.24 batches/s]
# Predict:  17%|█▋        | 1397/8236 [01:55<09:15, 12.31 batches/s]
# Predict:  17%|█▋        | 1399/8236 [01:55<09:13, 12.36 batches/s]
# Predict:  17%|█▋        | 1401/8236 [01:55<09:18, 12.24 batches/s]
# Predict:  17%|█▋        | 1403/8236 [01:55<09:02, 12.58 batches/s]
# Predict:  17%|█▋        | 1405/8236 [01:55<09:02, 12.60 batches/s]
# Predict:  17%|█▋        | 1407/8236 [01:55<09:07, 12.48 batches/s]
# Predict:  17%|█▋        | 1409/8236 [01:56<09:02, 12.58 batches/s]
# Predict:  17%|█▋        | 1411/8236 [01:56<09:17, 12.24 batches/s]
# Predict:  17%|█▋        | 1413/8236 [01:56<09:02, 12.58 batches/s]
# Predict:  17%|█▋        | 1415/8236 [01:56<09:00, 12.61 batches/s]
# Predict:  17%|█▋        | 1417/8236 [01:56<09:19, 12.20 batches/s]
# Predict:  17%|█▋        | 1419/8236 [01:56<09:20, 12.17 batches/s]
# Predict:  17%|█▋        | 1421/8236 [01:56<09:16, 12.26 batches/s]
# Predict:  17%|█▋        | 1423/8236 [01:57<09:14, 12.29 batches/s]
# Predict:  17%|█▋        | 1425/8236 [01:57<09:08, 12.41 batches/s]
# Predict:  17%|█▋        | 1427/8236 [01:57<09:04, 12.52 batches/s]
# Predict:  17%|█▋        | 1429/8236 [01:57<09:14, 12.27 batches/s]
# Predict:  17%|█▋        | 1431/8236 [01:57<09:10, 12.35 batches/s]
# Predict:  17%|█▋        | 1433/8236 [01:57<09:22, 12.09 batches/s]
# Predict:  17%|█▋        | 1435/8236 [01:58<09:20, 12.13 batches/s]
# Predict:  17%|█▋        | 1437/8236 [01:58<09:12, 12.32 batches/s]
# Predict:  17%|█▋        | 1439/8236 [01:58<09:05, 12.45 batches/s]
# Predict:  17%|█▋        | 1441/8236 [01:58<09:12, 12.30 batches/s]
# ...
# Predict:  94%|█████████▍| 7761/8236 [10:26<00:37, 12.50 batches/s]
# Predict:  94%|█████████▍| 7763/8236 [10:26<00:37, 12.69 batches/s]
# Predict:  94%|█████████▍| 7765/8236 [10:26<00:37, 12.48 batches/s]
# Predict:  94%|█████████▍| 7767/8236 [10:27<00:38, 12.28 batches/s]
# Predict:  94%|█████████▍| 7769/8236 [10:27<00:38, 12.09 batches/s]
# Predict:  94%|█████████▍| 7771/8236 [10:27<00:38, 12.02 batches/s]
# Predict:  94%|█████████▍| 7773/8236 [10:27<00:39, 11.80 batches/s]
# Predict:  94%|█████████▍| 7775/8236 [10:27<00:39, 11.70 batches/s]
# Predict:  94%|█████████▍| 7777/8236 [10:27<00:39, 11.64 batches/s]
# Predict:  94%|█████████▍| 7779/8236 [10:28<00:39, 11.71 batches/s]
# Predict:  94%|█████████▍| 7781/8236 [10:28<00:39, 11.52 batches/s]
# Predict:  94%|█████████▍| 7783/8236 [10:28<00:38, 11.72 batches/s]
# Predict:  95%|█████████▍| 7785/8236 [10:28<00:38, 11.86 batches/s]
# Predict:  95%|█████████▍| 7787/8236 [10:28<00:38, 11.75 batches/s]
# Predict:  95%|█████████▍| 7789/8236 [10:28<00:37, 12.00 batches/s]
# Predict:  95%|█████████▍| 7791/8236 [10:29<00:37, 11.81 batches/s]
# Predict:  95%|█████████▍| 7793/8236 [10:29<00:37, 11.85 batches/s]
# Predict:  95%|█████████▍| 7795/8236 [10:29<00:37, 11.80 batches/s]
# Predict:  95%|█████████▍| 7797/8236 [10:29<00:36, 12.01 batches/s]
# Predict:  95%|█████████▍| 7799/8236 [10:29<00:37, 11.78 batches/s]
# Predict:  95%|█████████▍| 7801/8236 [10:29<00:37, 11.63 batches/s]
# Predict:  95%|█████████▍| 7803/8236 [10:30<00:37, 11.63 batches/s]
# Predict:  95%|█████████▍| 7805/8236 [10:30<00:35, 12.02 batches/s]
# Predict:  95%|█████████▍| 7807/8236 [10:30<00:35, 12.07 batches/s]
# Predict:  95%|█████████▍| 7809/8236 [10:30<00:35, 11.99 batches/s]
# Predict:  95%|█████████▍| 7811/8236 [10:30<00:34, 12.18 batches/s]
# Predict:  95%|█████████▍| 7813/8236 [10:30<00:34, 12.30 batches/s]
# Predict:  95%|█████████▍| 7815/8236 [10:31<00:33, 12.40 batches/s]
# Predict:  95%|█████████▍| 7817/8236 [10:31<00:34, 12.14 batches/s]
# Predict:  95%|█████████▍| 7819/8236 [10:31<00:33, 12.30 batches/s]
# Predict:  95%|█████████▍| 7821/8236 [10:31<00:33, 12.27 batches/s]
# Predict:  95%|█████████▍| 7823/8236 [10:31<00:33, 12.27 batches/s]
# Predict:  95%|█████████▌| 7825/8236 [10:31<00:33, 12.42 batches/s]
# Predict:  95%|█████████▌| 7827/8236 [10:32<00:32, 12.46 batches/s]
# Predict:  95%|█████████▌| 7829/8236 [10:32<00:33, 12.20 batches/s]
# Predict:  95%|█████████▌| 7831/8236 [10:32<00:33, 12.06 batches/s]
# Predict:  95%|█████████▌| 7833/8236 [10:32<00:33, 12.10 batches/s]
# Predict:  95%|█████████▌| 7835/8236 [10:32<00:32, 12.31 batches/s]
# Predict:  95%|█████████▌| 7837/8236 [10:32<00:32, 12.25 batches/s]
# Predict:  95%|█████████▌| 7839/8236 [10:33<00:32, 12.40 batches/s]
# Predict:  95%|█████████▌| 7841/8236 [10:33<00:31, 12.46 batches/s]
# Predict:  95%|█████████▌| 7843/8236 [10:33<00:31, 12.37 batches/s]
# Predict:  95%|█████████▌| 7845/8236 [10:33<00:31, 12.47 batches/s]
# Predict:  95%|█████████▌| 7847/8236 [10:33<00:33, 11.70 batches/s]
# Predict:  95%|█████████▌| 7849/8236 [10:33<00:32, 11.77 batches/s]
# Predict:  95%|█████████▌| 7851/8236 [10:34<00:32, 11.96 batches/s]
# Predict:  95%|█████████▌| 7853/8236 [10:34<00:31, 12.17 batches/s]
# Predict:  95%|█████████▌| 7855/8236 [10:34<00:31, 12.22 batches/s]
# Predict:  95%|█████████▌| 7857/8236 [10:34<00:30, 12.33 batches/s]
# Predict:  95%|█████████▌| 7859/8236 [10:34<00:30, 12.30 batches/s]
# Predict:  95%|█████████▌| 7861/8236 [10:34<00:31, 12.04 batches/s]
# Predict:  95%|█████████▌| 7863/8236 [10:35<00:30, 12.10 batches/s]
# Predict:  95%|█████████▌| 7865/8236 [10:35<00:31, 11.81 batches/s]
# Predict:  96%|█████████▌| 7867/8236 [10:35<00:30, 12.05 batches/s]
# Predict:  96%|█████████▌| 7869/8236 [10:35<00:30, 11.94 batches/s]
# Predict:  96%|█████████▌| 7871/8236 [10:35<00:31, 11.70 batches/s]
# Predict:  96%|█████████▌| 7873/8236 [10:35<00:30, 11.84 batches/s]
# Predict:  96%|█████████▌| 7875/8236 [10:36<00:30, 11.98 batches/s]
# Predict:  96%|█████████▌| 7877/8236 [10:36<00:29, 12.02 batches/s]
# Predict:  96%|█████████▌| 7879/8236 [10:36<00:29, 11.95 batches/s]
# Predict:  96%|█████████▌| 7881/8236 [10:36<00:29, 12.17 batches/s]
# Predict:  96%|█████████▌| 7883/8236 [10:36<00:28, 12.29 batches/s]
# Predict:  96%|█████████▌| 7885/8236 [10:36<00:29, 12.00 batches/s]
# Predict:  96%|█████████▌| 7887/8236 [10:37<00:28, 12.27 batches/s]
# Predict:  96%|█████████▌| 7889/8236 [10:37<00:28, 12.12 batches/s]
# Predict:  96%|█████████▌| 7891/8236 [10:37<00:28, 12.22 batches/s]
# Predict:  96%|█████████▌| 7893/8236 [10:37<00:28, 11.98 batches/s]
# Predict:  96%|█████████▌| 7895/8236 [10:37<00:28, 12.04 batches/s]
# Predict:  96%|█████████▌| 7897/8236 [10:37<00:28, 11.95 batches/s]
# Predict:  96%|█████████▌| 7899/8236 [10:38<00:28, 11.89 batches/s]
# Predict:  96%|█████████▌| 7901/8236 [10:38<00:28, 11.94 batches/s]
# Predict:  96%|█████████▌| 7903/8236 [10:38<00:28, 11.67 batches/s]
# Predict:  96%|█████████▌| 7905/8236 [10:38<00:29, 11.39 batches/s]
# Predict:  96%|█████████▌| 7907/8236 [10:38<00:28, 11.50 batches/s]
# Predict:  96%|█████████▌| 7909/8236 [10:38<00:28, 11.61 batches/s]
# Predict:  96%|█████████▌| 7911/8236 [10:39<00:28, 11.26 batches/s]
# Predict:  96%|█████████▌| 7913/8236 [10:39<00:27, 11.56 batches/s]
# Predict:  96%|█████████▌| 7915/8236 [10:39<00:26, 11.95 batches/s]
# Predict:  96%|█████████▌| 7917/8236 [10:39<00:26, 12.15 batches/s]
# Predict:  96%|█████████▌| 7919/8236 [10:39<00:26, 11.95 batches/s]
# Predict:  96%|█████████▌| 7921/8236 [10:39<00:27, 11.37 batches/s]
# Predict:  96%|█████████▌| 7923/8236 [10:40<00:27, 11.46 batches/s]
# Predict:  96%|█████████▌| 7925/8236 [10:40<00:26, 11.53 batches/s]
# Predict:  96%|█████████▌| 7927/8236 [10:40<00:26, 11.78 batches/s]
# Predict:  96%|█████████▋| 7929/8236 [10:40<00:26, 11.73 batches/s]
# Predict:  96%|█████████▋| 7931/8236 [10:40<00:25, 11.95 batches/s]
# Predict:  96%|█████████▋| 7933/8236 [10:40<00:25, 11.73 batches/s]
# Predict:  96%|█████████▋| 7935/8236 [10:41<00:25, 11.76 batches/s]
# Predict:  96%|█████████▋| 7937/8236 [10:41<00:25, 11.70 batches/s]
# Predict:  96%|█████████▋| 7939/8236 [10:41<00:25, 11.67 batches/s]
# Predict:  96%|█████████▋| 7941/8236 [10:41<00:25, 11.78 batches/s]
# Predict:  96%|█████████▋| 7943/8236 [10:41<00:24, 11.95 batches/s]
# Predict:  96%|█████████▋| 7945/8236 [10:41<00:23, 12.21 batches/s]
# Predict:  96%|█████████▋| 7947/8236 [10:42<00:23, 12.42 batches/s]
# Predict:  97%|█████████▋| 7949/8236 [10:42<00:23, 12.35 batches/s]
# Predict:  97%|█████████▋| 7951/8236 [10:42<00:23, 12.31 batches/s]
# Predict:  97%|█████████▋| 7953/8236 [10:42<00:22, 12.42 batches/s]
# Predict:  97%|█████████▋| 7955/8236 [10:42<00:22, 12.42 batches/s]
# Predict:  97%|█████████▋| 7957/8236 [10:42<00:22, 12.45 batches/s]
# Predict:  97%|█████████▋| 7959/8236 [10:43<00:22, 12.20 batches/s]
# Predict:  97%|█████████▋| 7961/8236 [10:43<00:22, 12.38 batches/s]
# Predict:  97%|█████████▋| 7963/8236 [10:43<00:21, 12.60 batches/s]
# Predict:  97%|█████████▋| 7965/8236 [10:43<00:22, 12.24 batches/s]
# Predict:  97%|█████████▋| 7967/8236 [10:43<00:21, 12.39 batches/s]
# Predict:  97%|█████████▋| 7969/8236 [10:43<00:22, 11.98 batches/s]
# Predict:  97%|█████████▋| 7971/8236 [10:44<00:22, 11.97 batches/s]
# Predict:  97%|█████████▋| 7973/8236 [10:44<00:21, 12.04 batches/s]
# Predict:  97%|█████████▋| 7975/8236 [10:44<00:21, 12.01 batches/s]
# Predict:  97%|█████████▋| 7977/8236 [10:44<00:21, 12.28 batches/s]
# Predict:  97%|█████████▋| 7979/8236 [10:44<00:20, 12.26 batches/s]
# Predict:  97%|█████████▋| 7981/8236 [10:44<00:20, 12.25 batches/s]
# Predict:  97%|█████████▋| 7983/8236 [10:45<00:20, 12.54 batches/s]
# Predict:  97%|█████████▋| 7985/8236 [10:45<00:20, 12.34 batches/s]
# Predict:  97%|█████████▋| 7987/8236 [10:45<00:19, 12.55 batches/s]
# Predict:  97%|█████████▋| 7989/8236 [10:45<00:19, 12.56 batches/s]
# Predict:  97%|█████████▋| 7991/8236 [10:45<00:20, 12.24 batches/s]
# Predict:  97%|█████████▋| 7993/8236 [10:45<00:19, 12.25 batches/s]
# Predict:  97%|█████████▋| 7995/8236 [10:45<00:19, 12.37 batches/s]
# Predict:  97%|█████████▋| 7997/8236 [10:46<00:19, 12.25 batches/s]
# Predict:  97%|█████████▋| 7999/8236 [10:46<00:19, 12.22 batches/s]
# Predict:  97%|█████████▋| 8001/8236 [10:46<00:18, 12.48 batches/s]
# Predict:  97%|█████████▋| 8003/8236 [10:46<00:19, 11.96 batches/s]
# Predict:  97%|█████████▋| 8005/8236 [10:46<00:19, 11.64 batches/s]
# Predict:  97%|█████████▋| 8007/8236 [10:47<00:19, 11.60 batches/s]
# Predict:  97%|█████████▋| 8009/8236 [10:47<00:18, 11.95 batches/s]
# Predict:  97%|█████████▋| 8011/8236 [10:47<00:18, 12.28 batches/s]
# Predict:  97%|█████████▋| 8013/8236 [10:47<00:17, 12.43 batches/s]
# Predict:  97%|█████████▋| 8015/8236 [10:47<00:17, 12.31 batches/s]
# Predict:  97%|█████████▋| 8017/8236 [10:47<00:17, 12.45 batches/s]
# Predict:  97%|█████████▋| 8019/8236 [10:47<00:18, 11.91 batches/s]
# Predict:  97%|█████████▋| 8021/8236 [10:48<00:17, 12.00 batches/s]
# Predict:  97%|█████████▋| 8023/8236 [10:48<00:17, 12.20 batches/s]
# Predict:  97%|█████████▋| 8025/8236 [10:48<00:17, 12.03 batches/s]
# Predict:  97%|█████████▋| 8027/8236 [10:48<00:17, 11.85 batches/s]
# Predict:  97%|█████████▋| 8029/8236 [10:48<00:17, 12.03 batches/s]
# Predict:  98%|█████████▊| 8031/8236 [10:48<00:17, 11.82 batches/s]
# Predict:  98%|█████████▊| 8033/8236 [10:49<00:17, 11.59 batches/s]
# Predict:  98%|█████████▊| 8035/8236 [10:49<00:17, 11.79 batches/s]
# Predict:  98%|█████████▊| 8037/8236 [10:49<00:16, 12.05 batches/s]
# Predict:  98%|█████████▊| 8039/8236 [10:49<00:16, 12.28 batches/s]
# Predict:  98%|█████████▊| 8041/8236 [10:49<00:16, 12.16 batches/s]
# Predict:  98%|█████████▊| 8043/8236 [10:49<00:15, 12.21 batches/s]
# Predict:  98%|█████████▊| 8045/8236 [10:50<00:15, 12.12 batches/s]
# Predict:  98%|█████████▊| 8047/8236 [10:50<00:15, 12.08 batches/s]
# Predict:  98%|█████████▊| 8049/8236 [10:50<00:15, 12.14 batches/s]
# Predict:  98%|█████████▊| 8051/8236 [10:50<00:15, 12.28 batches/s]
# Predict:  98%|█████████▊| 8053/8236 [10:50<00:14, 12.35 batches/s]
# Predict:  98%|█████████▊| 8055/8236 [10:50<00:14, 12.09 batches/s]
# Predict:  98%|█████████▊| 8057/8236 [10:51<00:15, 11.86 batches/s]
# Predict:  98%|█████████▊| 8059/8236 [10:51<00:14, 12.21 batches/s]
# Predict:  98%|█████████▊| 8061/8236 [10:51<00:14, 12.23 batches/s]
# Predict:  98%|█████████▊| 8063/8236 [10:51<00:14, 12.33 batches/s]
# Predict:  98%|█████████▊| 8065/8236 [10:51<00:14, 12.09 batches/s]
# Predict:  98%|█████████▊| 8067/8236 [10:51<00:13, 12.20 batches/s]
# Predict:  98%|█████████▊| 8069/8236 [10:52<00:13, 12.43 batches/s]
# Predict:  98%|█████████▊| 8071/8236 [10:52<00:13, 12.27 batches/s]
# Predict:  98%|█████████▊| 8073/8236 [10:52<00:13, 12.30 batches/s]
# Predict:  98%|█████████▊| 8075/8236 [10:52<00:12, 12.39 batches/s]
# Predict:  98%|█████████▊| 8077/8236 [10:52<00:12, 12.41 batches/s]
# Predict:  98%|█████████▊| 8079/8236 [10:52<00:12, 12.08 batches/s]
# Predict:  98%|█████████▊| 8081/8236 [10:53<00:12, 12.08 batches/s]
# Predict:  98%|█████████▊| 8083/8236 [10:53<00:12, 12.24 batches/s]
# Predict:  98%|█████████▊| 8085/8236 [10:53<00:12, 12.11 batches/s]
# Predict:  98%|█████████▊| 8087/8236 [10:53<00:12, 11.96 batches/s]
# Predict:  98%|█████████▊| 8089/8236 [10:53<00:12, 12.10 batches/s]
# Predict:  98%|█████████▊| 8091/8236 [10:53<00:11, 12.22 batches/s]
# Predict:  98%|█████████▊| 8093/8236 [10:54<00:12, 11.89 batches/s]
# Predict:  98%|█████████▊| 8095/8236 [10:54<00:11, 12.23 batches/s]
# Predict:  98%|█████████▊| 8097/8236 [10:54<00:11, 12.22 batches/s]
# Predict:  98%|█████████▊| 8099/8236 [10:54<00:11, 12.11 batches/s]
# Predict:  98%|█████████▊| 8101/8236 [10:54<00:11, 12.07 batches/s]
# Predict:  98%|█████████▊| 8103/8236 [10:54<00:10, 12.53 batches/s]
# Predict:  98%|█████████▊| 8105/8236 [10:55<00:10, 12.35 batches/s]
# Predict:  98%|█████████▊| 8107/8236 [10:55<00:10, 12.39 batches/s]
# Predict:  98%|█████████▊| 8109/8236 [10:55<00:10, 12.25 batches/s]
# Predict:  98%|█████████▊| 8111/8236 [10:55<00:10, 12.27 batches/s]
# Predict:  99%|█████████▊| 8113/8236 [10:55<00:09, 12.43 batches/s]
# Predict:  99%|█████████▊| 8115/8236 [10:55<00:10, 12.08 batches/s]
# Predict:  99%|█████████▊| 8117/8236 [10:56<00:09, 11.90 batches/s]
# Predict:  99%|█████████▊| 8119/8236 [10:56<00:09, 12.27 batches/s]
# Predict:  99%|█████████▊| 8121/8236 [10:56<00:09, 12.01 batches/s]
# Predict:  99%|█████████▊| 8123/8236 [10:56<00:09, 12.21 batches/s]
# Predict:  99%|█████████▊| 8125/8236 [10:56<00:08, 12.40 batches/s]
# Predict:  99%|█████████▊| 8127/8236 [10:56<00:08, 12.23 batches/s]
# Predict:  99%|█████████▊| 8129/8236 [10:57<00:08, 12.26 batches/s]
# Predict:  99%|█████████▊| 8131/8236 [10:57<00:08, 12.43 batches/s]
# Predict:  99%|█████████▊| 8133/8236 [10:57<00:08, 12.53 batches/s]
# Predict:  99%|█████████▉| 8135/8236 [10:57<00:08, 12.40 batches/s]
# Predict:  99%|█████████▉| 8137/8236 [10:57<00:07, 12.61 batches/s]
# Predict:  99%|█████████▉| 8139/8236 [10:57<00:07, 12.60 batches/s]
# Predict:  99%|█████████▉| 8141/8236 [10:57<00:07, 12.38 batches/s]
# Predict:  99%|█████████▉| 8143/8236 [10:58<00:07, 11.95 batches/s]
# Predict:  99%|█████████▉| 8145/8236 [10:58<00:07, 12.16 batches/s]
# Predict:  99%|█████████▉| 8147/8236 [10:58<00:07, 12.07 batches/s]
# Predict:  99%|█████████▉| 8149/8236 [10:58<00:07, 12.29 batches/s]
# Predict:  99%|█████████▉| 8151/8236 [10:58<00:06, 12.28 batches/s]
# Predict:  99%|█████████▉| 8153/8236 [10:58<00:06, 12.47 batches/s]
# Predict:  99%|█████████▉| 8155/8236 [10:59<00:06, 12.31 batches/s]
# Predict:  99%|█████████▉| 8157/8236 [10:59<00:06, 12.21 batches/s]
# Predict:  99%|█████████▉| 8159/8236 [10:59<00:06, 12.17 batches/s]
# Predict:  99%|█████████▉| 8161/8236 [10:59<00:06, 12.13 batches/s]
# Predict:  99%|█████████▉| 8163/8236 [10:59<00:06, 12.11 batches/s]
# Predict:  99%|█████████▉| 8165/8236 [10:59<00:05, 11.88 batches/s]
# Predict:  99%|█████████▉| 8167/8236 [11:00<00:05, 11.81 batches/s]
# Predict:  99%|█████████▉| 8169/8236 [11:00<00:05, 11.80 batches/s]
# Predict:  99%|█████████▉| 8171/8236 [11:00<00:05, 12.03 batches/s]
# Predict:  99%|█████████▉| 8173/8236 [11:00<00:05, 11.74 batches/s]
# Predict:  99%|█████████▉| 8175/8236 [11:00<00:05, 11.91 batches/s]
# Predict:  99%|█████████▉| 8177/8236 [11:00<00:04, 11.84 batches/s]
# Predict:  99%|█████████▉| 8179/8236 [11:01<00:04, 11.73 batches/s]
# Predict:  99%|█████████▉| 8181/8236 [11:01<00:04, 12.02 batches/s]
# Predict:  99%|█████████▉| 8183/8236 [11:01<00:04, 12.28 batches/s]
# Predict:  99%|█████████▉| 8185/8236 [11:01<00:04, 12.48 batches/s]
# Predict:  99%|█████████▉| 8187/8236 [11:01<00:03, 12.38 batches/s]
# Predict:  99%|█████████▉| 8189/8236 [11:01<00:03, 11.92 batches/s]
# Predict:  99%|█████████▉| 8191/8236 [11:02<00:03, 11.76 batches/s]
# Predict:  99%|█████████▉| 8193/8236 [11:02<00:03, 11.90 batches/s]
# Predict: 100%|█████████▉| 8195/8236 [11:02<00:03, 11.95 batches/s]
# Predict: 100%|█████████▉| 8197/8236 [11:02<00:03, 12.06 batches/s]
# Predict: 100%|█████████▉| 8199/8236 [11:02<00:03, 12.05 batches/s]
# Predict: 100%|█████████▉| 8201/8236 [11:02<00:02, 12.00 batches/s]
# Predict: 100%|█████████▉| 8203/8236 [11:03<00:02, 11.93 batches/s]
# Predict: 100%|█████████▉| 8205/8236 [11:03<00:02, 12.13 batches/s]
# Predict: 100%|█████████▉| 8207/8236 [11:03<00:02, 12.38 batches/s]
# Predict: 100%|█████████▉| 8209/8236 [11:03<00:02, 12.55 batches/s]
# Predict: 100%|█████████▉| 8211/8236 [11:03<00:01, 12.77 batches/s]
# Predict: 100%|█████████▉| 8213/8236 [11:03<00:01, 12.78 batches/s]
# Predict: 100%|█████████▉| 8215/8236 [11:04<00:01, 12.66 batches/s]
# Predict: 100%|█████████▉| 8217/8236 [11:04<00:01, 12.74 batches/s]
# Predict: 100%|█████████▉| 8219/8236 [11:04<00:01, 13.07 batches/s]
# Predict: 100%|█████████▉| 8221/8236 [11:04<00:01, 13.00 batches/s]
# Predict: 100%|█████████▉| 8223/8236 [11:04<00:01, 12.94 batches/s]
# Predict: 100%|█████████▉| 8225/8236 [11:04<00:00, 12.71 batches/s]
# Predict: 100%|█████████▉| 8227/8236 [11:05<00:00, 12.94 batches/s]
# Predict: 100%|█████████▉| 8229/8236 [11:05<00:00, 12.42 batches/s]
# Predict: 100%|█████████▉| 8231/8236 [11:05<00:00, 12.30 batches/s]
# Predict: 100%|█████████▉| 8233/8236 [11:05<00:00, 12.94 batches/s]
# Predict: 100%|██████████| 8236/8236 [11:05<00:00, 12.37 batches/s]
# Val eval time: 723.588577329001

# %%
# # load eval results - also we can resume eval at a later point in time
# with open(exp_model_dir + os.sep + "val5yr_actuals.pkl", "rb") as fin:
#     val_acutals = pickle.load(fin)

# with open(exp_model_dir + os.sep + "val5yr_q_predictions.pkl", "rb") as fin:
#     val_q_predictions = pickle.load(fin)

val_predictions = val_q_predictions[:, :, 3] # p50 == estimation
val_p90 = val_q_predictions[:, :,5] # p90
#del val_q_predictions
    
# Unmasked evaltaion
eval_metric = get_eval_metrics(val_actuals, val_predictions, None, val_p90)
print(f"Unmasked Val eval evaluation: {eval_metric}")

# Masked evlationa
start = default_timer()
mask = torch.logical_not(torch.cat([x['decoder_cat'][:, :, -1].reshape(-1) for x, y in iter(val_dataloader)]))
masked_eval_metric = get_eval_metrics(val_actuals, val_predictions, mask, val_p90)
eval_time = default_timer() - start
print(f"Masked Val eval time: {eval_time}")
print(f"Masked Val eval evaluation: {masked_eval_metric}")
# Out:
# Unmasked Val eval evaluation: {'rmse': 3.7135982513427734, 'mae': 2.0345048904418945, 'nse': 0.7280431985855103, 'r2': 0.728043250362639, 'p50_loss': 0.5005776882171631, 'p90_loss': 0.28066569566726685}
# Masked Val eval time: 60.46160401199995
# Masked Val eval evaluation: {'rmse': 1.5558595657348633, 'mae': 0.8453733325004578, 'nse': 0.20473861694335938, 'r2': 0.20473860699055235, 'p50_loss': 0.9071527719497681, 'p90_loss': 0.5814838409423828}

# %% [markdown]
# # Model Interpreation

# %%
# Setup dataset
train_df, val_df, _ = get_splited_datasets(data_df, VAL_INDEX, TEST_INDEX)
train_df, val_df, _ = subset_data(train_df, val_df, None, SUBSET_LEN)
_, validation, _ = setup_tsdataset_nogpp(train_df, val_df, None, ENCODER_LEN)
raw_predictions = best_tft.predict(validation, mode="raw",  show_progress_bar=True)
interpretation = best_tft.interpret_output(raw_predictions, reduction="sum")
best_tft.plot_interpretation(interpretation)
# Out:
# Subest length: 43800 timesteps for each sites
# Subset num train timesteps: 2579424
# Subset num val timesteps: 952752
# Predict: 100%|██████████| 14858/14858 [16:44<00:00, 14.79 batches/s]
# {'attention': <Figure size 640x480 with 1 Axes>,
#  'static_variables': <Figure size 700x225 with 1 Axes>,
#  'encoder_variables': <Figure size 700x675 with 1 Axes>,
#  'decoder_variables': <Figure size 700x675 with 1 Axes>}
